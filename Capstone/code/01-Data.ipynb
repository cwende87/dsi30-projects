# %% [markdown]
# # Capstone: SG Food Recommender
# Author: Choo Wende
#
# ---

# %% [markdown]
# <details>
# 1. https://towardsdatascience.com/yelp-restaurant-recommendation-system-capstone-project-264fe7a7dea1
# 2. https://github.com/dominiczrong/yelp-restaurant-recommendation-system
# 3. https://github.com/jcy10/DSI-Capstone-Project4. https://github.com/nikasso/movie2vec
# 5. https://github.com/dnaylah/movie-recommender
# 6. https://towardsdatascience.com/foodiebuddie-how-we-built-singapores-first-food-recommender-b7f3eed0ac77
# 7. https://github.com/terenceneo/Social-Analytics </details>

# %% [markdown]
# ## Background

# %% [markdown]
# ## Problem Statement

# %%
# pip install webdriver-manager

# %% [markdown]
# ## Libraries Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import json
import requests
import re

from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
from bs4 import BeautifulSoup
from datetime import datetime
from nltk.corpus import stopwords

import time
import random

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## 1. WebScrapping Yelp

# %% [markdown]
# ### Restaurant Info

# %%
# Web page used is from yelp.com that is filtered by 99 neighbourhoods.
# Target web page:
url='https://www.yelp.com/search?find_desc=Restaurants&find_loc=Singapore&l=p%3ASG-SG%3ASingapore%3A%3A%5BAlexandra%2CAng_Mo_Kio%2CAnn_Siang_Hill%2CArab_Street%2CBayfront%2CBedok_North%2CBedok_Reservoir%2CBedok_South%2CBencoolen%2CBishan%2CBoat_Quay%2CBoon_Keng%2CBoon_Lay%2CBras_Brasah%2CBuangkok%2CBugis%2CBukit_Batok%2CBukit_Panjang%2CBukit_Timah%2CChangi%2CChinatown%2CChoa_Chu_Kang%2CCity_Hall%2CClarke_Quay%2CClementi%2CDempsey_Hill%2CDhoby_Ghaut%2CDover%2CDuxton_Hill%2CEunos%2CFarrer_Park%2CGeylang%2CGhim_Moh%2CHarbourfront%2CHolland_Hill%2CHolland_Village%2CHougang%2CJoo_Chiat%2CJurong%2CJurong_Island%2CKallang%2CKatong%2CKembangan%2CKent_Ridge%2CKeppel%2CLabrador_Park%2CLavender%2CLim_Chu_Kang%2CLittle_India%2CMacpherson%2CMandai%2CMarine_Parade%2CMount_Sophia%2CMountbatten%2CNewton%2CNovena%2COrchard%2COutram%2CPasir_Panjang%2CPasir_Ris%2CPaya_Lebar%2CPotong_Pasir%2CPulau_Ubin%2CPunggol%2CQueenstown%2CRaffles_Place%2CRedhill%2CRiver_Valley%2CRobertson_Quay%2CSeletar%2CSembawang%2CSengkang%2CSentosa%2CSerangoon%2CSerangoon_Gardens%2CSiglap%2CSimei%2CSixth_Avenue%2CSomerset%2CTampines%2CTanglin%2CTanglin_Halt%2CTanjong_Pagar%2CTanjong_Rhu%2CTelok_Blangah%2CTelok_Kurau%2CThomson%2CTiong_Bahru%2CToa_Payoh%2CTuas%2CUbi%2CUlu_Pandan%2CUpper_Bukit_Timah%2CWessex_Estate%2CWest_Coast%2CWoodlands%2CYio_Chu_Kang%2CYishun%2Cone-north%5D'

# %%
# Establishing the connection to the web page:
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
res.text[:500]
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel='

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %% [markdown]
# **Extract Neighbourhood**

# %%
# Extract the list of Singapore neighbourhood in Yelp. 
neighbourhoods=[]

for row in soup.find('div', {'class':'transitionGroup__09f24__nJIf6'}):
    if row.text!=' • ':
        neighbourhoods.append(row.text)


# display list of neighbourhoods
neighbourhoods[-5:]
# Out:
# ['Queenstown', 'Potong Pasir', 'Pulau Ubin', 'Paya Lebar', "Bird's-eye View"]

# %%
# Remove last element as it is invalid.
neighbourhoods.remove("Bird's-eye View")

# %%
# create list of neighbourhood url
neighbourhood_urls = {}

for hood in sorted(neighbourhoods):
    hoods=[]
    
    text=hood.replace(' ', '+')
    hoods.append(f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={text}%2C+Singapore')
    
    for i in range(10, 240, 10):
        hoods.append(f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={text}%2C+Singapore&start={i}')
        
    neighbourhood_urls[hood]=hoods

# %%
# Display first 5 urls for each neighbourhood
pd.DataFrame(neighbourhood_urls).head()
# Out:
#                                            Alexandra  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                           Ang Mo Kio  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                       Ann Siang Hill  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                          Arab Street  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                             Bayfront  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                          Bedok North  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                      Bedok Reservoir  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                          Bedok South  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                            Bencoolen  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                               Bishan  ...  \
# 0  https://www.yelp.com/search?find_desc=Restaura...  ...
# 1  https://www.yelp.com/search?find_desc=Restaura...  ...
# 2  https://www.yelp.com/search?find_desc=Restaura...  ...
# 3  https://www.yelp.com/search?find_desc=Restaura...  ...
# 4  https://www.yelp.com/search?find_desc=Restaura...  ...
#
#                                                 Tuas  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                                  Ubi  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                           Ulu Pandan  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                    Upper Bukit Timah  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                        Wessex Estate  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                           West Coast  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                            Woodlands  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                         Yio Chu Kang  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                               Yishun  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                            one-north
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
# [5 rows x 99 columns]

# %% [markdown]
# **Extract Restaurant Info**

# %%
def get_soup(url):
    
    # Establishing the connection to the web page:
    res = requests.get(url, stream=True)

    if res.status_code==200:
        return BeautifulSoup(res.content, 'lxml')
        
    else:
        print(f'Res Status Code: {res.status_code}')
        pass

# %%
def get_data(hood, url):
    
    print(url)
    soup=get_soup(url)

    restaurants = []

    # restaurants details
    biz=soup.find_all('span', {'class':'css-1egxyvc'})

    # image
    img=soup.find_all('img', {'class':'css-xlzvdl'})
    
    # rating
    rating_class='attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ margin-r1__09f24__rN_ga border-color--default__09f24__NPAKY'
            
    # review count
    review_count=soup.find_all('span', {'class':'reviewCount__09f24__tnBk4 css-chan6m'})
    
    # location
    # location=soup.find_all('span', {'class':'css-chan6m'})[1:21:2]
    location=soup.find_all('p',{'class':'css-dzq7l1'})
    
    #category
    category=soup.find_all('span', {'class':'css-epvm6 display--inline__09f24__c6N_k border-color--default__09f24__NPAKY'})

    # PriceRange
    pricerange=soup.find_all('p', {'class':'css-dzq7l1'})

    for i in range(len(biz)):
        
        # biz info
        restaurant ={}
        restaurant['neighbourhood'] = hood
        restaurant['name']=biz[i].a['name']
        href=biz[i].a['href']
        restaurant['href']=f'www.yelp.com{href}'
        
        # image info
        restaurant['img']=img[i]['src']

        # rating info
        row=soup.find_all('div', {'class':rating_class})[i]
        restaurant['star_rating']=row.div['aria-label'].replace(' star rating','')

        # Review count info
        restaurant['review_count']=review_count[i].text

        # Location info
        restaurant['location']=location[i].find('span',{'class':'css-chan6m'}).text

        # category info
        try:
            cats_ls=[]
            cat=category[i].find_all('span', {'class':'css-11bijt4'})
            for j in range(len(cat)):
                cats_ls.append(cat[j].text)
            restaurant['category']=cats_ls
        except:
            restaurant['category']=None

        # Price range info
        price=pricerange[i].find('span', {'class':'priceRange__09f24__mmOuH'})
        try:
            restaurant['price_range']=len(price.text)
        except:
            restaurant['price_range']=price
        
        restaurants.append(restaurant)
        restaurant ={}
        
    return pd.DataFrame(restaurants)

# %% [markdown]
# ```python
# # The following code scrape through Yelp for restaurants info based on neighbourhood search
# # A total of 99 neighbourhoods were available on yelp to search.
# # The codes are commented out to prevent re-run of the code, which took some time to run.
#
# # Create restaurant dataframe.
# rest_data = pd.DataFrame()
#
# for hood, urls in list(neighbourhood_urls.items()):
#     print(f'\nScraping from {hood}:')
#     for i in range(len(urls)):
#         hood_data = get_data(hood, urls[i])
#         rest_data=pd.concat([rest_data, hood_data]).reset_index(drop=True)
#
#         if i%np.random.randint(8,11)==0:
#             # generate a random sleep duration to manage number of requests per second
#             sleep_duration = np.random.randint(5,12)
#             print(f'Sleep: {sleep_duration}s')
#             time.sleep(sleep_duration)
#     text=hood.replace(' ', '_')
#     rest_data.to_csv(f'../data/neighbourhoods/{text}.csv', index=False)
#     rest_data = pd.DataFrame()
#
#     # generate a random sleep duration to manage number of requests per second.
#     # Sleep duration is set at such long interval
#     # because shorter intervals will face interruption by the server.
#     sleep_duration = np.random.randint(60,80)
#     print(f'Sleep: {sleep_duration}s')
#     time.sleep(sleep_duration)
# ```

# %%
# Create dataframe of restaurants to merge data in various neighbourhood
rest_df=pd.DataFrame()

for hood in list(neighbourhood_urls.keys()):
    
    text=hood.replace(' ', '_')
    temp_df=pd.read_csv(f'../data/neighbourhoods/{text}.csv')
    rest_df=pd.concat([rest_df, temp_df]).reset_index(drop=True)
    
# Display first 5 and last 5 rows of restaurant dataframe.
rest_df
# Out:
#       neighbourhood                               name  \
# 0         Alexandra                     The Naked Finn
# 1         Alexandra                  Soi Thai Soi Nice
# 2         Alexandra                           The Gogi
# 3         Alexandra               Keng Eng Kee Seafood
# 4         Alexandra                        Burger Barn
# ...             ...                                ...
# 14946     one-north                  The World is Flat
# 14947     one-north                        Food Canopy
# 14948     one-north                Thaksin Beef Noodle
# 14949     one-north  The Bakery By Woodlands Sourdough
# 14950     one-north    Chuan Kee Boneless Braised Duck
#
#                                                     href  \
# 0      www.yelp.com/biz/the-naked-finn-singapore?osq=...
# 1      www.yelp.com/biz/soi-thai-soi-nice-singapore?o...
# 2      www.yelp.com/biz/the-gogi-singapore?osq=Restau...
# 3      www.yelp.com/biz/keng-eng-kee-seafood-singapor...
# 4      www.yelp.com/biz/burger-barn-singapore?osq=Res...
# ...                                                  ...
# 14946  www.yelp.com/biz/the-world-is-flat-singapore?o...
# 14947  www.yelp.com/biz/food-canopy-singapore?osq=Res...
# 14948  www.yelp.com/biz/thaksin-beef-noodle-singapore...
# 14949  www.yelp.com/biz/the-bakery-by-woodlands-sourd...
# 14950  www.yelp.com/biz/chuan-kee-boneless-braised-du...
#
#                                                      img  star_rating  \
# 0      https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1      https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2      https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
# 3      https://s3-media0.fl.yelpcdn.com/bphoto/1TziiZ...          4.0
# 4      https://s3-media0.fl.yelpcdn.com/bphoto/ABw7yU...          4.0
# ...                                                  ...          ...
# 14946  https://s3-media0.fl.yelpcdn.com/bphoto/JZgM6o...          3.0
# 14947  https://s3-media0.fl.yelpcdn.com/bphoto/Z12m7m...          3.0
# 14948  https://s3-media0.fl.yelpcdn.com/bphoto/wvQ5wj...          4.5
# 14949  https://s3-media0.fl.yelpcdn.com/bphoto/q0HOoI...          5.0
# 14950  https://s3-media0.fl.yelpcdn.com/bphoto/n9HZCW...          4.5
#
#        review_count     location                                 category  \
# 0                19    Alexandra                              ['Seafood']
# 1                 2    Alexandra                                 ['Thai']
# 2                 1    Alexandra                   ['Korean', 'Barbeque']
# 3                22    Alexandra                              ['Seafood']
# 4                 4    Alexandra                              ['Burgers']
# ...             ...          ...                                      ...
# 14946             1    one-north  ['Pizza', 'Asian Fusion', 'Sandwiches']
# 14947             1  Bukit Timah                           ['Food Court']
# 14948             2   West Coast                              ['Chinese']
# 14949             1  Bukit Timah                    ['Bakeries', 'Pizza']
# 14950             7     Ghim Moh                              ['Chinese']
#
#        price_range
# 0              3.0
# 1              NaN
# 2              NaN
# 3              2.0
# 4              1.0
# ...            ...
# 14946          NaN
# 14947          NaN
# 14948          1.0
# 14949          NaN
# 14950          1.0
#
# [14951 rows x 9 columns]

# %%
# Display summary info.
rest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14951 entries, 0 to 14950
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   neighbourhood  14951 non-null  object
#  1   name           14951 non-null  object
#  2   href           14951 non-null  object
#  3   img            14951 non-null  object
#  4   star_rating    14951 non-null  float64
#  5   review_count   14951 non-null  int64
#  6   location       14523 non-null  object
#  7   category       14939 non-null  object
#  8   price_range    7959 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.0+ MB

# %%
# Display numeric columns summary info
rest_df.describe()
# Out:
#         star_rating  review_count  price_range
# count  14951.000000  14951.000000  7959.000000
# mean       4.021972      8.622768     1.932529
# std        0.717602     21.443366     0.889946
# min        1.000000      1.000000     1.000000
# 25%        3.500000      1.000000     1.000000
# 50%        4.000000      3.000000     2.000000
# 75%        4.500000      8.000000     2.000000
# max        5.000000    385.000000     4.000000

# %%
# Number of unique restaurants
len(rest_df['href'].unique())
# Out:
# 4026

# %%
# show number of duplicates
rest_df.duplicated().value_counts()
# Out:
# False    14411
# True       540
# dtype: int64

# %% [markdown]
# ### Restaurant Reviews

# %%
# Create dataframe of unique restaurants and url
rest_url=rest_df.drop(columns=['neighbourhood', 'location']).drop_duplicates(subset=['href']).reset_index(drop=True)

# Display first 5 rows of dataframe
rest_url.head()
# Out:
#                    name                                               href  \
# 0        The Naked Finn  www.yelp.com/biz/the-naked-finn-singapore?osq=...
# 1     Soi Thai Soi Nice  www.yelp.com/biz/soi-thai-soi-nice-singapore?o...
# 2              The Gogi  www.yelp.com/biz/the-gogi-singapore?osq=Restau...
# 3  Keng Eng Kee Seafood  www.yelp.com/biz/keng-eng-kee-seafood-singapor...
# 4           Burger Barn  www.yelp.com/biz/burger-barn-singapore?osq=Res...
#
#                                                  img  star_rating  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/1TziiZ...          4.0
# 4  https://s3-media0.fl.yelpcdn.com/bphoto/ABw7yU...          4.0
#
#    review_count                category  price_range
# 0            19             ['Seafood']          3.0
# 1             2                ['Thai']          NaN
# 2             1  ['Korean', 'Barbeque']          NaN
# 3            22             ['Seafood']          2.0
# 4             4             ['Burgers']          1.0

# %%
# Display shape of rest_url
rest_url.shape
# Out:
# (4026, 7)

# %%
# add 'http://' to 'href' column
rest_url['href'] = 'http://' + rest_url['href']

# %%
# Display restaurants with high review count
rest_url[rest_url['review_count']>100]
# Out:
#                                  name  \
# 454  Tian Tian Hainanese Chicken Rice
# 515                     Jumbo Seafood
# 557               Song Fa Bak Kut Teh
# 667              Liao Fan Hawker Chan
# 672               CÉ LA VI Restaurant
# 750                      Din Tai Fung
#
#                                                   href  \
# 454  http://www.yelp.com/biz/tian-tian-hainanese-ch...
# 515  http://www.yelp.com/biz/jumbo-seafood-singapor...
# 557  http://www.yelp.com/biz/song-fa-bak-kut-teh-si...
# 667  http://www.yelp.com/biz/liao-fan-hawker-chan-s...
# 672  http://www.yelp.com/biz/c%C3%A9-la-vi-restaura...
# 750  http://www.yelp.com/biz/din-tai-fung-singapore...
#
#                                                    img  star_rating  \
# 454  https://s3-media0.fl.yelpcdn.com/bphoto/UJ5Kp3...          4.0
# 515  https://s3-media0.fl.yelpcdn.com/bphoto/85hCRe...          4.0
# 557  https://s3-media0.fl.yelpcdn.com/bphoto/cgE6mZ...          4.0
# 667  https://s3-media0.fl.yelpcdn.com/bphoto/LMpD02...          4.0
# 672  https://s3-media0.fl.yelpcdn.com/bphoto/Y9T9Iu...          3.0
# 750  https://s3-media0.fl.yelpcdn.com/bphoto/fxsbP8...          4.5
#
#      review_count                               category  price_range
# 454           385             ['Hainan', 'Chicken Shop']          1.0
# 515           188                            ['Seafood']          3.0
# 557           136             ['Singaporean', 'Chinese']          1.0
# 667           140            ['Noodles', 'Chicken Shop']          1.0
# 672           134               ['Bars', 'Asian Fusion']          3.0
# 750           132  ['Taiwanese', 'Dim Sum', 'Dumplings']          2.0

# %%
# Generate url to extract reviews.

# Create a column of urls to extract reviews. 
rest_url['review_url'] = np.nan
rest_url.head()

# Loop through every row to input urls
for i in range(len(rest_url['href'])):
    url_ls = rest_url['href'][i]
    
    if rest_url['review_count'][i]<11:
        pass
    else:
        # check number of url pages to scrap reviews.
        pages=int(rest_url['review_count'][i]/10) + (rest_url['review_count'][i]%10 > 0)
                
        for j in range(10, (pages*10), 10):
            url_ls = url_ls + ' ' + (rest_url['href'][i]+f'&start={j}')
    
    rest_url.loc[i, 'review_url']= url_ls

# %%
# Check dataframe and column created.
rest_url.head()
# Out:
#                    name                                               href  \
# 0        The Naked Finn  http://www.yelp.com/biz/the-naked-finn-singapo...
# 1     Soi Thai Soi Nice  http://www.yelp.com/biz/soi-thai-soi-nice-sing...
# 2              The Gogi  http://www.yelp.com/biz/the-gogi-singapore?osq...
# 3  Keng Eng Kee Seafood  http://www.yelp.com/biz/keng-eng-kee-seafood-s...
# 4           Burger Barn  http://www.yelp.com/biz/burger-barn-singapore?...
#
#                                                  img  star_rating  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/1TziiZ...          4.0
# 4  https://s3-media0.fl.yelpcdn.com/bphoto/ABw7yU...          4.0
#
#    review_count                category  price_range  \
# 0            19             ['Seafood']          3.0
# 1             2                ['Thai']          NaN
# 2             1  ['Korean', 'Barbeque']          NaN
# 3            22             ['Seafood']          2.0
# 4             4             ['Burgers']          1.0
#
#                                           review_url
# 0  http://www.yelp.com/biz/the-naked-finn-singapo...
# 1  http://www.yelp.com/biz/soi-thai-soi-nice-sing...
# 2  http://www.yelp.com/biz/the-gogi-singapore?osq...
# 3  http://www.yelp.com/biz/keng-eng-kee-seafood-s...
# 4  http://www.yelp.com/biz/burger-barn-singapore?...

# %%
# Check total number of reviews 
rest_url['review_count'].sum()
# Out:
# 24792

# %%
# Define function to scrape reviews. 
def get_reviews(rest_name, url):
    
    # Instantiate reviews list
    reviews =[]
    
    print(url)
    soup=get_soup(url)

    reviews = []

    # restaurants address info
    add = ''

    for row in soup.find('address').find_all('span', {'class':'raw__09f24__T4Ezm'}):
        add += (row.text + ' ')

    alt_add = soup.find('address').find_all('span', {'class':'raw__09f24__T4Ezm'})[0].text
    

    # Get postal code and latitude, longitude via onemap api
    try:
        postal_code = re.search('\d{6}', add).group()
        onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={postal_code}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
        latitude = json.loads(onemap.p.text)['results'][0]['LATITUDE']
        longitude = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']
    
    except:
        onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={alt_add}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
        
        try: 
            postal_code = json.loads(onemap.p.text)['results'][0]['POSTAL']
            latitude = json.loads(onemap.p.text)['results'][0]['LATITUDE']
            longitude = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']
        except:
            latitude = np.nan
            longitude = np.nan
            try:
                postal_code = postal_code
            except:
                postal_code = np.nan
    
    # opening hours info
    day=[]
    hrs=[]
    
    opening_table = soup.find('table', {'class':'hours-table__09f24__KR8wh table__09f24__J2OBP table--simple__09f24__vy16f'})
    
    for row in opening_table.find_all('th', {'class':"table-header-cell__09f24__y32Xb"}):
        day.append(row.text)

    for row in opening_table.find_all('ul', {'class':"undefined list__09f24__ynIEd"}):
        subset=[]
        for i in range(len(row.find_all('li'))):
            subset.append(row.find_all('li')[i].text)
        hrs.append(subset)
        
    opening = list(zip(day, hrs))

    # Review info
    review_div = soup.find('div', {'class':'css-79elbk border-color--default__09f24__NPAKY'})
    review_li = review_div.find_all('li', {'class':'margin-b5__09f24__pTvws border-color--default__09f24__NPAKY'})
    
    # scrape through every review. 
    for row in review_li:
        
        # instantiate review dictionary to store information. 
        review = {}
        
        # Store additional restaurants information.
        review['rest_name'] = rest_name
        review['address'] = add
        review['postal_code'] = postal_code
        review['latitude'] = latitude
        review['longitude'] = longitude
        review['opening'] = opening        
        
        # username
        try:
            user_info = row.find('div', {'class':'user-passport-info border-color--default__09f24__NPAKY'})
            review['username'] = user_info.a.text

        except:
            # user might be blocked.
            # Hence, their comments may not be credible
            break   
        
        # usesrid
        review['userid'] = user_info.a['href'].replace('/user_details?userid=','')
        
        # location
        try:
            review['user_location'] = user_info.find('span', {'class':'css-qgunke'}).text
        except:
            # some users did not indicate where they are from. 
            # hence, we will indicate as null value. 
            review['user_location'] = np.nan
        
        # rating
        rating_div = row.find('div', {'class':'margin-t1__09f24__w96jn margin-b1-5__09f24__NHcQi border-color--default__09f24__NPAKY'})
        review['user_rating'] = rating_div.span.div['aria-label'].replace(' star rating','')
        
        # date of post
        review['review_date'] = row.find('span', {'class':'css-chan6m'}).text
        
        # comments
        review['comment'] = row.find('span', {'class':'raw__09f24__T4Ezm'}).text
        
        reviews.append(review)
        review ={}
        
    return pd.DataFrame(reviews)

# %% [markdown]
# ```python
# # The following code scrape through Yelp for restaurants review
# # The codes are commented out to prevent re-run of the code, which took some time to run.
#
# # Create review dataframe.
# reviews_data = pd.DataFrame()
# count_url = 0
# i = 200
#
# # while loop is used instead of (for i in range(400, len(rest_url)):)
# # because there better control on restarting scrapping a particular restaurants when needed.
# while i < len(rest_url):
#
#     to_break = 0
#
#     # Display info on scrapping status
#     rest_name = rest_url.loc[i, 'name']
#     print(f'\nScraping from {rest_name}:')
#     print(i)
#
#     urls = rest_url.loc[i, 'review_url'].split()
#
#     for url in urls:
#
#         try:
#             review_data = get_reviews(rest_name, url)
#
#         except:
#
#             # sleep and try scrapping again.
#             # generate a random sleep duration to manage number of requests per second
#             sleep_duration = np.random.randint(60,80)
#             print(f'Sleep: {sleep_duration}s')
#             time.sleep(sleep_duration)
#
#             # break from url loop and restart scrapping
#             to_break = 1
#             break
#
#         # to add data to dataframe.
#         reviews_data = pd.concat([reviews_data, review_data]).reset_index(drop=True)
#         count_url +=1
#
#         # generate a random sleep duration to manage number of requests per second
#         # at random interval in every 20 restaurants.
#         if count_url%np.random.randint(7,10)==0:
#             sleep_duration = np.random.randint(5,8)
#             print(f'Sleep: {sleep_duration}s')
#             time.sleep(sleep_duration)
#
#         # generate a random sleep duration to manage number of requests per second
#         # sleep after scraping every 20 urls
#         if (count_url+1)%20 == 0:
#             sleep_duration = np.random.randint(10,15)
#             print(f'Sleep: {sleep_duration}s')
#             time.sleep(sleep_duration)
#
#     # reset i and restart scrapping
#     if to_break:
#         rest_name = rest_url.loc[i, 'name']
#         print(f'Restart scrapping from last restaurant: i is {i}, {rest_name}')
#
#     else:
#
#         # increase i count by 1
#         i += 1
#
#         # Save out data after every 20 restaurants
#         if i%20 == 0:
#             reviews_data.to_csv(f'../data/reviews/reviews_{i}.csv', index=False)
#             print(f'Saved to reviews_{i}.csv')
#             rest_data = pd.DataFrame()
#
#         # Save last set of data
#         if i == len(rest_url):
#             reviews_data.to_csv(f'../data/reviews/reviews_{(i)//10*10 + 10}.csv', index=False)
#             rest_data = pd.DataFrame()
#             print('Scrap Completed')
#
# ```

# %%
# Create dataframe of reviews to merge data of various restaurants
reviews_df=pd.DataFrame()

for i in range(20, rest_url.shape[0] + 10, 20):
    # Read saved data
    temp_df = pd.read_csv(f'../data/reviews/reviews_{i}.csv')
    
    # Extract restaurant href to be used as rest id.
    rest_href_df = rest_url.loc[i-20:i+1, ['name', 'href']]
    
    # Merge temp_df and rest_href_df
    temp_df = pd.merge(temp_df, rest_href_df, left_on = 'rest_name', right_on = 'name', how = 'left')
    temp_df.drop(columns = ['name'], inplace=True)
    temp_df.dropna(subset = 'href', axis=0, inplace=True)
    
    # add data to reviews_df
    reviews_df=pd.concat([reviews_df, temp_df]).reset_index(drop=True)

# %%
# Rearrange columns
reviews_df = reviews_df[['rest_name', 'href'] + reviews_df.drop(columns = ['rest_name', 'href']).columns.tolist()]

# %%
# Display first 5 and last 5 rows of restaurant dataframe.
reviews_df
# Out:
#                   rest_name  \
# 0            The Naked Finn
# 1            The Naked Finn
# 2            The Naked Finn
# 3            The Naked Finn
# 4            The Naked Finn
# ...                     ...
# 28123       Wadori Yakitori
# 28124  Thai Hao Chi Mookata
# 28125         Seoul Jjimdak
# 28126         Seoul Jjimdak
# 28127         Seoul Jjimdak
#
#                                                     href  \
# 0      http://www.yelp.com/biz/the-naked-finn-singapo...
# 1      http://www.yelp.com/biz/the-naked-finn-singapo...
# 2      http://www.yelp.com/biz/the-naked-finn-singapo...
# 3      http://www.yelp.com/biz/the-naked-finn-singapo...
# 4      http://www.yelp.com/biz/the-naked-finn-singapo...
# ...                                                  ...
# 28123  http://www.yelp.com/biz/wadori-yakitori-singap...
# 28124  http://www.yelp.com/biz/thai-hao-chi-mookata-s...
# 28125  http://www.yelp.com/biz/seoul-jjimdak-singapor...
# 28126  http://www.yelp.com/biz/seoul-jjimdak-singapor...
# 28127  http://www.yelp.com/biz/seoul-jjimdak-singapor...
#
#                                                  address postal_code  \
# 0                39 Malan Rd Singapore 109442 Singapore       109442
# 1                39 Malan Rd Singapore 109442 Singapore       109442
# 2                39 Malan Rd Singapore 109442 Singapore       109442
# 3                39 Malan Rd Singapore 109442 Singapore       109442
# 4                39 Malan Rd Singapore 109442 Singapore       109442
# ...                                                  ...         ...
# 28123  1 Woodlands Square #B1-17 Singapore 738099 Sin...      738099
# 28124   908 Upper Thomson Rd Singapore 787111 Singapore       787111
# 28125  930 Yishun Avenue 2 #B1-179 Singapore 769098 S...      769098
# 28126  930 Yishun Avenue 2 #B1-179 Singapore 769098 S...      769098
# 28127  930 Yishun Avenue 2 #B1-179 Singapore 769098 S...      769098
#
#        latitude   longitude  \
# 0      1.276081  103.804434
# 1      1.276081  103.804434
# 2      1.276081  103.804434
# 3      1.276081  103.804434
# 4      1.276081  103.804434
# ...         ...         ...
# 28123  1.435900  103.785796
# 28124  1.398459  103.818329
# 28125  1.429244  103.836107
# 28126  1.429244  103.836107
# 28127  1.429244  103.836107
#
#                                                  opening    username  \
# 0      [('Mon', ['12:00 PM - 3:00 PM', '6:00 PM - 10:...   San-Ju T.
# 1      [('Mon', ['12:00 PM - 3:00 PM', '6:00 PM - 10:...   Doreen T.
# 2      [('Mon', ['12:00 PM - 3:00 PM', '6:00 PM - 10:...     Ancy N.
# 3      [('Mon', ['12:00 PM - 3:00 PM', '6:00 PM - 10:...   Wesley L.
# 4      [('Mon', ['12:00 PM - 3:00 PM', '6:00 PM - 10:...    Bjørn B.
# ...                                                  ...         ...
# 28123                                                 []    Boris P.
# 28124  [('Mon', ['5:30 PM - 12:00 AM (Next day)']), (...    Danny T.
# 28125  [('Mon', ['11:30 AM - 10:00 PM']), ('Tue', ['1...  Zhi Yan C.
# 28126  [('Mon', ['11:30 AM - 10:00 PM']), ('Tue', ['1...  Melissa Y.
# 28127  [('Mon', ['11:30 AM - 10:00 PM']), ('Tue', ['1...   Doreen T.
#
#                        userid                    user_location  user_rating  \
# 0      ij3UcrQUXl7YBoBTcH89rQ             Singapore, Singapore            5
# 1      2F38Uc4UNNbFVdyUUnBjOA             Singapore, Singapore            4
# 2      4y4obgWxi_CL25nRHrhuEA             Singapore, Singapore            4
# 3      i0x6MWNiFLQ2cV3aIVjO5g                        Wayne, PA            3
# 4      w3Md0jvpgG2ZiMRoAYRPCQ                     Oslo, Norway            5
# ...                       ...                              ...          ...
# 28123  YQ6MAHSW4jTAzGRUvio1yA                    Manhattan, NY            2
# 28124  e9Sn1IZZZ_1Qa_vUdtskjA     Bishan, Singapore, Singapore            5
# 28125  HjlYjgSv_mA-35VuMef94Q  Sembawang, Singapore, Singapore            4
# 28126  H8mXfh5XgGCqmMLwVH7k5A             Singapore, Singapore            4
# 28127  2F38Uc4UNNbFVdyUUnBjOA             Singapore, Singapore            3
#
#       review_date                                            comment
# 0      12/24/2019  The Naked FinnWell known for its seafood for d...
# 1      12/26/2020  The place was quite difficult to book even for...
# 2        7/7/2013  Love the space. If anyone remember Klee (now d...
# 3       11/5/2015  I really want to like this place more, but I c...
# 4       6/22/2016  The Naked Finn is run by Ken Loon whom I met t...
# ...           ...                                                ...
# 28123   3/22/2018  Came here for lunch.Their yakitori sticks are ...
# 28124   5/19/2017  Been here couple of times. Love the mookata he...
# 28125   1/20/2019  Taste: Jjimdak at Seoul Jjimdak is a mixture o...
# 28126   3/13/2018  Loved the jimdak here! The portion of the tend...
# 28127    1/9/2018  The restaurant had recently opened at the new ...
#
# [28128 rows x 13 columns]

# %%
# Display summary info.
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28128 entries, 0 to 28127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rest_name      28128 non-null  object
#  1   href           28128 non-null  object
#  2   address        28128 non-null  object
#  3   postal_code    28033 non-null  object
#  4   latitude       27809 non-null  float64
#  5   longitude      27809 non-null  float64
#  6   opening        28128 non-null  object
#  7   username       28128 non-null  object
#  8   userid         28128 non-null  object
#  9   user_location  28127 non-null  object
#  10  user_rating    28128 non-null  int64
#  11  review_date    28128 non-null  object
#  12  comment        28128 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.8+ MB

# %%
# Display numeric columns summary info
reviews_df.describe()
# Out:
#            latitude     longitude  user_rating
# count  27809.000000  27809.000000  28128.00000
# mean       1.304497    103.847851      3.79771
# std        0.027347      0.039466      1.08914
# min        1.244007    103.631753      1.00000
# 25%        1.287151    103.834676      3.00000
# 50%        1.300839    103.846491      4.00000
# 75%        1.309908    103.857758      5.00000
# max        1.469394    103.989707      5.00000

# %% [markdown]
# ## 2. Data Cleaning and Processing

# %% [markdown]
# ### Restaurant Info

# %% [markdown]
# Datatypes for dataframe seems to be correctly assigned.

# %%
# Display data types
rest_df.dtypes
# Out:
# neighbourhood     object
# name              object
# href              object
# img               object
# star_rating      float64
# review_count       int64
# location          object
# category          object
# price_range      float64
# dtype: object

# %% [markdown]
# #### Remove Duplicates
# Unique restaurants are identified using their `href`, yelp restaurant website.

# %%
# drop duplicates and display first 3 restaurants. 
rest_df = rest_df.drop_duplicates(subset='href')
rest_df.head(3)
# Out:
#   neighbourhood               name  \
# 0     Alexandra     The Naked Finn
# 1     Alexandra  Soi Thai Soi Nice
# 2     Alexandra           The Gogi
#
#                                                 href  \
# 0  www.yelp.com/biz/the-naked-finn-singapore?osq=...
# 1  www.yelp.com/biz/soi-thai-soi-nice-singapore?o...
# 2  www.yelp.com/biz/the-gogi-singapore?osq=Restau...
#
#                                                  img  star_rating  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
#
#    review_count   location                category  price_range
# 0            19  Alexandra             ['Seafood']          3.0
# 1             2  Alexandra                ['Thai']          NaN
# 2             1  Alexandra  ['Korean', 'Barbeque']          NaN

# %% [markdown]
# #### Check null values

# %%
# Display summary of null values
rest_df.isnull().sum()
# Out:
# neighbourhood       0
# name                0
# href                0
# img                 0
# star_rating         0
# review_count        0
# location          110
# category            5
# price_range      2015
# dtype: int64

# %% [markdown]
# **`location`** <br>
# The null values will be imputed using on K-Nearest Neighbour based on latitude and longitude after merging with Restaurant Reviews dataframe.

# %%
# Display null values for locations.
rest_df[rest_df['location'].isnull()]
# Out:
#       neighbourhood                                             name  \
# 167       Alexandra                                            Atout
# 188       Alexandra                                   Rochester Cafe
# 192       Alexandra                                         Brewerkz
# 232       Alexandra                                 2fifteen Kitchen
# 277      Ang Mo Kio                                   Flavour Flings
# ...             ...                                              ...
# 12946       Thomson  Golden Triangle Thai and Kamats Indian at Koufu
# 14259     Woodlands                          Sunflower Bakery & Cafe
# 14305     Woodlands                               Flower In A Window
# 14313     Woodlands                                      Souper Tang
# 14337     Woodlands                                  SK Sayed Bistro
#
#                                                     href  \
# 167     www.yelp.com/biz/atout-singapore?osq=Restaurants
# 188    www.yelp.com/biz/rochester-cafe-singapore?osq=...
# 192    www.yelp.com/biz/brewerkz-singapore-4?osq=Rest...
# 232    www.yelp.com/biz/2fifteen-kitchen-singapore?os...
# 277    www.yelp.com/biz/flavour-flings-singapore?osq=...
# ...                                                  ...
# 12946  www.yelp.com/biz/golden-triangle-thai-and-kama...
# 14259  www.yelp.com/biz/sunflower-bakery-and-cafe-joh...
# 14305  www.yelp.com/biz/flower-in-a-window-johor-bahr...
# 14313  www.yelp.com/biz/souper-tang-johor-bahru-2?osq...
# 14337  www.yelp.com/biz/sk-sayed-bistro-johor-bahru?o...
#
#                                                      img  star_rating  \
# 167    https://s3-media0.fl.yelpcdn.com/bphoto/zmMX7i...          4.5
# 188    https://s3-media0.fl.yelpcdn.com/bphoto/8D0huU...          4.0
# 192    https://s3-media0.fl.yelpcdn.com/bphoto/3uE4vF...          4.5
# 232    https://s3-media0.fl.yelpcdn.com/bphoto/1TSVnB...          3.5
# 277    https://s3-media0.fl.yelpcdn.com/bphoto/ohg6aa...          4.5
# ...                                                  ...          ...
# 12946  https://s3-media0.fl.yelpcdn.com/bphoto/lBNaHb...          5.0
# 14259  https://s3-media0.fl.yelpcdn.com/bphoto/65c5H8...          5.0
# 14305  https://s3-media0.fl.yelpcdn.com/bphoto/iSo8ex...          3.5
# 14313  https://s3-media0.fl.yelpcdn.com/bphoto/H7_oQ9...          2.0
# 14337  https://s3-media0.fl.yelpcdn.com/bphoto/_fnsED...          4.0
#
#        review_count location                                category  \
# 167               4      NaN                 ['Wine Bars', 'French']
# 188               1      NaN                               ['Cafes']
# 192               4      NaN  ['American (Traditional)', 'Beer Bar']
# 232               2      NaN                         ['Singaporean']
# 277               7      NaN                               ['Cafes']
# ...             ...      ...                                     ...
# 12946             1      NaN                          ['Food Court']
# 14259             1      NaN                   ['Bakeries', 'Cafes']
# 14305             2      NaN   ['Cafes', 'Coffee & Tea', 'Bakeries']
# 14313             2      NaN                     ['Soup', 'Chinese']
# 14337             1      NaN      ['Bistros', 'Indian', 'Malaysian']
#
#        price_range
# 167            NaN
# 188            NaN
# 192            NaN
# 232            NaN
# 277            NaN
# ...            ...
# 12946          NaN
# 14259          NaN
# 14305          NaN
# 14313          NaN
# 14337          NaN
#
# [110 rows x 9 columns]

# %%
# Check unique values for 'locations'
rest_df['location'].unique()
# Out:
# array(['Alexandra', 'Tanglin', 'Redhill', 'Telok Blangah', 'Queenstown',
#        'Pasir Panjang', 'Dempsey Hill', 'Kent Ridge', 'Sentosa',
#        'Harbourfront', 'one-north', 'Wessex Estate', 'Labrador Park',
#        'Dover', '$$', 'River Valley', 'Tanglin Halt', 'Tiong Bahru',
#        'Bukit Timah', 'Holland Hill', '$', nan, 'Ang Mo Kio', 'Hougang',
#        'Bishan', 'Yio Chu Kang', '$$$', 'Thomson', 'Farrer Park',
#        'Toa Payoh', 'Serangoon Gardens', 'Novena', 'Seletar', 'Serangoon',
#        'Boon Keng', 'Ubi', 'Macpherson', 'Geylang', 'Little India',
#        'Sengkang', 'Eunos', 'Yishun', 'Newton', 'Mandai', 'Potong Pasir',
#        'Tanjong Pagar', 'Ann Siang Hill', 'Raffles Place', 'Chinatown',
#        'Bugis', 'Arab Street', 'Lavender', 'Clarke Quay', 'City Hall',
#        'Bras Brasah', 'Bencoolen', 'Mount Sophia', 'Bayfront',
#        'Duxton Hill', 'Boat Quay', 'Orchard', 'Bedok Reservoir',
#        'Bedok North', 'Marine Parade', 'Simei', 'Katong', 'Tampines',
#        'Pasir Ris', 'Changi', 'Siglap', 'Bedok South', 'Joo Chiat',
#        'Telok Kurau', 'Kembangan', 'Kallang', 'Punggol', 'Tanjong Rhu',
#        'Mountbatten', 'Dhoby Ghaut', 'Boon Lay', 'Tuas', 'Lim Chu Kang',
#        'Ulu Pandan', 'Bukit Batok', 'Woodlands', 'Jurong', 'West Coast',
#        'Upper Bukit Timah', 'Choa Chu Kang', 'Clementi', 'Ghim Moh',
#        'Bukit Panjang', 'Buangkok', '$$$$', 'Holland Village',
#        'Robertson Quay', 'Sembawang', 'Sixth Avenue', 'Pulau Ubin',
#        'Somerset', 'Keppel', 'Outram', 'Paya Lebar'], dtype=object)

# %%
# There are some locations indicated as '$'. These values are replaced as null

# get index of row with "$" in category column
dollar_index = rest_df[(rest_df['location']=='$')
                       | (rest_df['location']=='$$') 
                       | (rest_df['location']=='$$$') 
                       | (rest_df['location']=='$$$$')].index

for i in dollar_index:
    rest_df.loc[i, 'location'] = np.nan

# %% [markdown]
# **`category`** <br>
# The null values will be imputed using on K-Nearest Neighbour based on latitude and longitude after merging with Restaurant Reviews dataframe.

# %%
# Display null values for category.
rest_df[rest_df['category'].isnull()]
# Out:
#         neighbourhood                    name  \
# 239         Alexandra            Washoku Goen
# 2434            Bugis  Ciao Italian Risto Bar
# 3264    Choa Chu Kang            73 Hillcrest
# 4972     Harbourfront          Modesto’s Vivo
# 10462  Robertson Quay                Damotory
#
#                                                     href  \
# 239    www.yelp.com/biz/washoku-goen-singapore?osq=Re...
# 2434   www.yelp.com/biz/ciao-italian-risto-bar-singap...
# 3264   www.yelp.com/biz/73-hillcrest-singapore?osq=Re...
# 4972   www.yelp.com/biz/modestos-vivo-singapore?osq=R...
# 10462  www.yelp.com/biz/damotory-singapore?osq=Restau...
#
#                                                      img  star_rating  \
# 239    https://s3-media0.fl.yelpcdn.com/bphoto/L01z3Z...          4.0
# 2434   https://s3-media0.fl.yelpcdn.com/bphoto/BnsHdw...          4.0
# 3264   https://s3-media0.fl.yelpcdn.com/bphoto/dPkpfY...          3.0
# 4972   https://s3-media0.fl.yelpcdn.com/bphoto/Ivkm5Q...          3.0
# 10462  https://s3-media0.fl.yelpcdn.com/bphoto/7yKb5n...          2.5
#
#        review_count        location category  price_range
# 239               2    Harbourfront      NaN          NaN
# 2434              5     Arab Street      NaN          NaN
# 3264              2     Bukit Timah      NaN          NaN
# 4972              7    Harbourfront      NaN          2.0
# 10462             3  Robertson Quay      NaN          NaN

# %%
# Verify restaurant website and impute the value manually. 

# print website of individual restaurant. 
for i in range(len(rest_df[rest_df['category'].isnull()])):
    print(rest_df[rest_df['category'].isnull()].iloc[i]['href'])
# Out:
# www.yelp.com/biz/washoku-goen-singapore?osq=Restaurants
# www.yelp.com/biz/ciao-italian-risto-bar-singapore?osq=Restaurants
# www.yelp.com/biz/73-hillcrest-singapore?osq=Restaurants
# www.yelp.com/biz/modestos-vivo-singapore?osq=Restaurants
# www.yelp.com/biz/damotory-singapore?osq=Restaurants

# %%
# impute catgory for the various restaurants.
rest_df.loc[239, 'category'] = "['Japanese']"
rest_df.loc[2434, 'category'] = "['Italian']"
rest_df.loc[3264, 'category'] = "['American (Traditional)', 'Bistros', 'Breakfast & Brunch']"
rest_df.loc[4972, 'category'] = "['Italian']"
rest_df.loc[10462, 'category'] = "['Korean']"

# %% [markdown]
# **`price_range`** <br>
# The null values in this column means that the restaurant do not have price range information. Null values will be imputed as '0' to indicate not available.

# %%
rest_df['price_range'].value_counts()
# Out:
# 2.0    849
# 1.0    691
# 3.0    304
# 4.0    167
# Name: price_range, dtype: int64

# %%
# Impute null values as 0 represent 'not available'
rest_df['price_range'].fillna(0, inplace=True)

# %%
# verify all null values for category and price_range are imputed. 
rest_df.isnull().sum()
# Out:
# neighbourhood      0
# name               0
# href               0
# img                0
# star_rating        0
# review_count       0
# location         161
# category           0
# price_range        0
# dtype: int64

# %% [markdown]
# #### Data Processing

# %% [markdown]
# **`category`** <br>
# Extract catergories of the restaurants and create columns for each category.

# %%
# Display first 3 rows of dataframe
rest_df.head(3)
# Out:
#   neighbourhood               name  \
# 0     Alexandra     The Naked Finn
# 1     Alexandra  Soi Thai Soi Nice
# 2     Alexandra           The Gogi
#
#                                                 href  \
# 0  www.yelp.com/biz/the-naked-finn-singapore?osq=...
# 1  www.yelp.com/biz/soi-thai-soi-nice-singapore?o...
# 2  www.yelp.com/biz/the-gogi-singapore?osq=Restau...
#
#                                                  img  star_rating  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
#
#    review_count   location                category  price_range
# 0            19  Alexandra             ['Seafood']          3.0
# 1             2  Alexandra                ['Thai']          0.0
# 2             1  Alexandra  ['Korean', 'Barbeque']          0.0

# %%
# get a set of all the categories
# Remove "[", "]", "'" from column values
rest_df['category'] = rest_df['category'].str.strip('[]').str.replace("'", "")

# Instantiate a categories set
categories_set = set()

# Loop to gather a set of categories
for row in rest_df['category']:
    row = row.split(', ')
    
    # add category to categories set if not in set
    for category in row:
        if category not in categories_set:
            categories_set.add(category)

print(f'Number of categories: {len(categories_set)}')
categories_set
# Out:
# Number of categories: 176
# {'"Womens Clothing"',
#  'Acai Bowls',
#  'Afghan',
#  'African',
#  'American (Traditional)',
#  'Antiques',
#  'Arts & Entertainment',
#  'Asian Fusion',
#  'Australian',
#  'Austrian',
#  'Bagels',
#  'Bakeries',
#  'Barbeque',
#  'Bars',
#  'Beach Bars',
#  'Beer',
#  'Beer Bar',
#  'Belgian',
#  'Bikes',
#  'Bistros',
#  'Brasseries',
#  'Brazilian',
#  'Breakfast & Brunch',
#  'Breweries',
#  'British',
#  'Bubble Tea',
#  'Buffets',
#  'Burgers',
#  'Burmese',
#  'Cafes',
#  'Cambodian',
#  'Cantonese',
#  'Caribbean',
#  'Caterers',
#  'Chicken Shop',
#  'Chicken Wings',
#  'Chinese',
#  'Cocktail Bars',
#  'Coffee & Tea',
#  'Coffee Roasteries',
#  'Congee',
#  'Convenience Stores',
#  'Conveyor Belt Sushi',
#  'Creperies',
#  'Cupcakes',
#  'Dance Clubs',
#  'Delicatessen',
#  'Delis',
#  'Desserts',
#  'Dim Sum',
#  'Diners',
#  'Do-It-Yourself Food',
#  'Dumplings',
#  'Falafel',
#  'Farmers Market',
#  'Fast Food',
#  'Filipino',
#  'Fish & Chips',
#  'Food',
#  'Food Court',
#  'Food Delivery Services',
#  'Food Stands',
#  'French',
#  'Fuzhou',
#  'Gastropubs',
#  'Gay Bars',
#  'Gelato',
#  'German',
#  'Gluten-Free',
#  'Greek',
#  'Grocery',
#  'Hainan',
#  'Hakka',
#  'Halal',
#  'Hawaiian',
#  'Hawker Centre',
#  'Health Markets',
#  'Henghwa',
#  'Himalayan/Nepalese',
#  'Hokkien',
#  'Home Decor',
#  'Hot Dogs',
#  'Hot Pot',
#  'Ice Cream & Frozen Yogurt',
#  'Imported Food',
#  'Indian',
#  'Indonesian',
#  'International',
#  'Irish',
#  'Irish Pub',
#  'Italian',
#  'Izakaya',
#  'Japanese',
#  'Japanese Curry',
#  'Juice Bars & Smoothies',
#  'Karaoke',
#  'Kebab',
#  'Kitchen & Bath',
#  'Kopitiam',
#  'Korean',
#  'Latin American',
#  'Lebanese',
#  'Live/Raw Food',
#  'Local Flavor',
#  'Lounges',
#  'Malaysian',
#  'Meat Shops',
#  'Mediterranean',
#  'Mexican',
#  'Middle Eastern',
#  'Modern European',
#  'Mongolian',
#  'Moroccan',
#  'Music Venues',
#  'Nasi Lemak',
#  'Noodles',
#  'Organic Stores',
#  'Pakistani',
#  'Pancakes',
#  'Party & Event Planning',
#  'Pasta Shops',
#  'Patisserie/Cake Shop',
#  'Pekinese',
#  'Persian/Iranian',
#  'Pet Adoption',
#  'Pets',
#  'Pizza',
#  'Playgrounds',
#  'Poke',
#  'Pop-Up Restaurants',
#  'Portuguese',
#  'Pubs',
#  'Ramen',
#  'Restaurants',
#  'Russian',
#  'Salad',
#  'Sandwiches',
#  'Scandinavian',
#  'Seafood',
#  'Seafood Markets',
#  'Shanghainese',
#  'Shopping',
#  'Shopping Centers',
#  'Singaporean',
#  'Smokehouse',
#  'Social Clubs',
#  'Soup',
#  'Spanish',
#  'Specialty Food',
#  'Sports Bars',
#  'Sri Lankan',
#  'Steakhouses',
#  'Street Vendors',
#  'Sushi Bars',
#  'Szechuan',
#  'Taiwanese',
#  'Tapas/Small Plates',
#  'Tea Rooms',
#  'Tempura',
#  'Teochew',
#  'Teppanyaki',
#  'Tex-Mex',
#  'Thai',
#  'Themed Cafes',
#  'Tonkatsu',
#  'Turkish',
#  'Vegan',
#  'Vegetarian',
#  'Venues & Event Spaces',
#  'Vietnamese',
#  'Waffles',
#  'Whiskey Bars',
#  'Wine & Spirits',
#  'Wine Bars',
#  'Yakiniku',
#  'Yakitori'}

# %%
# display rows with 'Womens Clothing'
rest_df[rest_df['category'].str.contains('Womens Clothing')]
# Out:
#      neighbourhood   name                                              href  \
# 1733     Boat Quay  Tossz  www.yelp.com/biz/tossz-singapore?osq=Restaurants
#
#                                                     img  star_rating  \
# 1733  https://s3-media0.fl.yelpcdn.com/bphoto/e6ZsbX...          3.0
#
#       review_count   location                            category  price_range
# 1733             1  Chinatown  Desserts, "Womens Clothing", Cafes          0.0

# %%
# remove 'Womens Clothing' from set
categories_set.remove('"Womens Clothing"')

# %% [markdown]
# There is a category called 'Womens Clothing' which does not seem to be related to food. It is removed from the categories set.

# %%
# Create a dataframe of columns for each category.
cat_col = [f'category_{category}' for category in categories_set]
cat_df = pd.DataFrame(columns = cat_col)

# %%
# add cat_df to rest_df
rest_df = pd.concat([rest_df, cat_df])

# %%
# update count in category
for category in categories_set:
    rest_df[f'category_{category}'] = rest_df['category'].apply(lambda value: 1 if category in value.split(', ') else 0)

# %%
# Drop `category` columns
rest_df.drop(columns='category', inplace=True)

# %% [markdown]
# **`review_count`**
# As reviews were scrapped for the various restaurants, the column is no longer required and will be dropped.

# %%
# Drop 'review_count' column.
rest_df.drop(columns='review_count', inplace=True)

# %% [markdown]
# ### Restaurant Reviews

# %% [markdown]
# Datatypes for dataframe need to be corrected for `postal_code` and `review_date`.

# %%
# Display data types
reviews_df.dtypes
# Out:
# rest_name         object
# href              object
# address           object
# postal_code       object
# latitude         float64
# longitude        float64
# opening           object
# username          object
# userid            object
# user_location     object
# user_rating        int64
# review_date       object
# comment           object
# dtype: object

# %% [markdown]
# **`review_date`** <br>
# Convert to datetime

# %%
reviews_df['review_date'] = pd.to_datetime(reviews_df['review_date'])

# %% [markdown]
# **`postal_code`** <br>
# Convert to string

# %%
# Check the value type in postal_code columnb
value_type = set()

for i in reviews_df.index:
    value_type.add(type(reviews_df.loc[i, 'postal_code']))
    
value_type
# Out:
# {float, int, str}

# %%
# Display unique values in column
reviews_df['postal_code'].value_counts()
# Out:
# 58416.0     676
# 69120       488
# 179103      324
# 58282       283
# 18971       281
#            ...
# 579522.0      1
# 310093.0      1
# 560128.0      1
# 270043        1
# 787111        1
# Name: postal_code, Length: 2432, dtype: int64

# %%
# Convert various datatype to str
for i in reviews_df[reviews_df['postal_code'].notnull()].index:    
    
    # Convert float and int value to string
    if type(reviews_df.loc[i, 'postal_code']) != str:
        reviews_df.loc[i, 'postal_code'] = str(int(reviews_df.loc[i, 'postal_code'])).zfill(6)
        
    else:
        reviews_df.loc[i, 'postal_code'] = reviews_df.loc[i, 'postal_code'].zfill(6)

# %%
# Display unique values in column
reviews_df['postal_code'].value_counts()
# Out:
# 058416    676
# 069120    489
# 179103    378
# 018971    304
# 058282    283
#          ...
# 440061      1
# 138567      1
# 521114      1
# 458225      1
# 787111      1
# Name: postal_code, Length: 2154, dtype: int64

# %% [markdown]
# #### Remove Duplicates
# There are many duplicates restaurants because reviews are re-scraped for the restaurant when there were interruptions in the server. As pre-saved data were not overwritten, many duplicates exist.

# %%
# Check for duplicated rows
reviews_df.duplicated().value_counts()
# Out:
# False    25569
# True      2559
# dtype: int64

# %%
# Drop duplicates.
reviews_df = reviews_df.drop_duplicates()

# %%
# Check number of reviews scrapped
reviews_df.shape
# Out:
# (25569, 13)

# %% [markdown]
# #### Check null values

# %%
# display summary of null values. 
reviews_df.isnull().sum()
# Out:
# rest_name          0
# href               0
# address            0
# postal_code       31
# latitude         251
# longitude        251
# opening            0
# username           0
# userid             0
# user_location      0
# user_rating        0
# review_date        0
# comment            0
# dtype: int64

# %% [markdown]
# **`user_location`**

# %%
# Display null value in user_location
reviews_df[reviews_df['user_location'].isnull()]
# Out:
#            rest_name                                               href  \
# 24329  The Sushi Bar  http://www.yelp.com/biz/the-sushi-bar-singapor...
#
#                                                  address postal_code  \
# 24329  391B Orchard Rd #05-34/35 Singapore 238874 Sin...      238874
#
#        latitude   longitude  \
# 24329  1.302424  103.834676
#
#                                                  opening      username  \
# 24329  [('Mon', ['11:30 AM - 9:00 PM']), ('Tue', ['11...  Annalissa M.
#
#                        userid user_location  user_rating review_date  \
# 24329  Mle-QxmQGvU_cI1Yhmq82w           NaN            5  2019-05-08
#
#                                                  comment
# 24329  The fish are fresh and love the food! Will def...

# %%
# Impute user_location as 'Not Available'
reviews_df.loc[24329, 'user_location'] = 'NotAvailable'

# %% [markdown]
# **`postal_code`**

# %%
# Display null values in postal_code column
null_postal_df = reviews_df[reviews_df['postal_code'].isnull()]
print(null_postal_df.shape)

# Display first 5 rows and last 5 rows of dataframe
null_postal_df
# Out:
# (95, 13)
#                               rest_name  \
# 3090                          Hamjipark
# 4882            Teochew Fishball Noodle
# 8958   Chir Chir Fusion Chicken Factory
# 9023                           Aji-ichi
# 9024                           Aji-ichi
# ...                                 ...
# 28118                Flower In A Window
# 28119                Flower In A Window
# 28120                       Souper Tang
# 28121                       Souper Tang
# 28122                           BE Cafe
#
#                                                     href  \
# 3090   http://www.yelp.com/biz/hamjipark-singapore?os...
# 4882   http://www.yelp.com/biz/teochew-fishball-noodl...
# 8958   http://www.yelp.com/biz/chir-chir-fusion-chick...
# 9023   http://www.yelp.com/biz/aji-ichi-singapore?osq...
# 9024   http://www.yelp.com/biz/aji-ichi-singapore?osq...
# ...                                                  ...
# 28118  http://www.yelp.com/biz/flower-in-a-window-joh...
# 28119  http://www.yelp.com/biz/flower-in-a-window-joh...
# 28120  http://www.yelp.com/biz/souper-tang-johor-bahr...
# 28121  http://www.yelp.com/biz/souper-tang-johor-bahr...
# 28122  http://www.yelp.com/biz/be-cafe-johor-bahru?os...
#
#                                                  address postal_code  \
# 3090    AmoyStreet 76 Tanjong Pagar Singapore Singapore          NaN
# 4882   Block 462 01-29 Wiseng Food Place Crawford Roa...         NaN
# 8958   799 Upper Changi Rd #02-05/06 Bedok Point Sing...         NaN
# 9023            4 Stadium Pl #02-01 Singapore Singapore          NaN
# 9024            4 Stadium Pl #02-01 Singapore Singapore          NaN
# ...                                                  ...         ...
# 28118   9 Jalan Dhoby 80000 Johor Bahru, Johor Malaysia          NaN
# 28119   9 Jalan Dhoby 80000 Johor Bahru, Johor Malaysia          NaN
# 28120  106 Jalan Wong Ah Fook J4-21, Level 04, City S...         NaN
# 28121  106 Jalan Wong Ah Fook J4-21, Level 04, City S...         NaN
# 28122  2, Jalan Molek 1/5C Taman Molek 81100 Johor Ba...         NaN
#
#        latitude  longitude                                            opening  \
# 3090        NaN        NaN                                                 []
# 4882        NaN        NaN                                                 []
# 8958        NaN        NaN                                                 []
# 9023        NaN        NaN                                                 []
# 9024        NaN        NaN                                                 []
# ...         ...        ...                                                ...
# 28118       NaN        NaN                                                 []
# 28119       NaN        NaN                                                 []
# 28120       NaN        NaN                                                 []
# 28121       NaN        NaN                                                 []
# 28122       NaN        NaN  [('Mon', ['8:00 AM - 11:30 PM']), ('Tue', ['8:...
#
#           username                  userid                    user_location  \
# 3090      Geert B.  BLCH29-jOurbrj1fsaQ3Hw             Singapore, Singapore
# 4882       Fern O.  wuRI6NhRB6cUWERRmcvOMQ  Bencoolen, Singapore, Singapore
# 8958       Jeff R.  F7wbhRy06EsULmGPLWbpvg                   The Colony, TX
# 9023     Edward T.  f_oXKDPalvG6gSqvyU3y1A             Singapore, Singapore
# 9024   Charlynn K.  ZNyfGsIwsedPlpjmoaq3Eg             Singapore, Singapore
# ...            ...                     ...                              ...
# 28118  Eminence P.  ksr6BWqyeEPQ24I5AqBQzw                    Ann Arbor, MI
# 28119    Ashley L.  Bp0wwAcjV35mUqcFB2WDZg       San Francisco Bay Area, CA
# 28120    Daniel L.  l9emn2tKkrtUV9Yx8l122g            Johor Bahru, Malaysia
# 28121    Doreen T.  2F38Uc4UNNbFVdyUUnBjOA             Singapore, Singapore
# 28122   Sin Yee Y.  noX-iU_Heolu0u_KsDAMTg           Kuala Lumpur, Malaysia
#
#        user_rating review_date  \
# 3090             3  2010-06-06
# 4882             4  2013-12-07
# 8958             5  2016-11-08
# 9023             5  2018-11-06
# 9024             4  2018-08-12
# ...            ...         ...
# 28118            4  2016-05-27
# 28119            3  2018-09-22
# 28120            2  2017-06-28
# 28121            2  2016-08-21
# 28122            3  2015-08-29
#
#                                                  comment
# 3090   I've only been here for lunch, but when you st...
# 4882   Look at the picture. The lard tells you all yo...
# 8958   Delicious fried chicken and rosemary chicken! ...
# 9023   Excellent value with the Salmon Fish Head soup...
# 9024   I never knew they had this Japanese outlet her...
# ...                                                  ...
# 28118  Specialty teas and cakes, a very chill and coo...
# 28119  It's Flowers In The Window.Quaint little café ...
# 28120  Changes in the menu for the past few years for...
# 28121  The outlet was part of a rather well chain in ...
# 28122  B.E Cafe is spacious. The cosy ambiance is def...
#
# [95 rows x 13 columns]

# %%
# Remove restaurants in malaysia. 
msia_index = null_postal_df[null_postal_df['address'].str.contains('Malaysia')].index
reviews_df.drop(index=msia_index, inplace=True)
null_postal_df.drop(index=msia_index, inplace=True)

# %%
# Display address columns
# Address will be modified to be processed by geocode later.  
for i in null_postal_df.index:
    print(i, null_postal_df.loc[i, 'address'])
# Out:
# 3090 AmoyStreet 76 Tanjong Pagar Singapore Singapore
# 4882 Block 462 01-29 Wiseng Food Place Crawford Road Singapore Singapore
# 8958 799 Upper Changi Rd #02-05/06 Bedok Point Singapore Singapore
# 9023 4 Stadium Pl #02-01 Singapore Singapore
# 9024 4 Stadium Pl #02-01 Singapore Singapore
# 9025 4 Stadium Pl #02-01 Singapore Singapore
# 10209 Blk 51 Lorong 5 Toa Payoh #01-60 Toa Payoh, Singapore Singapore
# 10210 Blk 51 Lorong 5 Toa Payoh #01-60 Toa Payoh, Singapore Singapore
# 10211 Blk 51 Lorong 5 Toa Payoh #01-60 Toa Payoh, Singapore Singapore
# 11021 B1 One Raffles Place Singapore Singapore
# 12107 Blk 721 Clementi West St 2 Singapore Singapore
# 12108 Blk 721 Clementi West St 2 Singapore Singapore
# 12111 325 Clementi Avenue 2 Clementi, Singapore Singapore
# 13511 #04-06 Westgate Mall 3 Gateway Drive Singapore Singapore
# 13957 01-37 Bukit Panjang Plz Singapore Singapore
# 13958 01-37 Bukit Panjang Plz Singapore Singapore
# 14710 6 Changi Business Park Ave 2 #01-21 Tampines, Singapore Singapore
# 14711 6 Changi Business Park Ave 2 #01-21 Tampines, Singapore Singapore
# 14712 6 Changi Business Park Ave 2 #01-21 Tampines, Singapore Singapore
# 14713 6 Changi Business Park Ave 2 #01-21 Tampines, Singapore Singapore
# 15807 Blk 345 Jurong East Avenue 1 #01-225 Singapore Singapore
# 15808 Blk 345 Jurong East Avenue 1 #01-225 Singapore Singapore
# 19258 Suite 02-48, Chinatown Complex Market 335 Smith St Fitzroy Victoria 3065 Australia
# 19259 Suite 02-48, Chinatown Complex Market 335 Smith St Fitzroy Victoria 3065 Australia
# 19260 Suite 02-48, Chinatown Complex Market 335 Smith St Fitzroy Victoria 3065 Australia
# 21211 33 Seng Kang West Ave #B2-05/06 The Seletar Mall Singapore Singapore
# 21283 1 Farleigh Avenue Singapore Singapore
# 21284 1 Farleigh Avenue Singapore Singapore
# 24425 Exter Rd Singapore Singapore
# 26537 Serangoon Nex Shopping Centre # B1-73 Singapore Singapore
# 27793 Blk 4, Jalan Bukit Ho Swee #01-162 Singapore Singapore

# %%
# Create alt_add column to be input into geocode to extract info. 
null_postal_df['alt_add'] = np.nan

for i in null_postal_df.index:
    
    try:
        # Remove unit number from address
        null_postal_df.loc[i, 'alt_add'] = re.sub('(\d+)-', '-', null_postal_df.loc[i, 'address'])
        null_postal_df.loc[i, 'alt_add'] = re.sub('-\d+', '', null_postal_df.loc[i, 'alt_add'])
        null_postal_df.loc[i, 'alt_add'] = null_postal_df.loc[i, 'alt_add'].replace('#', '')
        null_postal_df.loc[i, 'alt_add'] = re.sub('/\d+', '', null_postal_df.loc[i, 'alt_add'])
    except:
        continue
        
    null_postal_df.loc[i, 'alt_add'] = null_postal_df.loc[i, 'alt_add'].replace('Singapore', '', 1)

# Remove AmoyStreet in alt_add for index 3090
null_postal_df.loc[3090, 'alt_add'] = '76 Amoy Street Tanjong Pagar Singapore'

# Simplify address for Wiseng Food Place for index 4882 
null_postal_df.loc[4882, 'alt_add'] = 'Block 462 Crawford Road Singapore'

# Remove duplicated 'Toa Payoh' for index 10209 , 10209 , 10209
null_postal_df.loc[[10209 , 10209 , 10209], 'alt_add'] = 'Blk 51 Lorong 5 Toa Payoh Singapore'

# remove B1 for index 11021 
null_postal_df.loc[11021, 'alt_add'] = null_postal_df.loc[11021, 'alt_add'].replace('B1 ', '')

# remove Westgate mall for index 13511 
null_postal_df.loc[13511, 'alt_add'] = null_postal_df.loc[13511, 'alt_add'].replace('Westgate Mall ', '')

# Correct address for chinatown complex for index 19258, 19259, 19260 
null_postal_df.loc[[19258, 19259, 19260], 'alt_add'] = '335 Smith St Singapore'

# Simplify address for seletar mall for index 21211 
null_postal_df.loc[21211, 'alt_add'] = '33 Seng Kang West Ave Singapore'

# %%
# Impute latitude and longitude

# create a Nominatim object
locator = Nominatim(user_agent='myGeocoder')

# function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# %%
# create add_loc column
null_postal_df['add_loc'] = null_postal_df['alt_add'].apply(geocode)

# Verify add_loc generated. 
null_postal_df[['rest_name','address','alt_add', 'add_loc']]

# %%
# Some of the add_loc are not accurate. 
# their add_loc will be imputed manually. 

null_postal_df.loc[4882, 'add_loc'] = '462 Crawford Ln, Singapore 190462'
null_postal_df.loc[8958, 'add_loc'] = '799 New Upper Changi Rd, Singapore 467351'
null_postal_df.loc[[10209, 10210, 10211], 'add_loc'] = '51 Lor. 5 Toa Payoh, Singapore 310051'
null_postal_df.loc[[12107, 12108], 'add_loc'] = '721 Clementi West Street 2, Singapore 120721'
null_postal_df.loc[12111, 'add_loc'] = '325 Clementi Ave 5, Singapore 120325'
null_postal_df.loc[[14710,14711, 14712, 14713], 'add_loc'] = '6 Changi Business Park Ave 1, Singapore 486017'
null_postal_df.loc[[15807, 15808], 'add_loc'] = '345 Jurong East Street 31, Singapore 600345'
null_postal_df.loc[[21283, 21284], 'add_loc'] = '3 Farleigh Avenue Singapore 557796'
null_postal_df.loc[24425, 'add_loc'] = '31C Exeter Rd, Singapore 239734'
null_postal_df.loc[26537, 'add_loc'] = '23 Serangoon Central, Singapore 556083'
null_postal_df.loc[27793, 'add_loc'] = '4 Jln Bukit Ho Swee, Singapore 162004'

# %%
# Loop to extract postal_code and input latitude and longitude
for i in null_postal_df.index:
    add1 = str(null_postal_df.loc[i, 'add_loc'])
    postal_code = re.search('\d{6}', str(null_postal_df.loc[i, 'add_loc'])).group()
    
    try:
        null_postal_df.loc[i, 'postal_code'] = postal_code
        onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={postal_code}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
        null_postal_df.loc[i, 'latitude'] = json.loads(onemap.p.text)['results'][0]['LATITUDE']
        null_postal_df.loc[i, 'longitude'] = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']
        
    except:
        continue

# %%
# Verify input.
null_postal_df
# Out:
#                                     rest_name  \
# 3090                                Hamjipark
# 4882                  Teochew Fishball Noodle
# 8958         Chir Chir Fusion Chicken Factory
# 9023                                 Aji-ichi
# 9024                                 Aji-ichi
# 9025                                 Aji-ichi
# 10209                          Uno Beef House
# 10210                          Uno Beef House
# 10211                          Uno Beef House
# 11021                          Paris Baguette
# 12107  Clementi West Street 2 XO Fish Beehoon
# 12108  Clementi West Street 2 XO Fish Beehoon
# 12111                           Aston Express
# 13511                      Tonkatsu Ma Maison
# 13957                           Ichiban Sushi
# 13958                           Ichiban Sushi
# 14710   Mikawa Japanese Sake Bar & Restaurant
# 14711   Mikawa Japanese Sake Bar & Restaurant
# 14712   Mikawa Japanese Sake Bar & Restaurant
# 14713   Mikawa Japanese Sake Bar & Restaurant
# 15807                            Pho Lee Hung
# 15808                            Pho Lee Hung
# 19258                         Wu Shi Nian Dai
# 19259                         Wu Shi Nian Dai
# 19260                         Wu Shi Nian Dai
# 21211                               Let’s Eat
# 21283            Poh Poh Roasted Chicken Rice
# 21284            Poh Poh Roasted Chicken Rice
# 24425               Singtel Comcentre Canteen
# 26537                      AOne Claypot House
# 27793                                 Le Halo
#
#                                                     href  \
# 3090   http://www.yelp.com/biz/hamjipark-singapore?os...
# 4882   http://www.yelp.com/biz/teochew-fishball-noodl...
# 8958   http://www.yelp.com/biz/chir-chir-fusion-chick...
# 9023   http://www.yelp.com/biz/aji-ichi-singapore?osq...
# 9024   http://www.yelp.com/biz/aji-ichi-singapore?osq...
# 9025   http://www.yelp.com/biz/aji-ichi-singapore?osq...
# 10209  http://www.yelp.com/biz/uno-beef-house-no-titl...
# 10210  http://www.yelp.com/biz/uno-beef-house-no-titl...
# 10211  http://www.yelp.com/biz/uno-beef-house-no-titl...
# 11021  http://www.yelp.com/biz/paris-baguette-singapo...
# 12107  http://www.yelp.com/biz/clementi-west-street-2...
# 12108  http://www.yelp.com/biz/clementi-west-street-2...
# 12111  http://www.yelp.com/biz/aston-express-no-title...
# 13511  http://www.yelp.com/biz/tonkatsu-ma-maison-sin...
# 13957  http://www.yelp.com/biz/ichiban-sushi-singapor...
# 13958  http://www.yelp.com/biz/ichiban-sushi-singapor...
# 14710  http://www.yelp.com/biz/mikawa-japanese-sake-b...
# 14711  http://www.yelp.com/biz/mikawa-japanese-sake-b...
# 14712  http://www.yelp.com/biz/mikawa-japanese-sake-b...
# 14713  http://www.yelp.com/biz/mikawa-japanese-sake-b...
# 15807  http://www.yelp.com/biz/pho-lee-hung-singapore...
# 15808  http://www.yelp.com/biz/pho-lee-hung-singapore...
# 19258  http://www.yelp.com/biz/wu-shi-nian-dai-fitzro...
# 19259  http://www.yelp.com/biz/wu-shi-nian-dai-fitzro...
# 19260  http://www.yelp.com/biz/wu-shi-nian-dai-fitzro...
# 21211  http://www.yelp.com/biz/lets-eat-singapore-3?o...
# 21283  http://www.yelp.com/biz/poh-poh-roasted-chicke...
# 21284  http://www.yelp.com/biz/poh-poh-roasted-chicke...
# 24425  http://www.yelp.com/biz/singtel-comcentre-cant...
# 26537  http://www.yelp.com/biz/aone-claypot-house-sin...
# 27793  http://www.yelp.com/biz/le-halo-singapore?osq=...
#
#                                                  address postal_code  \
# 3090    AmoyStreet 76 Tanjong Pagar Singapore Singapore       069895
# 4882   Block 462 01-29 Wiseng Food Place Crawford Roa...      190462
# 8958   799 Upper Changi Rd #02-05/06 Bedok Point Sing...      467351
# 9023            4 Stadium Pl #02-01 Singapore Singapore       397628
# 9024            4 Stadium Pl #02-01 Singapore Singapore       397628
# 9025            4 Stadium Pl #02-01 Singapore Singapore       397628
# 10209  Blk 51 Lorong 5 Toa Payoh #01-60 Toa Payoh, Si...      310051
# 10210  Blk 51 Lorong 5 Toa Payoh #01-60 Toa Payoh, Si...      310051
# 10211  Blk 51 Lorong 5 Toa Payoh #01-60 Toa Payoh, Si...      310051
# 11021          B1 One Raffles Place Singapore Singapore       048616
# 12107    Blk 721 Clementi West St 2 Singapore Singapore       120721
# 12108    Blk 721 Clementi West St 2 Singapore Singapore       120721
# 12111  325 Clementi Avenue 2 Clementi, Singapore Sing...      120325
# 13511  #04-06 Westgate Mall 3 Gateway Drive Singapore...      608532
# 13957       01-37 Bukit Panjang Plz Singapore Singapore       677743
# 13958       01-37 Bukit Panjang Plz Singapore Singapore       677743
# 14710  6 Changi Business Park Ave 2 #01-21 Tampines, ...      486017
# 14711  6 Changi Business Park Ave 2 #01-21 Tampines, ...      486017
# 14712  6 Changi Business Park Ave 2 #01-21 Tampines, ...      486017
# 14713  6 Changi Business Park Ave 2 #01-21 Tampines, ...      486017
# 15807  Blk 345 Jurong East Avenue 1 #01-225 Singapore...      600345
# 15808  Blk 345 Jurong East Avenue 1 #01-225 Singapore...      600345
# 19258  Suite 02-48, Chinatown Complex Market 335 Smit...      052335
# 19259  Suite 02-48, Chinatown Complex Market 335 Smit...      052335
# 19260  Suite 02-48, Chinatown Complex Market 335 Smit...      052335
# 21211  33 Seng Kang West Ave #B2-05/06 The Seletar Ma...      797653
# 21283             1 Farleigh Avenue Singapore Singapore       557796
# 21284             1 Farleigh Avenue Singapore Singapore       557796
# 24425                      Exter Rd Singapore Singapore       239734
# 26537  Serangoon Nex Shopping Centre # B1-73 Singapor...      556083
# 27793  Blk 4, Jalan Bukit Ho Swee #01-162 Singapore S...      162004
#
#                latitude         longitude  \
# 3090   1.28048638504217  103.846617752784
# 4882   1.30458618029941  103.860840750826
# 8958           1.324972        103.932442
# 9023   1.30307515150401  103.873149707591
# 9024   1.30307515150401  103.873149707591
# 9025   1.30307515150401  103.873149707591
# 10209  1.33778337648439  103.852507455855
# 10210  1.33778337648439  103.852507455855
# 10211  1.33778337648439  103.852507455855
# 11021  1.28434954622306  103.851072545834
# 12107   1.3024252487869   103.76435385686
# 12108   1.3024252487869   103.76435385686
# 12111    1.315096685325  103.766817400667
# 13511  1.33415752008876  103.742766489597
# 13957  1.37989494369864  103.764459887796
# 13958  1.37989494369864  103.764459887796
# 14710  1.33535677709911  103.963892243026
# 14711  1.33535677709911  103.963892243026
# 14712  1.33535677709911  103.963892243026
# 14713  1.33535677709911  103.963892243026
# 15807  1.34551210586752   103.73121914575
# 15808  1.34551210586752   103.73121914575
# 19258  1.28236449613222  103.843448181669
# 19259  1.28236449613222  103.843448181669
# 19260  1.28236449613222  103.843448181669
# 21211  1.39131549124709  103.876213231014
# 21283  1.36446029733043   103.86540061509
# 21284  1.36446029733043   103.86540061509
# 24425  1.29859523339043   103.83823047574
# 26537  1.35064579494756  103.872590477492
# 27793  1.28742239926051  103.831238878232
#
#                                                  opening     username  \
# 3090                                                  []     Geert B.
# 4882                                                  []      Fern O.
# 8958                                                  []      Jeff R.
# 9023                                                  []    Edward T.
# 9024                                                  []  Charlynn K.
# 9025                                                  []    Doreen T.
# 10209                                                 []     Danny T.
# 10210                                                 []      Boon T.
# 10211                                                 []   Jessica G.
# 11021                                                 []        Li T.
# 12107                                                 []   Caspere L.
# 12108                                                 []       Lek W.
# 12111  [('Mon', ['11:00 AM - 10:00 PM']), ('Tue', ['1...  Tze Kiat L.
# 13511  [('Mon', ['11:00 AM - 10:00 PM']), ('Tue', ['1...  Letticia C.
# 13957                                                 []  Fang Wei G.
# 13958                                                 []    Samuel L.
# 14710                                                 []      Kyle S.
# 14711                                                 []     Eddie K.
# 14712                                                 []      Will S.
# 14713                                                 []    Joseph K.
# 15807                                                 []     Chris B.
# 15808                                                 []      Phil P.
# 19258                                                 []   Loretta C.
# 19259                                                 []     Brian S.
# 19260                                                 []   Kenneth H.
# 21211                                                 []       Vin C.
# 21283                                                 []     Dylan C.
# 21284                                                 []      Joey C.
# 24425  [('Mon', ['7:30 AM - 2:30 PM']), ('Tue', ['7:3...   Carolyn L.
# 26537                                                 []  Charlynn K.
# 27793  [('Mon', ['9:00 AM - 6:00 PM']), ('Tue', ['Clo...     Jason L.
#
#                        userid                    user_location  user_rating  \
# 3090   BLCH29-jOurbrj1fsaQ3Hw             Singapore, Singapore            3
# 4882   wuRI6NhRB6cUWERRmcvOMQ  Bencoolen, Singapore, Singapore            4
# 8958   F7wbhRy06EsULmGPLWbpvg                   The Colony, TX            5
# 9023   f_oXKDPalvG6gSqvyU3y1A             Singapore, Singapore            5
# 9024   ZNyfGsIwsedPlpjmoaq3Eg             Singapore, Singapore            4
# 9025   2F38Uc4UNNbFVdyUUnBjOA             Singapore, Singapore            4
# 10209  e9Sn1IZZZ_1Qa_vUdtskjA     Bishan, Singapore, Singapore            5
# 10210  iqPpCHOIN36YtI3Plh7aIw             Singapore, Singapore            4
# 10211  t5XN2Lmv_VeXRSw9YdGf_w             Singapore, Singapore            4
# 11021  dJzKwp5k65MK3R_qn4Xpow             Singapore, Singapore            3
# 12107  BSzE4Vu-yzyTMSJpwZtIBw             Singapore, Singapore            5
# 12108  N6-1lKl1pibMHsjpgv6o2w     Keppel, Singapore, Singapore            3
# 12111  8ZZduZzQWFookRBk6I6tpg   Clementi, Singapore, Singapore            4
# 13511  pu2YKTbOBBy45iL-SqlRRg                  Toronto, Canada            4
# 13957  pDk2mjq7RTpIc6AWIvrbfw             Singapore, Singapore            4
# 13958  uvDgC3dqLYUJvoefGBJM8A             Singapore, Singapore            1
# 14710  bQCTHiz5LpZuDFS5DYl2bw                   New Albany, IN            3
# 14711  BsC-nudtxV0gkG9PhWPfmw             Singapore, Singapore            5
# 14712  0gBy-cIXe0DQKhFjifu68Q                 White Plains, NY            3
# 14713  vy6N0_l9UiFMjBbu3cPQJA                     San Jose, CA            1
# 15807  2vkWfQ-qqxUFBHt_MFItxQ                   Sacramento, CA            5
# 15808  iGfP-QhjwzQKbpc_VoX2tw             Singapore, Singapore            4
# 19258  f_1bRw8RuK-zZAKuUMTqNw                  Los Angeles, CA            5
# 19259  opdbggrufvUGH8gP9wHL8w                  Minneapolis, MN            4
# 19260  XjqF7ABSlI5xF99LaEUcLA                      Arcadia, CA            4
# 21211  HyKRpDAdDn1yLUQFUa5jCQ             Singapore, Singapore            1
# 21283  qmDxX7utwb2tA1tP9ASfAw             Singapore, Singapore            3
# 21284  _gyBH_pVycVOnjikFVXuBQ             Singapore, Singapore            3
# 24425  Q1oMmm7tKPOzA7_gqcV4zg                Vancouver, Canada            4
# 26537  ZNyfGsIwsedPlpjmoaq3Eg             Singapore, Singapore            4
# 27793  oGtf2Wbi2Wq6TTJecDZFMQ             Singapore, Singapore            3
#
#       review_date                                            comment  \
# 3090   2010-06-06  I've only been here for lunch, but when you st...
# 4882   2013-12-07  Look at the picture. The lard tells you all yo...
# 8958   2016-11-08  Delicious fried chicken and rosemary chicken! ...
# 9023   2018-11-06  Excellent value with the Salmon Fish Head soup...
# 9024   2018-08-12  I never knew they had this Japanese outlet her...
# 9025   2016-04-04  The restaurant was located at the second floor...
# 10209  2017-04-27  Love love love this place! Beef cooked to perf...
# 10210  2013-03-18  A decent neighborhood steak place. Black peppe...
# 10211  2014-03-02  My 2nd time here and my daughter and I had:1) ...
# 11021  2015-09-26  Bread is the first thing I think of when it co...
# 12107  2016-05-28  Very consistent flavour, and tastes wonderful....
# 12108  2014-01-09  The fish head bee hoon looks good before eatin...
# 12111  2013-01-07  Aston"s has put a high benchmark for coffee sh...
# 13511  2017-06-15  I don't think I'll ever forget the Tonkatsu I ...
# 13957  2017-06-19  Family-friendly restaurant with a decent varie...
# 13958  2012-09-02  I had lunch here a couple weeks back and it le...
# 14710  2014-04-22  The atmosphere at Mikawa is delightful.  The p...
# 14711  2015-04-12  This Japanese restuarant had been around for o...
# 14712  2015-10-08  This is an okay place. I didn't order anything...
# 14713  2017-07-16  For the past two years, I have been coming To ...
# 15807  2015-03-11  Great Place in Jurong East to get some good Vi...
# 15808  2015-01-02  The majority of the dishes are great here. Esp...
# 19258  2016-11-11  Great place for breakfast!  We got some kaya t...
# 19259  2017-11-16  We stumbled upon this little eatery while look...
# 19260  2017-02-07  This is a short review because its only for co...
# 21211  2015-10-03  Went to tabao in the evening (Seletar Mall Bra...
# 21283  2015-10-21  This place not only serves chicken rice, it ha...
# 21284  2012-11-06  The good:  Chicken Rice, tasty and cheap.  Unl...
# 24425  2015-11-17  A gem "hidden" in Orchard Road area. Well it i...
# 26537  2018-08-12  Simply love the porridge here, especially the ...
# 27793  2014-12-27  Tucked away along the quiet Jalan Bukit Ho Swe...
#
#                                                  alt_add  \
# 3090              76 Amoy Street Tanjong Pagar Singapore
# 4882                   Block 462 Crawford Road Singapore
# 8958        799 Upper Changi Rd  Bedok Point  Singapore
# 9023                           4 Stadium Pl   Singapore
# 9024                           4 Stadium Pl   Singapore
# 9025                           4 Stadium Pl   Singapore
# 10209                Blk 51 Lorong 5 Toa Payoh Singapore
# 10210  Blk 51 Lorong 5 Toa Payoh  Toa Payoh,  Singapore
# 10211  Blk 51 Lorong 5 Toa Payoh  Toa Payoh,  Singapore
# 11021                      One Raffles Place  Singapore
# 12107             Blk 721 Clementi West St 2  Singapore
# 12108             Blk 721 Clementi West St 2  Singapore
# 12111        325 Clementi Avenue 2 Clementi,  Singapore
# 13511                        3 Gateway Drive  Singapore
# 13957                      Bukit Panjang Plz  Singapore
# 13958                      Bukit Panjang Plz  Singapore
# 14710  6 Changi Business Park Ave 2  Tampines,  Singa...
# 14711  6 Changi Business Park Ave 2  Tampines,  Singa...
# 14712  6 Changi Business Park Ave 2  Tampines,  Singa...
# 14713  6 Changi Business Park Ave 2  Tampines,  Singa...
# 15807          Blk 345 Jurong East Avenue 1   Singapore
# 15808          Blk 345 Jurong East Avenue 1   Singapore
# 19258                             335 Smith St Singapore
# 19259                             335 Smith St Singapore
# 19260                             335 Smith St Singapore
# 21211                    33 Seng Kang West Ave Singapore
# 21283                      1 Farleigh Avenue  Singapore
# 21284                      1 Farleigh Avenue  Singapore
# 24425                               Exter Rd  Singapore
# 26537       Serangoon Nex Shopping Centre  B  Singapore
# 27793            Blk 4, Jalan Bukit Ho Swee   Singapore
#
#                                                  add_loc
# 3090   (Go! K - BBQ Korean Restaurant, 76, Amoy Stree...
# 4882                   462 Crawford Ln, Singapore 190462
# 8958           799 New Upper Changi Rd, Singapore 467351
# 9023   (Stadium Place, Kallang, Southeast, 397628, Si...
# 9024   (Stadium Place, Kallang, Southeast, 397628, Si...
# 9025   (Stadium Place, Kallang, Southeast, 397628, Si...
# 10209              51 Lor. 5 Toa Payoh, Singapore 310051
# 10210              51 Lor. 5 Toa Payoh, Singapore 310051
# 10211              51 Lor. 5 Toa Payoh, Singapore 310051
# 11021  (One Raffles Place, 1, Raffles Place, Downtown...
# 12107       721 Clementi West Street 2, Singapore 120721
# 12108       721 Clementi West Street 2, Singapore 120721
# 12111               325 Clementi Ave 5, Singapore 120325
# 13511  (Westgate, 3, Gateway Drive, Jurong East, Sing...
# 13957  (Bukit Panjang Plaza, 1, Jelebu Road, Zhenghua...
# 13958  (Bukit Panjang Plaza, 1, Jelebu Road, Zhenghua...
# 14710     6 Changi Business Park Ave 1, Singapore 486017
# 14711     6 Changi Business Park Ave 1, Singapore 486017
# 14712     6 Changi Business Park Ave 1, Singapore 486017
# 14713     6 Changi Business Park Ave 1, Singapore 486017
# 15807        345 Jurong East Street 31, Singapore 600345
# 15808        345 Jurong East Street 31, Singapore 600345
# 19258  (Chinatown Complex, 335, Smith Street, Chinato...
# 19259  (Chinatown Complex, 335, Smith Street, Chinato...
# 19260  (Chinatown Complex, 335, Smith Street, Chinato...
# 21211  (Xing Hua, 33, Sengkang West Avenue, Fernvale,...
# 21283                 3 Farleigh Avenue Singapore 557796
# 21284                 3 Farleigh Avenue Singapore 557796
# 24425                    31C Exeter Rd, Singapore 239734
# 26537             23 Serangoon Central, Singapore 556083
# 27793              4 Jln Bukit Ho Swee, Singapore 162004

# %%
# manuall y input for index 8958, Chir Chir Fusion Chicken Factory
null_postal_df.loc[8958, 'latitude'] = 1.3249724942178276 
null_postal_df.loc[8958, 'longitude'] = 103.93244161653209

# %%
# input postal_code, latitude and longitude in reviews dataframe.
for i in null_postal_df.index:
    reviews_df.loc[i, 'postal_code'] = null_postal_df.loc[i, 'postal_code']
    reviews_df.loc[i, 'latitude'] = null_postal_df.loc[i, 'latitude']
    reviews_df.loc[i, 'longitude'] = null_postal_df.loc[i, 'longitude']

# %%
# Display summary of null values
reviews_df.isnull().sum()
# Out:
# rest_name          0
# href               0
# address            0
# postal_code        0
# latitude         220
# longitude        220
# opening            0
# username           0
# userid             0
# user_location      0
# user_rating        0
# review_date        0
# comment            0
# dtype: int64

# %% [markdown]
# **`latitude` and `longitude`**

# %%
# Display dataframe with missing latitude and longitude
null_latlong_df = reviews_df[reviews_df['latitude'].isnull()]
null_latlong_df.head(3)
# Out:
#               rest_name                                               href  \
# 183        Chicken Rice  http://www.yelp.com/biz/chicken-rice-singapore...
# 513   Indian Vegetarian  http://www.yelp.com/biz/indian-vegetarian-sing...
# 1205             Korean  http://www.yelp.com/biz/korean-singapore?osq=R...
#
#                                                 address postal_code latitude  \
# 183   Comtech 60 Alexandra Terrace Singapore 118502 ...      118502      NaN
# 513   Comtech 60 Alexandra Terrace Singapore 118502 ...      118502      NaN
# 1205  Comtech 60 Alexandra Terrace Singapore 118502 ...      118502      NaN
#
#      longitude opening  username                  userid  \
# 183        NaN      []  Peter A.  OBFRSw7mTGtKJC89Qcai2w
# 513        NaN      []  Peter A.  OBFRSw7mTGtKJC89Qcai2w
# 1205       NaN      []  Peter A.  OBFRSw7mTGtKJC89Qcai2w
#
#              user_location  user_rating review_date  \
# 183   Singapore, Singapore            4  2012-09-07
# 513   Singapore, Singapore            3  2012-09-07
# 1205  Singapore, Singapore            3  2012-09-07
#
#                                                 comment
# 183   Chicken Rice is located next to the Resh Fruit...
# 513   Indian Vegetarian is located next all the way ...
# 1205  The Korean stall is located in the centre of t...

# %%
# Use geocode to get location
null_latlong_df['alt_add'] = 'Singapore ' + null_latlong_df['postal_code']
null_latlong_df['add_loc'] = null_latlong_df['alt_add'].apply(geocode)

# Verify add_loc generated. 
null_latlong_df[['rest_name','address', 'add_loc']]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [137], in <cell line: 3>()
#       1 # Use geocode to get location
#       2 null_latlong_df['alt_add'] = 'Singapore ' + null_latlong_df['postal_code']
# ----> 3 null_latlong_df['add_loc'] = null_latlong_df['alt_add'].apply(geocode)
#       5 # Verify add_loc generated.
#       6 null_latlong_df[['rest_name','address', 'add_loc']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py:272, in RateLimiter.__call__(self, *args, **kwargs)
#     270 gen = self._retries_gen(args, kwargs)
#     271 for _ in gen:
# --> 272     self._acquire_request_slot()
#     273     try:
#     274         res = self.func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py:267, in RateLimiter._acquire_request_slot(self)
#     265 def _acquire_request_slot(self):
#     266     for wait in self._acquire_request_slot_gen():
# --> 267         self._sleep(wait)
#
# File ~\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py:263, in RateLimiter._sleep(self, seconds)
#     261 def _sleep(self, seconds):  # pragma: no cover
#     262     logger.debug(type(self).__name__ + " sleep(%r)", seconds)
# --> 263     sleep(seconds)
#
# KeyboardInterrupt:

# %%
null_latlong_df['add_loc'].value_counts()
# Out:
# (Singapore, Don Bosco, Parañaque, Southern Manila District, Metro Manila, 1711, Philippines, (14.4848138, 121.0232316))    199
# (Singapore, (1.357107, 103.8194992))                                                                                         5
# (Singapore, Central, Singapore, (1.3408630000000001, 103.83039182212079))                                                    1
# (Tampines, Northeast, 499803, Singapore, (1.3322695, 103.9799766))                                                           1
# Name: add_loc, dtype: int64

# %%
# create longitude, latitude and altitude from location column (returns tuple)
null_latlong_df['point'] = null_latlong_df['add_loc'].apply(lambda loc: tuple(loc.point) if loc else None)
# split point column into latitude, longitude and altitude columns
null_latlong_df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(null_latlong_df['point'].tolist(), index=null_latlong_df.index)

# %%
for i, postal_code in zip(null_latlong_df.index, null_latlong_df['postal_code']):
    try: 
        onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={postal_code}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
        null_latlong_df.loc[i, 'latitude'] = json.loads(onemap.p.text)['results'][0]['LATITUDE']
        null_latlong_df.loc[i, 'longitude'] = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']
        print(i, postal_code)
        print(json.loads(onemap.p.text)['results'][0]['LATITUDE'])
        print(json.loads(onemap.p.text)['results'][0]['LONGTITUDE'])
    except:
        continue
# Out:
# 8959 449876
# 1.30200053040251
# 103.914145450611
# 8960 437844
# 1.30382040183737
# 103.901040040407
# 8961 460068
# 1.31875088774492
# 103.94336390491
# 8962 488696
# 1.3338338017911
# 103.948812554003
# 8963 488696
# 1.3338338017911
# 103.948812554003

# %%
# Verify add_loc generated. 
null_latlong_df[['rest_name','address', 'latitude', 'longitude']]
# Out:
#                     rest_name  \
# 183              Chicken Rice
# 513         Indian Vegetarian
# 1205                   Korean
# 1790      Astons Specialities
# 1791      Astons Specialities
# ...                       ...
# 27888            818 Kopitiam
# 27916               Lenas Jem
# 27922  Yunnan View Restaurant
# 27954                     KFC
# 28099                Buta Kin
#
#                                                  address latitude longitude
# 183    Comtech 60 Alexandra Terrace Singapore 118502 ...      NaN       NaN
# 513    Comtech 60 Alexandra Terrace Singapore 118502 ...      NaN       NaN
# 1205   Comtech 60 Alexandra Terrace Singapore 118502 ...      NaN       NaN
# 1790   295 Lorong 6 Toa Payoh Singapore 319388 Singap...      NaN       NaN
# 1791   295 Lorong 6 Toa Payoh Singapore 319388 Singap...      NaN       NaN
# ...                                                  ...      ...       ...
# 27888  60 Jurong Road Track 22 Singapore 649567 Singa...      NaN       NaN
# 27916  155 Jurong East Street 13 #01-16 Singapore 609...      NaN       NaN
# 27922  11 Japanese Garden Road Singapore 619229 Singa...      NaN       NaN
# 27954             4 Crest Rd Singapore 779651 Singapore       NaN       NaN
# 28099  1A Chun Tin Rd Rooftop Market Singapore 599588...      NaN       NaN
#
# [220 rows x 4 columns]

# %%
# Display summary of null values
null_latlong_df.isnull().sum()
# Out:
# rest_name          0
# href               0
# address            0
# postal_code        0
# latitude         215
# longitude        215
# opening            0
# username           0
# userid             0
# user_location      0
# user_rating        0
# review_date        0
# comment            0
# dtype: int64

# %% [markdown]
# ### Merge and Export Data

# %%
# add 'http://' to 'href' column to rest_df
rest_df['href'] = 'http://' + rest_df['href']

# %%
df = pd.merge(reviews_df, rest_df.drop(columns='name'), left_on='href', right_on='href')

# %%
df.head(2)

# %% [markdown]
# ## 3. Data Dictionary

# %% [markdown]
# | **Dataset** | **Features**| **Year Available for** |
# |---|---|---|
# | **Weather** | - Date<br/> - Temperature<br/> - Sunset/Sunrise Timing<br/> - Precipitation<br/> | 2007-2014|
# | **Spray**   | - Date<br/> - Time<br/> - Location<br/>| 2011 & 2013            |
# | **Train**   | - Date<br/> - Location of Mosquitos<br/> - Mosquitos Species</br> - Location of Trap<br/> - Number of Mosquito Caught<br/> - Presence of West Nile Virus<br/> | 2007, 2009, 2011, 2013 |
# | **Test** | Same as Train, excluding Number of Mosquito Caught and Presence of West Nile Virus| 2008, 2010, 2012, 2014 |

# %% [markdown]
# read up
# 1. matrix factorisation
# 2.

# %% [markdown]
# ## 4. Prelim EDA

# %%
comment_count_df = df.groupby(['rest_name', 'href']).count()[['comment']].sort_values(by='comment', ascending=False)

# %%
comment_count_df.head(3)

# %%
comment_count_df.describe()

# %%
comment_count_df = comment_count_df.reset_index(drop=False)
comment_count_df.head()

# %%
sns.boxplot(data=comment_count_df, orient='h');

# %%
# Plotting the distribution

plt.figure(figsize=(8, 6))
plt.title("Density and Histogram of No. of reviews per restaurant", fontsize=18)

ax = sns.distplot(comment_count_df["comment"], hist=True, kde=True, bins=45,
                  color ="tab:blue", hist_kws={"edgecolor":"black"}, kde_kws={"linewidth": 3})
ax.set_xlabel("No. of Reviews per Restaurant", size=14)
ax.set_ylabel("Density", size=14)

plt.show()

# %%
user_count_df = df.groupby(['username', 'userid']).count()[['comment']].sort_values(by='comment', ascending=False)

# %%
user_count_df.head()

# %%
len(user_count_df[user_count_df['comment']>4])

# %%
user_count_df.describe()

# %%
user_count_df = user_count_df.reset_index()

# %%
sns.boxplot(data=user_count_df, orient='h');

# %%
# Plotting the distribution

plt.figure(figsize=(8, 6))
plt.title("Density and Histogram of No. of reviews per user", fontsize=18)

ax = sns.distplot(user_count_df["comment"], hist=True, kde=True, bins=60,
                  color ="tab:blue", hist_kws={"edgecolor":"black"}, kde_kws={"linewidth": 3})
ax.set_xlabel("No. of Reviews per user", size=14)
ax.set_ylabel("Density", size=14)

plt.show()

# %%
review_dates_df = reviews_df.review_date.dt.year.value_counts().reset_index()
review_dates_df.rename(columns = {'index':'review_date', 
                                  'review_date':'review_count'}, 
                       inplace=True)

# %%
review_dates_df

# %%
# Plotting in a graph

plt.figure(figsize=(8, 6))
plt.xticks(rotation=90)
plt.title("Number of restaurant reviews across years", fontsize=18)

ax = sns.barplot(x="review_date", y="review_count", data=review_dates_df, orient="v", color="tab:blue")
ax.set_xlabel("Review publish year", size=12)
ax.set_ylabel("Num of reviews", size=12)

plt.show()

# %%
from nltk.corpus import stopwords
cust_stopwords = set(stopwords.words('english'))

# %%
## Creating new feature columns
# Calculate reviews word count

df['word_count'] = df['comment'].apply(lambda body: len([w for w in body.split(" ") if w not in cust_stopwords]))

# %%
df.head(2)

# %%
# Histogram of Word Count of Yelp Reviews

sns.set_style("darkgrid")
plt.figure(figsize=(14,8))
sns.distplot(df['word_count'])
plt.title('Histogram of Word Count in Yelp Reviews', fontsize = 16)
plt.xlabel('Word Count of Reviews', fontsize=14)
plt.ylabel('Percentage of Reviews', fontsize=14)

# %%
df['word_count'].describe()

# %%
sns.boxplot(data=df['word_count'], orient='h');

# %%
cat_sum_df = pd.DataFrame(df[cat_col].sum().sort_values(ascending=False), columns=['sum'])
cat_sum_df.head(20)

# %%
plt.figure(figsize=(8, 6))
plt.title("No. of Reviews for Various Categories", fontsize=18)
ax = sns.barplot(data=cat_sum_df.head(20), 
                 y=cat_sum_df.head(20).index, 
                 x='sum', 
                 palette='Blues_r');
ax.set_xlabel("No. of Reviews", size=14)
ax.set_ylabel("Categories", size=14)
ax.bar_label(ax.containers[0]);

# %%
cat_mean_df = pd.DataFrame()

for i, cat in enumerate(cat_col):
    temp_df = df.groupby(by = cat).mean().reset_index(drop=False)
    
    try:
        cat_mean_df.loc[i, 'category'] = cat
        cat_mean_df.loc[i, 'avg_user_rating'] = temp_df.loc[1, 'user_rating']
    except:
        continue

# %%
cat_mean_df = cat_mean_df.sort_values(by='avg_user_rating', ascending=False)

# %%
plt.figure(figsize=(8, 6))
plt.title("Average User Rating for Various Categories", fontsize=18)
ax = sns.barplot(data=cat_mean_df.head(20), 
                 y='category', 
                 x='avg_user_rating', 
                 palette='Blues_r');
ax.set_xlabel("No. of Reviews", size=14)
ax.set_ylabel("Categories", size=14)
ax.bar_label(ax.containers[0]);

# %%
rating_count_df = df.groupby(['user_rating']).count()[['comment']].sort_values(by='comment', ascending=False)

# %%
rating_count_df = rating_count_df.reset_index(drop=False)
rating_count_df

# %%
# Plotting the distribution

plt.figure(figsize=(8, 6))
plt.title("Count and No. of Reviews for Various Ratings", fontsize=18)

ax = sns.barplot(data=rating_count_df, x='user_rating', y='comment', palette='Blues')
ax.set_xlabel("Ratings", size=14)
ax.set_ylabel("Count", size=14)
ax.bar_label(ax.containers[0]);

plt.show()

# %%
location_rating_df = df.groupby(['location']).mean()[['user_rating']].sort_values(by='user_rating', ascending=False)
location_rating_df = location_rating_df.reset_index(drop=False)
location_rating_df

# %%
# Plotting the distribution

plt.figure(figsize=(8, 6))
plt.title("Mean User Rating for Various Locations", fontsize=18)

ax = sns.barplot(data=location_rating_df.head(20), y='location', x='user_rating', palette='Blues_r')
ax.set_xlabel("Mean Ratings", size=14)
ax.set_ylabel("Locations", size=14)
ax.bar_label(ax.containers[0]);

plt.show()

# %%
location_count_df = df.groupby(['location']).count()[['comment']].sort_values(by='comment', ascending=False)

# %%
location_count_df = location_count_df.reset_index(drop=False)
location_count_df

# %%
# Plotting the distribution

plt.figure(figsize=(8, 6))
plt.title("No. of Reviews for Various Locations", fontsize=18)

ax = sns.barplot(data=location_count_df.head(20), y='location', x='comment', palette='Blues_r')
ax.set_xlabel("No of Comments", size=14)
ax.set_ylabel("Locations", size=14)
ax.bar_label(ax.containers[0]);

plt.show()

# %%
count_rating_df = df.groupby(['rest_name', 'href']).count()[['comment']].sort_values(by='comment', ascending=False)
count_rating_df = count_rating_df.reset_index(drop=False)
count_rating_df.head()

# %%
# Plotting the distribution

plt.figure(figsize=(8, 6))
plt.title("No. of Reviews for Various Restaurants", fontsize=18)

ax = sns.barplot(data=count_rating_df.head(20), y='rest_name', x='comment', palette='Blues_r')
ax.set_xlabel("No of Comments", size=14)
ax.set_ylabel("Restaurants", size=14)
ax.bar_label(ax.containers[0]);

plt.show()

# %%
ave_rating_df = df.groupby(['rest_name', 'href']).mean()[['user_rating']].sort_values(by='user_rating', ascending=False)
ave_rating_df[ave_rating_df['user_rating']<5].head(20)
