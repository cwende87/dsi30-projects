# %% [markdown]
# # Capstone: SG Food Recommender
# Author: Choo Wende
#
# ---

# %%
# pip install webdriver-manager

# %% [markdown]
# ## Libraries Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import json
import requests
import re

from bs4 import BeautifulSoup
from datetime import datetime

import time
import re
# from collections import defaultdict
# import pickle
import random

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## WebScrapping Yelp

# %% [markdown]
# ### Restaurant Info

# %%
# Web page used is from yelp.com that is filtered by 99 neighbourhoods.
# Target web page:
url='https://www.yelp.com/search?find_desc=Restaurants&find_loc=Singapore&l=p%3ASG-SG%3ASingapore%3A%3A%5BAlexandra%2CAng_Mo_Kio%2CAnn_Siang_Hill%2CArab_Street%2CBayfront%2CBedok_North%2CBedok_Reservoir%2CBedok_South%2CBencoolen%2CBishan%2CBoat_Quay%2CBoon_Keng%2CBoon_Lay%2CBras_Brasah%2CBuangkok%2CBugis%2CBukit_Batok%2CBukit_Panjang%2CBukit_Timah%2CChangi%2CChinatown%2CChoa_Chu_Kang%2CCity_Hall%2CClarke_Quay%2CClementi%2CDempsey_Hill%2CDhoby_Ghaut%2CDover%2CDuxton_Hill%2CEunos%2CFarrer_Park%2CGeylang%2CGhim_Moh%2CHarbourfront%2CHolland_Hill%2CHolland_Village%2CHougang%2CJoo_Chiat%2CJurong%2CJurong_Island%2CKallang%2CKatong%2CKembangan%2CKent_Ridge%2CKeppel%2CLabrador_Park%2CLavender%2CLim_Chu_Kang%2CLittle_India%2CMacpherson%2CMandai%2CMarine_Parade%2CMount_Sophia%2CMountbatten%2CNewton%2CNovena%2COrchard%2COutram%2CPasir_Panjang%2CPasir_Ris%2CPaya_Lebar%2CPotong_Pasir%2CPulau_Ubin%2CPunggol%2CQueenstown%2CRaffles_Place%2CRedhill%2CRiver_Valley%2CRobertson_Quay%2CSeletar%2CSembawang%2CSengkang%2CSentosa%2CSerangoon%2CSerangoon_Gardens%2CSiglap%2CSimei%2CSixth_Avenue%2CSomerset%2CTampines%2CTanglin%2CTanglin_Halt%2CTanjong_Pagar%2CTanjong_Rhu%2CTelok_Blangah%2CTelok_Kurau%2CThomson%2CTiong_Bahru%2CToa_Payoh%2CTuas%2CUbi%2CUlu_Pandan%2CUpper_Bukit_Timah%2CWessex_Estate%2CWest_Coast%2CWoodlands%2CYio_Chu_Kang%2CYishun%2Cone-north%5D'

# %%
# Establishing the connection to the web page:
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
res.text[:500]
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel='

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %% [markdown]
# **Extract Neighbourhood**

# %%
# Extract the list of Singapore neighbourhood in Yelp. 
neighbourhoods=[]

for row in soup.find('div', {'class':'transitionGroup__09f24__nJIf6'}):
    if row.text!=' • ':
        neighbourhoods.append(row.text)


# display list of neighbourhoods
neighbourhoods[-5:]
# Out:
# ['Newton', 'Seletar', 'Paya Lebar', 'Macpherson', "Bird's-eye View"]

# %%
# Remove last element as it is invalid.
neighbourhoods.remove("Bird's-eye View")

# %%
# create list of neighbourhood url
neighbourhood_urls = {}

for hood in sorted(neighbourhoods):
    hoods=[]
    
    text=hood.replace(' ', '+')
    hoods.append(f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={text}%2C+Singapore')
    
    for i in range(10, 240, 10):
        hoods.append(f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={text}%2C+Singapore&start={i}')
        
    neighbourhood_urls[hood]=hoods

# %%
# Display first 5 urls for each neighbourhood
pd.DataFrame(neighbourhood_urls).head()
# Out:
#                                            Alexandra  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                           Ang Mo Kio  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                       Ann Siang Hill  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                          Arab Street  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                             Bayfront  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                          Bedok North  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                      Bedok Reservoir  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                          Bedok South  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                            Bencoolen  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                               Bishan  ...  \
# 0  https://www.yelp.com/search?find_desc=Restaura...  ...
# 1  https://www.yelp.com/search?find_desc=Restaura...  ...
# 2  https://www.yelp.com/search?find_desc=Restaura...  ...
# 3  https://www.yelp.com/search?find_desc=Restaura...  ...
# 4  https://www.yelp.com/search?find_desc=Restaura...  ...
#
#                                                 Tuas  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                                  Ubi  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                           Ulu Pandan  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                    Upper Bukit Timah  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                        Wessex Estate  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                           West Coast  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                            Woodlands  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                         Yio Chu Kang  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                               Yishun  \
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
#                                            one-north
# 0  https://www.yelp.com/search?find_desc=Restaura...
# 1  https://www.yelp.com/search?find_desc=Restaura...
# 2  https://www.yelp.com/search?find_desc=Restaura...
# 3  https://www.yelp.com/search?find_desc=Restaura...
# 4  https://www.yelp.com/search?find_desc=Restaura...
#
# [5 rows x 99 columns]

# %% [markdown]
# **Extract Restaurant Info**

# %%
def get_soup(url):
    
    # Establishing the connection to the web page:
    res = requests.get(url, stream=True)

    if res.status_code==200:
        return BeautifulSoup(res.content, 'lxml')
        
    else:
        print(f'Res Status Code: {res.status_code}')
        pass

# %%
def get_data(hood, url):
    
    print(url)
    soup=get_soup(url)

    restaurants = []

    # restaurants details
    biz=soup.find_all('span', {'class':'css-1egxyvc'})

    # image
    img=soup.find_all('img', {'class':'css-xlzvdl'})
    
    # rating
    rating_class='attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ margin-r1__09f24__rN_ga border-color--default__09f24__NPAKY'
            
    # review count
    review_count=soup.find_all('span', {'class':'reviewCount__09f24__tnBk4 css-chan6m'})
    
    # location
    # location=soup.find_all('span', {'class':'css-chan6m'})[1:21:2]
    location=soup.find_all('p',{'class':'css-dzq7l1'})
    
    #category
    category=soup.find_all('span', {'class':'css-epvm6 display--inline__09f24__c6N_k border-color--default__09f24__NPAKY'})

    # PriceRange
    pricerange=soup.find_all('p', {'class':'css-dzq7l1'})

    for i in range(len(biz)):
        
        # biz info
        restaurant ={}
        restaurant['neighbourhood'] = hood
        restaurant['name']=biz[i].a['name']
        href=biz[i].a['href']
        restaurant['href']=f'www.yelp.com{href}'
        
        # image info
        restaurant['img']=img[i]['src']

        # rating info
        row=soup.find_all('div', {'class':rating_class})[i]
        restaurant['star_rating']=row.div['aria-label'].replace(' star rating','')

        # Review count info
        restaurant['review_count']=review_count[i].text

        # Location info
        restaurant['location']=location[i].find('span',{'class':'css-chan6m'}).text

        # category info
        try:
            cats_ls=[]
            cat=category[i].find_all('span', {'class':'css-11bijt4'})
            for j in range(len(cat)):
                cats_ls.append(cat[j].text)
            restaurant['category']=cats_ls
        except:
            restaurant['category']=None

        # Price range info
        price=pricerange[i].find('span', {'class':'priceRange__09f24__mmOuH'})
        try:
            restaurant['price_range']=len(price.text)
        except:
            restaurant['price_range']=price
        
        restaurants.append(restaurant)
        restaurant ={}
        
    return pd.DataFrame(restaurants)

# %% [markdown]
# ```python
# # The following code scrape through Yelp for restaurants info based on neighbourhood search
# # A total of 99 neighbourhoods were available on yelp to search.
# # The codes are commented out to prevent re-run of the code, which took some time to run.
#
# # Create restaurant dataframe.
# rest_data = pd.DataFrame()
#
# for hood, urls in list(neighbourhood_urls.items()):
#     print(f'\nScraping from {hood}:')
#     for i in range(len(urls)):
#         hood_data = get_data(hood, urls[i])
#         rest_data=pd.concat([rest_data, hood_data]).reset_index(drop=True)
#
#         if i%np.random.randint(8,11)==0:
#             # generate a random sleep duration to manage number of requests per second
#             sleep_duration = np.random.randint(5,12)
#             print(f'Sleep: {sleep_duration}s')
#             time.sleep(sleep_duration)
#     text=hood.replace(' ', '_')
#     rest_data.to_csv(f'../data/neighbourhoods/{text}.csv', index=False)
#     rest_data = pd.DataFrame()
#
#     # generate a random sleep duration to manage number of requests per second.
#     # Sleep duration is set at such long interval
#     # because shorter intervals will face interruption by the server.
#     sleep_duration = np.random.randint(60,80)
#     print(f'Sleep: {sleep_duration}s')
#     time.sleep(sleep_duration)
# ```

# %%
# Create dataframe of restaurants to merge data in various neighbourhood
rest_df=pd.DataFrame()

for hood in list(neighbourhood_urls.keys()):
    
    text=hood.replace(' ', '_')
    temp_df=pd.read_csv(f'../data/neighbourhoods/{text}.csv')
    rest_df=pd.concat([rest_df, temp_df]).reset_index(drop=True)
    
# Display first 5 and last 5 rows of restaurant dataframe.
rest_df
# Out:
#       neighbourhood                               name  \
# 0         Alexandra                     The Naked Finn
# 1         Alexandra                  Soi Thai Soi Nice
# 2         Alexandra                           The Gogi
# 3         Alexandra               Keng Eng Kee Seafood
# 4         Alexandra                        Burger Barn
# ...             ...                                ...
# 14946     one-north                  The World is Flat
# 14947     one-north                        Food Canopy
# 14948     one-north                Thaksin Beef Noodle
# 14949     one-north  The Bakery By Woodlands Sourdough
# 14950     one-north    Chuan Kee Boneless Braised Duck
#
#                                                     href  \
# 0      www.yelp.com/biz/the-naked-finn-singapore?osq=...
# 1      www.yelp.com/biz/soi-thai-soi-nice-singapore?o...
# 2      www.yelp.com/biz/the-gogi-singapore?osq=Restau...
# 3      www.yelp.com/biz/keng-eng-kee-seafood-singapor...
# 4      www.yelp.com/biz/burger-barn-singapore?osq=Res...
# ...                                                  ...
# 14946  www.yelp.com/biz/the-world-is-flat-singapore?o...
# 14947  www.yelp.com/biz/food-canopy-singapore?osq=Res...
# 14948  www.yelp.com/biz/thaksin-beef-noodle-singapore...
# 14949  www.yelp.com/biz/the-bakery-by-woodlands-sourd...
# 14950  www.yelp.com/biz/chuan-kee-boneless-braised-du...
#
#                                                      img  star_rating  \
# 0      https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1      https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2      https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
# 3      https://s3-media0.fl.yelpcdn.com/bphoto/1TziiZ...          4.0
# 4      https://s3-media0.fl.yelpcdn.com/bphoto/ABw7yU...          4.0
# ...                                                  ...          ...
# 14946  https://s3-media0.fl.yelpcdn.com/bphoto/JZgM6o...          3.0
# 14947  https://s3-media0.fl.yelpcdn.com/bphoto/Z12m7m...          3.0
# 14948  https://s3-media0.fl.yelpcdn.com/bphoto/wvQ5wj...          4.5
# 14949  https://s3-media0.fl.yelpcdn.com/bphoto/q0HOoI...          5.0
# 14950  https://s3-media0.fl.yelpcdn.com/bphoto/n9HZCW...          4.5
#
#        review_count     location                                 category  \
# 0                19    Alexandra                              ['Seafood']
# 1                 2    Alexandra                                 ['Thai']
# 2                 1    Alexandra                   ['Korean', 'Barbeque']
# 3                22    Alexandra                              ['Seafood']
# 4                 4    Alexandra                              ['Burgers']
# ...             ...          ...                                      ...
# 14946             1    one-north  ['Pizza', 'Asian Fusion', 'Sandwiches']
# 14947             1  Bukit Timah                           ['Food Court']
# 14948             2   West Coast                              ['Chinese']
# 14949             1  Bukit Timah                    ['Bakeries', 'Pizza']
# 14950             7     Ghim Moh                              ['Chinese']
#
#        price_range
# 0              3.0
# 1              NaN
# 2              NaN
# 3              2.0
# 4              1.0
# ...            ...
# 14946          NaN
# 14947          NaN
# 14948          1.0
# 14949          NaN
# 14950          1.0
#
# [14951 rows x 9 columns]

# %%
# Display summary info.
rest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14951 entries, 0 to 14950
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   neighbourhood  14951 non-null  object
#  1   name           14951 non-null  object
#  2   href           14951 non-null  object
#  3   img            14951 non-null  object
#  4   star_rating    14951 non-null  float64
#  5   review_count   14951 non-null  int64
#  6   location       14523 non-null  object
#  7   category       14939 non-null  object
#  8   price_range    7959 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.0+ MB

# %%
# Display numeric columns summary info
rest_df.describe()
# Out:
#         star_rating  review_count  price_range
# count  14951.000000  14951.000000  7959.000000
# mean       4.021972      8.622768     1.932529
# std        0.717602     21.443366     0.889946
# min        1.000000      1.000000     1.000000
# 25%        3.500000      1.000000     1.000000
# 50%        4.000000      3.000000     2.000000
# 75%        4.500000      8.000000     2.000000
# max        5.000000    385.000000     4.000000

# %%
# Number of unique restaurants
len(rest_df['href'].unique())
# Out:
# 4026

# %%
# show number of duplicates
rest_df.duplicated().value_counts()
# Out:
# False    14411
# True       540
# dtype: int64

# %% [markdown]
# ### Restaurant Review

# %%
# Create dataframe of unique restaurants and url
rest_url=rest_df.drop(columns=['neighbourhood', 'location']).drop_duplicates(subset=['href']).reset_index(drop=True)

# Display first 5 rows of dataframe
rest_url.head()
# Out:
#                    name                                               href  \
# 0        The Naked Finn  www.yelp.com/biz/the-naked-finn-singapore?osq=...
# 1     Soi Thai Soi Nice  www.yelp.com/biz/soi-thai-soi-nice-singapore?o...
# 2              The Gogi  www.yelp.com/biz/the-gogi-singapore?osq=Restau...
# 3  Keng Eng Kee Seafood  www.yelp.com/biz/keng-eng-kee-seafood-singapor...
# 4           Burger Barn  www.yelp.com/biz/burger-barn-singapore?osq=Res...
#
#                                                  img  star_rating  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/1TziiZ...          4.0
# 4  https://s3-media0.fl.yelpcdn.com/bphoto/ABw7yU...          4.0
#
#    review_count                category  price_range
# 0            19             ['Seafood']          3.0
# 1             2                ['Thai']          NaN
# 2             1  ['Korean', 'Barbeque']          NaN
# 3            22             ['Seafood']          2.0
# 4             4             ['Burgers']          1.0

# %%
# add 'http://' to 'href' column
rest_url['href'] = 'http://' + rest_url['href']

# %%
# Display restaurants with high review count
rest_url[rest_url['review_count']>100]
# Out:
#                                  name  \
# 454  Tian Tian Hainanese Chicken Rice
# 515                     Jumbo Seafood
# 557               Song Fa Bak Kut Teh
# 667              Liao Fan Hawker Chan
# 672               CÉ LA VI Restaurant
# 750                      Din Tai Fung
#
#                                                   href  \
# 454  http://www.yelp.com/biz/tian-tian-hainanese-ch...
# 515  http://www.yelp.com/biz/jumbo-seafood-singapor...
# 557  http://www.yelp.com/biz/song-fa-bak-kut-teh-si...
# 667  http://www.yelp.com/biz/liao-fan-hawker-chan-s...
# 672  http://www.yelp.com/biz/c%C3%A9-la-vi-restaura...
# 750  http://www.yelp.com/biz/din-tai-fung-singapore...
#
#                                                    img  star_rating  \
# 454  https://s3-media0.fl.yelpcdn.com/bphoto/UJ5Kp3...          4.0
# 515  https://s3-media0.fl.yelpcdn.com/bphoto/85hCRe...          4.0
# 557  https://s3-media0.fl.yelpcdn.com/bphoto/cgE6mZ...          4.0
# 667  https://s3-media0.fl.yelpcdn.com/bphoto/LMpD02...          4.0
# 672  https://s3-media0.fl.yelpcdn.com/bphoto/Y9T9Iu...          3.0
# 750  https://s3-media0.fl.yelpcdn.com/bphoto/fxsbP8...          4.5
#
#      review_count                               category  price_range
# 454           385             ['Hainan', 'Chicken Shop']          1.0
# 515           188                            ['Seafood']          3.0
# 557           136             ['Singaporean', 'Chinese']          1.0
# 667           140            ['Noodles', 'Chicken Shop']          1.0
# 672           134               ['Bars', 'Asian Fusion']          3.0
# 750           132  ['Taiwanese', 'Dim Sum', 'Dumplings']          2.0

# %%
# Generate url to extract reviews.

# Create a column of urls to extract reviews. 
rest_url['review_url'] = np.nan
rest_url.head()

# Loop through every row to input urls
for i in range(len(rest_url['href'])):
    url_ls = rest_url['href'][i]
    
    if rest_url['review_count'][i]<11:
        pass
    else:
        # check number of url pages to scrap reviews.
        pages=int(rest_url['review_count'][i]/10) + (rest_url['review_count'][i]%10 > 0)
                
        for j in range(10, (pages*10), 10):
            url_ls = url_ls + ' ' + (rest_url['href'][i]+f'&start={j}')
    
    rest_url.loc[i, 'review_url']= url_ls

# %%
# Check dataframe and column created.
rest_url.head()
# Out:
#                    name                                               href  \
# 0        The Naked Finn  http://www.yelp.com/biz/the-naked-finn-singapo...
# 1     Soi Thai Soi Nice  http://www.yelp.com/biz/soi-thai-soi-nice-sing...
# 2              The Gogi  http://www.yelp.com/biz/the-gogi-singapore?osq...
# 3  Keng Eng Kee Seafood  http://www.yelp.com/biz/keng-eng-kee-seafood-s...
# 4           Burger Barn  http://www.yelp.com/biz/burger-barn-singapore?...
#
#                                                  img  star_rating  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvC...          4.5
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/qmndjm...          4.5
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/srghHe...          5.0
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/1TziiZ...          4.0
# 4  https://s3-media0.fl.yelpcdn.com/bphoto/ABw7yU...          4.0
#
#    review_count                category  price_range  \
# 0            19             ['Seafood']          3.0
# 1             2                ['Thai']          NaN
# 2             1  ['Korean', 'Barbeque']          NaN
# 3            22             ['Seafood']          2.0
# 4             4             ['Burgers']          1.0
#
#                                           review_url
# 0  http://www.yelp.com/biz/the-naked-finn-singapo...
# 1  http://www.yelp.com/biz/soi-thai-soi-nice-sing...
# 2  http://www.yelp.com/biz/the-gogi-singapore?osq...
# 3  http://www.yelp.com/biz/keng-eng-kee-seafood-s...
# 4  http://www.yelp.com/biz/burger-barn-singapore?...

# %%
# Check column created for high review counts.
rest_url.loc[3]['review_url']
# Out:
# 'http://www.yelp.com/biz/keng-eng-kee-seafood-singapore?osq=Restaurants http://www.yelp.com/biz/keng-eng-kee-seafood-singapore?osq=Restaurants&start=10 http://www.yelp.com/biz/keng-eng-kee-seafood-singapore?osq=Restaurants&start=20'

# %%
# Define function to scrape reviews. 
def get_reviews(rest_name, url):
    
    # Instantiate reviews list
    reviews =[]
    
    print(url)
    soup=get_soup(url)

    reviews = []

    # restaurants address info
    add = ''

    for row in soup.find('address').find_all('span', {'class':'raw__09f24__T4Ezm'}):
        add += (row.text + ' ')

    alt_add = soup.find('address').find_all('span', {'class':'raw__09f24__T4Ezm'})[0].text
    

    # Get postal code and latitude, longitude via onemap api
    try:
        postal_code = re.search('\d{6}', add).group()
        onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={postal_code}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
        latitude = json.loads(onemap.p.text)['results'][0]['LATITUDE']
        longitude = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']
    
    except:
        onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={alt_add}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
        
        try: 
            postal_code = json.loads(onemap.p.text)['results'][0]['POSTAL']
            latitude = json.loads(onemap.p.text)['results'][0]['LATITUDE']
            longitude = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']
        except:
            latitude = np.nan
            longitude = np.nan
            try:
                postal_code = postal_code
            except:
                postal_code = np.nan
    
    # opening hours info
    day=[]
    hrs=[]
    
    opening_table = soup.find('table', {'class':'hours-table__09f24__KR8wh table__09f24__J2OBP table--simple__09f24__vy16f'})
    
    for row in opening_table.find_all('th', {'class':"table-header-cell__09f24__y32Xb"}):
        day.append(row.text)

    for row in opening_table.find_all('ul', {'class':"undefined list__09f24__ynIEd"}):
        subset=[]
        for i in range(len(row.find_all('li'))):
            subset.append(row.find_all('li')[i].text)
        hrs.append(subset)
        
    opening = list(zip(day, hrs))

    # Review info
    review_div = soup.find('div', {'class':'css-79elbk border-color--default__09f24__NPAKY'})
    review_li = review_div.find_all('li', {'class':'margin-b5__09f24__pTvws border-color--default__09f24__NPAKY'})
    
    # scrape through every review. 
    for row in review_li:
        
        # instantiate review dictionary to store information. 
        review = {}
        
        # Store additional restaurants information.
        review['rest_name'] = rest_name
        review['address'] = add
        review['postal_code'] = postal_code
        review['latitude'] = latitude
        review['longitude'] = longitude
        review['opening'] = opening        
        
        # username
        try:
            user_info = row.find('div', {'class':'user-passport-info border-color--default__09f24__NPAKY'})
            review['username'] = user_info.a.text
        except:
            # user might be blocked.
            # Hence, their comments may not be credible
            break   
        
        # usesrid
        review['userid'] = user_info.a['href'].replace('/user_details?userid=','')
        
        # location
        review['user_location'] = user_info.find('span', {'class':'css-qgunke'}).text
        
        # rating
        rating_div = row.find('div', {'class':'margin-t1__09f24__w96jn margin-b1-5__09f24__NHcQi border-color--default__09f24__NPAKY'})
        review['user_rating'] = rating_div.span.div['aria-label'].replace(' star rating','')
        
        # date of post
        review['review_date'] = row.find('span', {'class':'css-chan6m'}).text
        
        # comments
        review['comment'] = row.find('span', {'class':'raw__09f24__T4Ezm'}).text
        
        reviews.append(review)
        review ={}
        
    return pd.DataFrame(reviews)

# %%
# ```python
# The following code scrape through Yelp for restaurants review
# The codes are commented out to prevent re-run of the code, which took some time to run. 

# Create review dataframe. 
reviews_data = pd.DataFrame()
count_url = 0
i = 940

# for i in range(400, len(rest_url)):
while i < len(rest_url):
    
    to_break = 0
    
    # Display info on scrapping status
    rest_name = rest_url.loc[i, 'name'] 
    print(f'\nScraping from {rest_name}:')
    print(i)
    
    urls = rest_url.loc[i, 'review_url'].split()
    
    for url in urls:
        
        try:
            review_data = get_reviews(rest_name, url)
        
        except:
            
            # sleep and try scrapping again.
            # generate a random sleep duration to manage number of requests per second         
            sleep_duration = np.random.randint(60,80)
            print(f'Sleep: {sleep_duration}s')
            time.sleep(sleep_duration)           
            
            # break from url loop and restart scrapping
            to_break = 1
            break

        # to add data to dataframe.
        reviews_data = pd.concat([reviews_data, review_data]).reset_index(drop=True)
        count_url +=1
        
        # generate a random sleep duration to manage number of requests per second
        # at random interval in every 20 restaurants.
        if count_url%np.random.randint(7,10)==0:
            sleep_duration = np.random.randint(5,8)
            print(f'Sleep: {sleep_duration}s')
            time.sleep(sleep_duration)
            
        # generate a random sleep duration to manage number of requests per second
        # sleep after scraping every 20 urls   
        if (count_url+1)%20 == 0:                 
            sleep_duration = np.random.randint(10,15)
            print(f'Sleep: {sleep_duration}s')
            time.sleep(sleep_duration)       

    # reset i and restart scrapping
    if to_break:
        rest_name = rest_url.loc[i, 'name']
        print(f'Restart scrapping from last url: i is {i}, {rest_name}')
    
    else:
        
        # increase i count by 1
        i += 1    

        # Save out data after every 20 restaurants
        if i%20 == 0:
            reviews_data.to_csv(f'../data/reviews_{i}.csv', index=False)
            print(f'Saved to reviews_{i}.csv')
            rest_data = pd.DataFrame()

        # Save last set of data   
        if i-1 == len(rest_url):
            reviews_data.to_csv(f'../data/reviews_{(i-1)%100 + 10}.csv', index=False)
            rest_data = pd.DataFrame()

# ```
# Out:
# Scraping from HG 106 Coffeeshop:
# 940
# http://www.yelp.com/biz/hg-106-coffeeshop-singapore?osq=Restaurants
#
# Scraping from Werner’s Oven:
# 941
# http://www.yelp.com/biz/werners-oven-singapore-2?osq=Restaurants
#
# Scraping from Tian Wai Tian Fishhead Steamboat:
# 942
# http://www.yelp.com/biz/tian-wai-tian-fishhead-steamboat-singapore?osq=Restaurants
#
# Scraping from Golden Jade Restaurant Culinary Group:
# 943
# http://www.yelp.com/biz/golden-jade-restaurant-culinary-group-singapore?osq=Restaurants
#
# Scraping from Wine Connection Bistro:
# 944
# http://www.yelp.com/biz/wine-connection-bistro-singapore-3?osq=Restaurants
#
# Scraping from Five Spice:
# 945
# http://www.yelp.com/biz/five-spice-singapore?osq=Restaurants
#
# Scraping from Saboten:
# 946
# http://www.yelp.com/biz/saboten-singapore-2?osq=Restaurants
# Sleep: 7s
# http://www.yelp.com/biz/saboten-singapore-2?osq=Restaurants&start=10
#
# Scraping from Bedok Corner Hokkien Prawn Mee:
# 947
# http://www.yelp.com/biz/bedok-corner-hokkien-prawn-mee-singapore?osq=Restaurants
#
# Scraping from Colonial Club:
# 948
# http://www.yelp.com/biz/colonial-club-singapore?osq=Restaurants
#
# Scraping from Tim Ho Wan:
# 949
# http://www.yelp.com/biz/tim-ho-wan-singapore-11?osq=Restaurants
#
# Scraping from Bedok Food Centre:
# 950
# http://www.yelp.com/biz/bedok-food-centre-singapore?osq=Restaurants
#
# Scraping from The Kitchen by Wolfgang Puck:
# 951
# http://www.yelp.com/biz/the-kitchen-by-wolfgang-puck-singapore?osq=Restaurants
#
# Scraping from Indonesian Cuisine Stall - Bagus - Changi City Point:
# 952
# http://www.yelp.com/biz/indonesian-cuisine-stall-bagus-changi-city-point-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Shin-Sapporo Ramen:
# 953
# http://www.yelp.com/biz/shin-sapporo-ramen-singapore-2?osq=Restaurants
#
# Scraping from Paper Rice Vietnamese Kitchen:
# 954
# http://www.yelp.com/biz/paper-rice-vietnamese-kitchen-singapore?osq=Restaurants
#
# Scraping from Myra’s Beach Club:
# 955
# http://www.yelp.com/biz/myras-beach-club-singapore?osq=Restaurants
#
# Scraping from Stuff’d:
# 956
# http://www.yelp.com/biz/stuffd-singapore-7?osq=Restaurants
# Sleep: 6s
#
# Scraping from Himawari Japanese Restaurant:
# 957
# http://www.yelp.com/biz/himawari-japanese-restaurant-singapore?osq=Restaurants
# Sleep: 13s
#
# Scraping from Toast Box:
# 958
# http://www.yelp.com/biz/toast-box-jewel-changi?osq=Restaurants
#
# Scraping from TGM:
# 959
# http://www.yelp.com/biz/tgm-singapore?osq=Restaurants
# Sleep: 6s
# Saved to reviews_960.csv
#
# Scraping from Table Manners:
# 960
# http://www.yelp.com/biz/table-manners-no-title?osq=Restaurants
# http://www.yelp.com/biz/table-manners-no-title?osq=Restaurants&start=10
#
# Scraping from Moa Tiki New Zealand Bar and Grill CCP:
# 961
# http://www.yelp.com/biz/moa-tiki-new-zealand-bar-and-grill-ccp-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from TFF Boneless Chicken Rice:
# 962
# http://www.yelp.com/biz/tff-boneless-chicken-rice-singapore?osq=Restaurants
#
# Scraping from Song Fa Bak Kut Teh:
# 963
# http://www.yelp.com/biz/song-fa-bak-kut-teh-singapore-9?osq=Restaurants
#
# Scraping from Peach Garden Noodle House:
# 964
# http://www.yelp.com/biz/peach-garden-noodle-house-singapore-3?osq=Restaurants
#
# Scraping from Din Tai Fung:
# 965
# http://www.yelp.com/biz/din-tai-fung-singapore-35?osq=Restaurants
#
# Scraping from The World is Flat at Changi Airport:
# 966
# http://www.yelp.com/biz/the-world-is-flat-at-changi-airport-singapore?osq=Restaurants
#
# Scraping from Orchis Food Court:
# 967
# http://www.yelp.com/biz/orchis-food-court-singapore?osq=Restaurants
#
# Scraping from Lots Gourmet:
# 968
# http://www.yelp.com/biz/lots-gourmet-singapore-2?osq=Restaurants
#
# Scraping from Big Eater Seafood:
# 969
# http://www.yelp.com/biz/big-eater-seafood-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Chicken Rice & Roasted Meat Stall Koufu Food Court:
# 970
# http://www.yelp.com/biz/chicken-rice-and-roasted-meat-stall-koufu-food-court-singapore?osq=Restaurants
#
# Scraping from The Asian Kitchen - Changi City Point Mall:
# 971
# http://www.yelp.com/biz/the-asian-kitchen-changi-city-point-mall-singapore?osq=Restaurants
#
# Scraping from Singapore Food Street:
# 972
# http://www.yelp.com/biz/singapore-food-street-singapore?osq=Restaurants
# Sleep: 6s
# http://www.yelp.com/biz/singapore-food-street-singapore?osq=Restaurants&start=10
# Sleep: 5s
#
# Scraping from Fart Tartz Cafe:
# 973
# http://www.yelp.com/biz/fart-tartz-cafe-singapore?osq=Restaurants
#
# Scraping from Four Seasons Durians Restaurant:
# 974
# http://www.yelp.com/biz/four-seasons-durians-restaurant-changi?osq=Restaurants
#
# Scraping from Tai Wah Bak Chor Mee:
# 975
# http://www.yelp.com/biz/tai-wah-bak-chor-mee-singapore?osq=Restaurants
# Sleep: 65s
# Restart scrapping from last url: i is 975, Tai Wah Bak Chor Mee
#
# Scraping from Tai Wah Bak Chor Mee:
# 975
# http://www.yelp.com/biz/tai-wah-bak-chor-mee-singapore?osq=Restaurants
# Sleep: 12s
#
# Scraping from Keith Crackling Roast:
# 976
# http://www.yelp.com/biz/keith-crackling-roast-singapore-2?osq=Restaurants
#
# Scraping from Bee Cheng Hiang:
# 977
# http://www.yelp.com/biz/bee-cheng-hiang-singapore-11?osq=Restaurants
#
# Scraping from Eggs ‘n Things:
# 978
# http://www.yelp.com/biz/eggs-n-things-singapore-3?osq=Restaurants
# Sleep: 6s
#
# Scraping from Shake Shack:
# 979
# http://www.yelp.com/biz/shake-shack-singapore?osq=Restaurants
# Saved to reviews_980.csv
#
# Scraping from Rongheng Seafood:
# 980
# http://www.yelp.com/biz/rongheng-seafood-singapore?osq=Restaurants
# Sleep: 65s
# Restart scrapping from last url: i is 980, Rongheng Seafood
#
# Scraping from Rongheng Seafood:
# 980
# http://www.yelp.com/biz/rongheng-seafood-singapore?osq=Restaurants
#
# Scraping from Heavenly Wang:
# 981
# http://www.yelp.com/biz/heavenly-wang-singapore-7?osq=Restaurants
#
# Scraping from Ya Kun Kaya Toast:
# 982
# http://www.yelp.com/biz/ya-kun-kaya-toast-singapore-31?osq=Restaurants
#
# Scraping from Ros Siam Thai Cuisine:
# 983
# http://www.yelp.com/biz/ros-siam-thai-cuisine-singapore?osq=Restaurants
#
# Scraping from Tasty Court By Chef Pung:
# 984
# http://www.yelp.com/biz/tasty-court-by-chef-pung-singapore?osq=Restaurants
#
# Scraping from Pondok Kartika:
# 985
# http://www.yelp.com/biz/pondok-kartika-no-title?osq=Restaurants
#
# Scraping from Baba Chews:
# 986
# http://www.yelp.com/biz/baba-chews-singapore?osq=Restaurants
#
# Scraping from House Of Peranakan Cuisine:
# 987
# http://www.yelp.com/biz/house-of-peranakan-cuisine-singapore?osq=Restaurants
#
# Scraping from Century Village Eating House:
# 988
# http://www.yelp.com/biz/century-village-eating-house-singapore?osq=Restaurants
#
# Scraping from Ah Orh Kway Chap:
# 989
# http://www.yelp.com/biz/ah-orh-kway-chap-singapore?osq=Restaurants
#
# Scraping from Beach Road Prawn Noodle House:
# 990
# http://www.yelp.com/biz/beach-road-prawn-noodle-house-singapore?osq=Restaurants
# http://www.yelp.com/biz/beach-road-prawn-noodle-house-singapore?osq=Restaurants&start=10
#
# Scraping from Crave:
# 991
# http://www.yelp.com/biz/crave-singapore-5?osq=Restaurants
#
# Scraping from Chat Masala:
# 992
# http://www.yelp.com/biz/chat-masala-singapore?osq=Restaurants
#
# Scraping from cedele:
# 993
# http://www.yelp.com/biz/cedele-singapore-25?osq=Restaurants
#
# Scraping from Wingstop:
# 994
# http://www.yelp.com/biz/wingstop-bedok?osq=Restaurants
# Sleep: 11s
#
# Scraping from Hill Street Fried Kway Teow:
# 995
# http://www.yelp.com/biz/hill-street-fried-kway-teow-singapore?osq=Restaurants
# http://www.yelp.com/biz/hill-street-fried-kway-teow-singapore?osq=Restaurants&start=10
#
# Scraping from Food Emporium:
# 996
# http://www.yelp.com/biz/food-emporium-singapore?osq=Restaurants
#
# Scraping from Guan Hoe Soon:
# 997
# http://www.yelp.com/biz/guan-hoe-soon-singapore-2?osq=Restaurants
# Sleep: 7s
#
# Scraping from Tang Tea House Hong Kong Cafe:
# 998
# http://www.yelp.com/biz/tang-tea-house-hong-kong-cafe-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Ya Kun Kaya Toast:
# 999
# http://www.yelp.com/biz/ya-kun-kaya-toast-singapore-22?osq=Restaurants
# http://www.yelp.com/biz/ya-kun-kaya-toast-singapore-22?osq=Restaurants&start=10
# Saved to reviews_1000.csv
#
# Scraping from Vietnamese Stall - Sim Lim Square Food Court:
# 1000
# http://www.yelp.com/biz/vietnamese-stall-sim-lim-square-food-court-singapore?osq=Restaurants
#
# Scraping from Wing Seong Fatty’s:
# 1001
# http://www.yelp.com/biz/wing-seong-fattys-singapore?osq=Restaurants
# http://www.yelp.com/biz/wing-seong-fattys-singapore?osq=Restaurants&start=10
#
# Scraping from Artichoke Cafe & Bar:
# 1002
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants
# Sleep: 6s
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=20
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=30
# Sleep: 67s
# Restart scrapping from last url: i is 1002, Artichoke Cafe & Bar
#
# Scraping from Artichoke Cafe & Bar:
# 1002
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=20
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=30
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=40
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=50
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=60
# Sleep: 14s
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=70
# Sleep: 77s
# Restart scrapping from last url: i is 1002, Artichoke Cafe & Bar
#
# Scraping from Artichoke Cafe & Bar:
# 1002
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants
# Sleep: 7s
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=20
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=30
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=40
# Sleep: 6s
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=50
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=60
# http://www.yelp.com/biz/artichoke-cafe-and-bar-singapore?osq=Restaurants&start=70
#
# Scraping from Teng Bespoke Japanese Vegetarian Dining:
# 1003
# http://www.yelp.com/biz/teng-bespoke-japanese-vegetarian-dining-singapore?osq=Restaurants
# http://www.yelp.com/biz/teng-bespoke-japanese-vegetarian-dining-singapore?osq=Restaurants&start=10
#
# Scraping from Rui Xiang Restaurant:
# 1004
# http://www.yelp.com/biz/rui-xiang-restaurant-singapore?osq=Restaurants
#
# Scraping from Soi Aroy:
# 1005
# http://www.yelp.com/biz/soi-aroy-singapore-2?osq=Restaurants
#
# Scraping from Queen St Prawn Noodles:
# 1006
# http://www.yelp.com/biz/queen-st-prawn-noodles-singapore?osq=Restaurants
#
# Scraping from Leong Yeow Famous Waterloo Street Chicken Rice:
# 1007
# http://www.yelp.com/biz/leong-yeow-famous-waterloo-street-chicken-rice-downtown-core?osq=Restaurants
#
# Scraping from Zen Japanese Vegetarian Restaurant:
# 1008
# http://www.yelp.com/biz/zen-japanese-vegetarian-restaurant-singapore?osq=Restaurants
#
# Scraping from Curious Palette:
# 1009
# http://www.yelp.com/biz/curious-palette-singapore?osq=Restaurants
# http://www.yelp.com/biz/curious-palette-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/curious-palette-singapore?osq=Restaurants&start=20
#
# Scraping from Song Garden:
# 1010
# http://www.yelp.com/biz/song-garden-singapore?osq=Restaurants
#
# Scraping from Geisha Specialty Coffee:
# 1011
# http://www.yelp.com/biz/geisha-specialty-coffee-singapore?osq=Restaurants
# Sleep: 5s
# Sleep: 14s
#
# Scraping from New Rong Ge Liang Hong Kong Roast:
# 1012
# http://www.yelp.com/biz/new-rong-ge-liang-hong-kong-roast-singapore?osq=Restaurants
#
# Scraping from Snowy Village:
# 1013
# http://www.yelp.com/biz/snowy-village-singapore?osq=Restaurants
#
# Scraping from En Sushi:
# 1014
# http://www.yelp.com/biz/en-sushi-singapore?osq=Restaurants
#
# Scraping from Red Stove Hokkien Prawn Mee:
# 1015
# http://www.yelp.com/biz/red-stove-hokkien-prawn-mee-singapore?osq=Restaurants
#
# Scraping from Happy Tummy:
# 1016
# http://www.yelp.com/biz/happy-tummy-singapore-2?osq=Restaurants
# Sleep: 7s
#
# Scraping from Mangiamo Pizzeria:
# 1017
# http://www.yelp.com/biz/mangiamo-pizzeria-singapore?osq=Restaurants
#
# Scraping from Hong Kong Dim Sum:
# 1018
# http://www.yelp.com/biz/hong-kong-dim-sum-singapore?osq=Restaurants
#
# Scraping from The American Taproom:
# 1019
# http://www.yelp.com/biz/the-american-taproom-singapore?osq=Restaurants
# Saved to reviews_1020.csv
#
# Scraping from Toast Box:
# 1020
# http://www.yelp.com/biz/toast-box-singapore-24?osq=Restaurants
#
# Scraping from Eat3Cuts:
# 1021
# http://www.yelp.com/biz/eat3cuts-singapore?osq=Restaurants
#
# Scraping from Taste Good:
# 1022
# http://www.yelp.com/biz/taste-good-singapore?osq=Restaurants
#
# Scraping from Pu3:
# 1023
# http://www.yelp.com/biz/pu3-singapore?osq=Restaurants
#
# Scraping from 3838 Eating Place:
# 1024
# http://www.yelp.com/biz/3838-eating-place-singapore?osq=Restaurants
# Sleep: 70s
# Restart scrapping from last url: i is 1024, 3838 Eating Place
#
# Scraping from 3838 Eating Place:
# 1024
# http://www.yelp.com/biz/3838-eating-place-singapore?osq=Restaurants
#
# Scraping from Astons Specialties:
# 1025
# http://www.yelp.com/biz/astons-specialties-singapore-6?osq=Restaurants
#
# Scraping from Komala Vilas Restaurant:
# 1026
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=20
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=30
# Sleep: 76s
# Restart scrapping from last url: i is 1026, Komala Vilas Restaurant
#
# Scraping from Komala Vilas Restaurant:
# 1026
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants
# Sleep: 6s
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=20
# Sleep: 6s
# Sleep: 14s
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=30
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=40
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=50
# http://www.yelp.com/biz/komala-vilas-restaurant-singapore?osq=Restaurants&start=60
#
# Scraping from Tanuki Raw at Kapok:
# 1027
# http://www.yelp.com/biz/tanuki-raw-at-kapok-singapore-2?osq=Restaurants
#
# Scraping from Din Tai Fung:
# 1028
# http://www.yelp.com/biz/din-tai-fung-singapore-23?osq=Restaurants
#
# Scraping from Pizza Maru:
# 1029
# http://www.yelp.com/biz/pizza-maru-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Bai Nian Yong Tau Foo:
# 1030
# http://www.yelp.com/biz/bai-nian-yong-tau-foo-singapore?osq=Restaurants
#
# Scraping from Nobu-ya:
# 1031
# http://www.yelp.com/biz/nobu-ya-singapore?osq=Restaurants
# http://www.yelp.com/biz/nobu-ya-singapore?osq=Restaurants&start=10
#
# Scraping from Korean Fusion BBQ:
# 1032
# http://www.yelp.com/biz/korean-fusion-bbq-singapore-2?osq=Restaurants
#
# Scraping from Bismillah Biryani:
# 1033
# http://www.yelp.com/biz/bismillah-biryani-singapore?osq=Restaurants
# http://www.yelp.com/biz/bismillah-biryani-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/bismillah-biryani-singapore?osq=Restaurants&start=20
# Sleep: 7s
# http://www.yelp.com/biz/bismillah-biryani-singapore?osq=Restaurants&start=30
#
# Scraping from Victor’s Kitchen:
# 1034
# http://www.yelp.com/biz/victors-kitchen-singapore?osq=Restaurants
# Sleep: 5s
# http://www.yelp.com/biz/victors-kitchen-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/victors-kitchen-singapore?osq=Restaurants&start=20
#
# Scraping from Aroy Dee:
# 1035
# http://www.yelp.com/biz/aroy-dee-singapore?osq=Restaurants
# http://www.yelp.com/biz/aroy-dee-singapore?osq=Restaurants&start=10
# Sleep: 14s
#
# Scraping from Seoul Yummy:
# 1036
# http://www.yelp.com/biz/seoul-yummy-singapore-3?osq=Restaurants
# Sleep: 7s
#
# Scraping from Twenty Eight Cafe:
# 1037
# http://www.yelp.com/biz/twenty-eight-cafe-singapore?osq=Restaurants
#
# Scraping from Four Seasons:
# 1038
# http://www.yelp.com/biz/four-seasons-singapore-2?osq=Restaurants
#
# Scraping from Thai Gold:
# 1039
# http://www.yelp.com/biz/thai-gold-singapore?osq=Restaurants
# Sleep: 69s
# Restart scrapping from last url: i is 1039, Thai Gold
#
# Scraping from Thai Gold:
# 1039
# http://www.yelp.com/biz/thai-gold-singapore?osq=Restaurants
# Saved to reviews_1040.csv
#
# Scraping from New Green Pasture:
# 1040
# http://www.yelp.com/biz/new-green-pasture-singapore?osq=Restaurants
#
# Scraping from Pepper Jade:
# 1041
# http://www.yelp.com/biz/pepper-jade-singapore?osq=Restaurants
#
# Scraping from Crossings Cafe:
# 1042
# http://www.yelp.com/biz/crossings-cafe-singapore?osq=Restaurants
#
# Scraping from Broadway Food Court:
# 1043
# http://www.yelp.com/biz/broadway-food-court-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Asanoya:
# 1044
# http://www.yelp.com/biz/asanoya-singapore?osq=Restaurants
# http://www.yelp.com/biz/asanoya-singapore?osq=Restaurants&start=10
#
# Scraping from PASSION:
# 1045
# http://www.yelp.com/biz/passion-singapore?osq=Restaurants
#
# Scraping from Ginett:
# 1046
# http://www.yelp.com/biz/ginett-singapore?osq=Restaurants
#
# Scraping from Mackenzie Rex:
# 1047
# http://www.yelp.com/biz/mackenzie-rex-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Sumire Yakitori House:
# 1048
# http://www.yelp.com/biz/sumire-yakitori-house-singapore?osq=Restaurants
#
# Scraping from Idealite:
# 1049
# http://www.yelp.com/biz/idealite-singapore?osq=Restaurants
# Sleep: 66s
# Restart scrapping from last url: i is 1049, Idealite
#
# Scraping from Idealite:
# 1049
# http://www.yelp.com/biz/idealite-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from QS269:
# 1050
# http://www.yelp.com/biz/qs269-singapore?osq=Restaurants
#
# Scraping from Teppanyaki - Food Junction - Bugis Junction:
# 1051
# http://www.yelp.com/biz/teppanyaki-food-junction-bugis-junction-singapore?osq=Restaurants
#
# Scraping from KungFu Paradise:
# 1052
# http://www.yelp.com/biz/kungfu-paradise-singapore?osq=Restaurants
#
# Scraping from Ma Maison:
# 1053
# http://www.yelp.com/biz/ma-maison-singapore-2?osq=Restaurants
# http://www.yelp.com/biz/ma-maison-singapore-2?osq=Restaurants&start=10
# Sleep: 11s
#
# Scraping from Yogart:
# 1054
# http://www.yelp.com/biz/yogart-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Chikuyotei:
# 1055
# http://www.yelp.com/biz/chikuyotei-singapore?osq=Restaurants
#
# Scraping from Brotzeit Raffles City:
# 1056
# http://www.yelp.com/biz/brotzeit-raffles-city-singapore?osq=Restaurants
# http://www.yelp.com/biz/brotzeit-raffles-city-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/brotzeit-raffles-city-singapore?osq=Restaurants&start=20
#
# Scraping from Burger & Lobster:
# 1057
# http://www.yelp.com/biz/burger-and-lobster-singapore-3?osq=Restaurants
#
# Scraping from Red House Seafood Restaurant:
# 1058
# http://www.yelp.com/biz/red-house-seafood-restaurant-singapore-2?osq=Restaurants
# http://www.yelp.com/biz/red-house-seafood-restaurant-singapore-2?osq=Restaurants&start=10
#
# Scraping from Sri Vijaya:
# 1059
# http://www.yelp.com/biz/sri-vijaya-singapore?osq=Restaurants
# Sleep: 6s
# Saved to reviews_1060.csv
#
# Scraping from Riki Power Ramen:
# 1060
# http://www.yelp.com/biz/riki-power-ramen-singapore?osq=Restaurants
#
# Scraping from Nihon Mura:
# 1061
# http://www.yelp.com/biz/nihon-mura-singapore-6?osq=Restaurants
#
# Scraping from Shahi Maharani:
# 1062
# http://www.yelp.com/biz/shahi-maharani-singapore?osq=Restaurants
# Sleep: 73s
# Restart scrapping from last url: i is 1062, Shahi Maharani
#
# Scraping from Shahi Maharani:
# 1062
# http://www.yelp.com/biz/shahi-maharani-singapore?osq=Restaurants
#
# Scraping from Belle-Ville Bugis Junction:
# 1063
# http://www.yelp.com/biz/belle-ville-bugis-junction-singapore?osq=Restaurants
#
# Scraping from The Refinery:
# 1064
# http://www.yelp.com/biz/the-refinery-singapore?osq=Restaurants
#
# Scraping from Wild Oats:
# 1065
# http://www.yelp.com/biz/wild-oats-singapore?osq=Restaurants
#
# Scraping from Ah Seng Bah Kut Teh:
# 1066
# http://www.yelp.com/biz/ah-seng-bah-kut-teh-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Lowercase:
# 1067
# http://www.yelp.com/biz/lowercase-singapore?osq=Restaurants
#
# Scraping from Din Tai Fung:
# 1068
# http://www.yelp.com/biz/din-tai-fung-singapore-3?osq=Restaurants
#
# Scraping from Mata Thai:
# 1069
# http://www.yelp.com/biz/mata-thai-singapore?osq=Restaurants
#
# Scraping from Pok Pok Thai Kitchen:
# 1070
# http://www.yelp.com/biz/pok-pok-thai-kitchen-no-title?osq=Restaurants
# Sleep: 12s
#
# Scraping from Hong Yun Seafood:
# 1071
# http://www.yelp.com/biz/hong-yun-seafood-singapore?osq=Restaurants
#
# Scraping from Food Pot:
# 1072
# http://www.yelp.com/biz/food-pot-singapore?osq=Restaurants
#
# Scraping from Parker Korean Restaurant:
# 1073
# http://www.yelp.com/biz/parker-korean-restaurant-singapore?osq=Restaurants
#
# Scraping from Casuarina Curry:
# 1074
# http://www.yelp.com/biz/casuarina-curry-singapore?osq=Restaurants
#
# Scraping from Uno Beef House:
# 1075
# http://www.yelp.com/biz/uno-beef-house-no-title?osq=Restaurants
# Sleep: 7s
#
# Scraping from Fu Shi Roasted Wanton Mee:
# 1076
# http://www.yelp.com/biz/fu-shi-roasted-wanton-mee-singapore-3?osq=Restaurants
#
# Scraping from Happy Garden Seafood:
# 1077
# http://www.yelp.com/biz/happy-garden-seafood-singapore?osq=Restaurants
# Sleep: 65s
# Restart scrapping from last url: i is 1077, Happy Garden Seafood
#
# Scraping from Happy Garden Seafood:
# 1077
# http://www.yelp.com/biz/happy-garden-seafood-singapore?osq=Restaurants
#
# Scraping from Wimbly Lu Chocolate.Cafe.Company:
# 1078
# http://www.yelp.com/biz/wimbly-lu-chocolate-cafe-company-singapore?osq=Restaurants
# http://www.yelp.com/biz/wimbly-lu-chocolate-cafe-company-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/wimbly-lu-chocolate-cafe-company-singapore?osq=Restaurants&start=20
#
# Scraping from Il Piccolo:
# 1079
# http://www.yelp.com/biz/il-piccolo-singapore-2?osq=Restaurants
# Saved to reviews_1080.csv
#
# Scraping from PP 881 Eating House:
# 1080
# http://www.yelp.com/biz/pp-881-eating-house-singapore?osq=Restaurants
#
# Scraping from Eighteen Chefs:
# 1081
# http://www.yelp.com/biz/eighteen-chefs-singapore-6?osq=Restaurants
#
# Scraping from Go-Ang Pratunam Chicken Rice:
# 1082
# http://www.yelp.com/biz/go-ang-pratunam-chicken-rice-singapore?osq=Restaurants
#
# Scraping from Ser Seng Herbs:
# 1083
# http://www.yelp.com/biz/ser-seng-herbs-singapore?osq=Restaurants
#
# Scraping from Fish & Chicks:
# 1084
# http://www.yelp.com/biz/fish-and-chicks-singapore-2?osq=Restaurants
#
# Scraping from Steam Box:
# 1085
# http://www.yelp.com/biz/steam-box-singapore?osq=Restaurants
#
# Scraping from Ocean Curry Fish Head:
# 1086
# http://www.yelp.com/biz/ocean-curry-fish-head-singapore-2?osq=Restaurants
#
# Scraping from Vava Bistro at Macritchie:
# 1087
# http://www.yelp.com/biz/vava-bistro-at-macritchie-singapore?osq=Restaurants
#
# Scraping from Siam Society:
# 1088
# http://www.yelp.com/biz/siam-society-singapore?osq=Restaurants
# Sleep: 10s
#
# Scraping from Fix:
# 1089
# http://www.yelp.com/biz/fix-singapore?osq=Restaurants
#
# Scraping from Roti Prata:
# 1090
# http://www.yelp.com/biz/roti-prata-singapore-2?osq=Restaurants
#
# Scraping from Tontei Pork Restaurant:
# 1091
# http://www.yelp.com/biz/tontei-pork-restaurant-singapore?osq=Restaurants
#
# Scraping from Tori-Q:
# 1092
# http://www.yelp.com/biz/tori-q-singapore-3?osq=Restaurants
#
# Scraping from AsterPau:
# 1093
# http://www.yelp.com/biz/asterpau-singapore-2?osq=Restaurants
#
# Scraping from Toa Payoh Lor 4 Market:
# 1094
# http://www.yelp.com/biz/toa-payoh-lor-4-market-singapore?osq=Restaurants
#
# Scraping from Pow Sing Restaurant:
# 1095
# http://www.yelp.com/biz/pow-sing-restaurant-singapore?osq=Restaurants
# Sleep: 65s
# Restart scrapping from last url: i is 1095, Pow Sing Restaurant
#
# Scraping from Pow Sing Restaurant:
# 1095
# http://www.yelp.com/biz/pow-sing-restaurant-singapore?osq=Restaurants
# http://www.yelp.com/biz/pow-sing-restaurant-singapore?osq=Restaurants&start=10
#
# Scraping from Hua Fong Kee Roasted Duck:
# 1096
# http://www.yelp.com/biz/hua-fong-kee-roasted-duck-singapore?osq=Restaurants
#
# Scraping from Yi Xin vegetarian:
# 1097
# http://www.yelp.com/biz/yi-xin-vegetarian-singapore?osq=Restaurants
#
# Scraping from Prata Wala:
# 1098
# http://www.yelp.com/biz/prata-wala-singapore-8?osq=Restaurants
#
# Scraping from Sarpino’s Pizzeria:
# 1099
# http://www.yelp.com/biz/sarpinos-pizzeria-singapore-16?osq=Restaurants
# Saved to reviews_1100.csv
#
# Scraping from Grumpy Bear:
# 1100
# http://www.yelp.com/biz/grumpy-bear-singapore?osq=Restaurants
#
# Scraping from Old Chang Kee:
# 1101
# http://www.yelp.com/biz/old-chang-kee-singapore-31?osq=Restaurants
#
# Scraping from Chomp Chomp Hai Wei Yuan Seafood BBQ:
# 1102
# http://www.yelp.com/biz/chomp-chomp-hai-wei-yuan-seafood-bbq-singapore?osq=Restaurants
#
# Scraping from Aone Claypot House:
# 1103
# http://www.yelp.com/biz/aone-claypot-house-singapore-2?osq=Restaurants
#
# Scraping from Stuff’D @ Junction 8:
# 1104
# http://www.yelp.com/biz/stuffd-junction-8-singapore?osq=Restaurants
# Sleep: 62s
# Restart scrapping from last url: i is 1104, Stuff’D @ Junction 8
#
# Scraping from Stuff’D @ Junction 8:
# 1104
# http://www.yelp.com/biz/stuffd-junction-8-singapore?osq=Restaurants
#
# Scraping from NGT Confectionery:
# 1105
# http://www.yelp.com/biz/ngt-confectionery-singapore?osq=Restaurants
# Sleep: 6s
#
# Scraping from Sembawang Hill Food Centre:
# 1106
# http://www.yelp.com/biz/sembawang-hill-food-centre-singapore?osq=Restaurants
#
# Scraping from Zhen Yi Vegetarian:
# 1107
# http://www.yelp.com/biz/zhen-yi-vegetarian-singapore?osq=Restaurants
# Sleep: 11s
#
# Scraping from Pin Xiang 品香:
# 1108
# http://www.yelp.com/biz/pin-xiang-%E5%93%81%E9%A6%99-singapore?osq=Restaurants
#
# Scraping from Kok Kee Turtle Soup:
# 1109
# http://www.yelp.com/biz/kok-kee-turtle-soup-singapore?osq=Restaurants
#
# Scraping from Ming Chu Chair Laoban:
# 1110
# http://www.yelp.com/biz/ming-chu-chair-laoban-singapore?osq=Restaurants
#
# Scraping from Suriya Curry House:
# 1111
# http://www.yelp.com/biz/suriya-curry-house-singapore?osq=Restaurants
#
# Scraping from Gu Ma Jia Private Kitchen:
# 1112
# http://www.yelp.com/biz/gu-ma-jia-private-kitchen-singapore?osq=Restaurants
#
# Scraping from Ikura Japanese:
# 1113
# http://www.yelp.com/biz/ikura-japanese-singapore-2?osq=Restaurants
#
# Scraping from Elemen:
# 1114
# http://www.yelp.com/biz/elemen-singapore-2?osq=Restaurants
#
# Scraping from Hiang Ji Roasted Meat Noodle House:
# 1115
# http://www.yelp.com/biz/hiang-ji-roasted-meat-noodle-house-singapore?osq=Restaurants
#
# Scraping from Thus Coffee:
# 1116
# http://www.yelp.com/biz/thus-coffee-singapore?osq=Restaurants
# Sleep: 75s
# Restart scrapping from last url: i is 1116, Thus Coffee
#
# Scraping from Thus Coffee:
# 1116
# http://www.yelp.com/biz/thus-coffee-singapore?osq=Restaurants
#
# Scraping from The Famous Ice-Cream Rolls Shop:
# 1117
# http://www.yelp.com/biz/the-famous-ice-cream-rolls-shop-singapore?osq=Restaurants
#
# Scraping from Food Junction:
# 1118
# http://www.yelp.com/biz/food-junction-singapore-13?osq=Restaurants
#
# Scraping from Siam Kitchen:
# 1119
# http://www.yelp.com/biz/siam-kitchen-singapore-3?osq=Restaurants
# Sleep: 5s
# Saved to reviews_1120.csv
#
# Scraping from Restaurant Hoshigaoka:
# 1120
# http://www.yelp.com/biz/restaurant-hoshigaoka-singapore-3?osq=Restaurants
#
# Scraping from Mos Burger:
# 1121
# http://www.yelp.com/biz/mos-burger-singapore-2?osq=Restaurants
#
# Scraping from Liao Fan Hawker Chan:
# 1122
# http://www.yelp.com/biz/liao-fan-hawker-chan-singapore-6?osq=Restaurants
# Sleep: 6s
#
# Scraping from KFC:
# 1123
# http://www.yelp.com/biz/kfc-singapore-21?osq=Restaurants
#
# Scraping from PastaMania:
# 1124
# http://www.yelp.com/biz/pastamania-singapore-36?osq=Restaurants
#
# Scraping from Chicken House:
# 1125
# http://www.yelp.com/biz/chicken-house-singapore?osq=Restaurants
#
# Scraping from Ah De Hainanese Chicken Rice:
# 1126
# http://www.yelp.com/biz/ah-de-hainanese-chicken-rice-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Fong Kee Delicacies:
# 1127
# http://www.yelp.com/biz/fong-kee-delicacies-singapore?osq=Restaurants
# Sleep: 14s
#
# Scraping from SG Rainbow Cafe:
# 1128
# http://www.yelp.com/biz/sg-rainbow-cafe-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Gourmet Paradise:
# 1129
# http://www.yelp.com/biz/gourmet-paradise-singapore?osq=Restaurants
#
# Scraping from Jack’s Place:
# 1130
# http://www.yelp.com/biz/jacks-place-singapore-10?osq=Restaurants
#
# Scraping from Men-Ichi:
# 1131
# http://www.yelp.com/biz/men-ichi-singapore?osq=Restaurants
#
# Scraping from Pastamania:
# 1132
# http://www.yelp.com/biz/pastamania-singapore-7?osq=Restaurants
#
# Scraping from Teochew Handmade Pau:
# 1133
# http://www.yelp.com/biz/teochew-handmade-pau-singapore-2?osq=Restaurants
#
# Scraping from Tian Wai Tian Steamboat:
# 1134
# http://www.yelp.com/biz/tian-wai-tian-steamboat-singapore-2?osq=Restaurants
#
# Scraping from Sync Korean Tapas Bar:
# 1135
# http://www.yelp.com/biz/sync-korean-tapas-bar-singapore?osq=Restaurants
#
# Scraping from R K Eating House:
# 1136
# http://www.yelp.com/biz/r-k-eating-house-singapore-2?osq=Restaurants
# http://www.yelp.com/biz/r-k-eating-house-singapore-2?osq=Restaurants&start=10
#
# Scraping from Ben’s Western Bar:
# 1137
# http://www.yelp.com/biz/bens-western-bar-singapore?osq=Restaurants
#
# Scraping from Old Long House Popiah:
# 1138
# http://www.yelp.com/biz/old-long-house-popiah-singapore?osq=Restaurants
#
# Scraping from The Dragon Chamber:
# 1139
# http://www.yelp.com/biz/the-dragon-chamber-singapore?osq=Restaurants
# Sleep: 5s
# Saved to reviews_1140.csv
#
# Scraping from Sahara:
# 1140
# http://www.yelp.com/biz/sahara-singapore?osq=Restaurants
#
# Scraping from OmoteNashi Dining Gosso:
# 1141
# http://www.yelp.com/biz/omotenashi-dining-gosso-singapore-4?osq=Restaurants
#
# Scraping from My Little Spanish Place:
# 1142
# http://www.yelp.com/biz/my-little-spanish-place-singapore-2?osq=Restaurants
#
# Scraping from Osteria L’operetta Pizzeria:
# 1143
# http://www.yelp.com/biz/osteria-l-operetta-pizzeria-singapore-2?osq=Restaurants
# Sleep: 7s
#
# Scraping from Beef Yakiniku Dining Yakiniquest:
# 1144
# http://www.yelp.com/biz/beef-yakiniku-dining-yakiniquest-singapore?osq=Restaurants
# Sleep: 63s
# Restart scrapping from last url: i is 1144, Beef Yakiniku Dining Yakiniquest
#
# Scraping from Beef Yakiniku Dining Yakiniquest:
# 1144
# http://www.yelp.com/biz/beef-yakiniku-dining-yakiniquest-singapore?osq=Restaurants
#
# Scraping from Throwback:
# 1145
# http://www.yelp.com/biz/throwback-singapore?osq=Restaurants
#
# Scraping from Viet Pho:
# 1146
# http://www.yelp.com/biz/viet-pho-singapore?osq=Restaurants
# Sleep: 13s
#
# Scraping from Neko no Niwa:
# 1147
# http://www.yelp.com/biz/neko-no-niwa-singapore?osq=Restaurants
#
# Scraping from Imakatsu Boat Quay:
# 1148
# http://www.yelp.com/biz/imakatsu-boat-quay-singapore-2?osq=Restaurants
# Sleep: 5s
#
# Scraping from King Kebabs:
# 1149
# http://www.yelp.com/biz/king-kebabs-singapore?osq=Restaurants
#
# Scraping from 109 Teochew Yong Tau Foo:
# 1150
# http://www.yelp.com/biz/109-teochew-yong-tau-foo-singapore-3?osq=Restaurants
#
# Scraping from Marco Marco:
# 1151
# http://www.yelp.com/biz/marco-marco-singapore-4?osq=Restaurants
#
# Scraping from Sinar Pagi Nasi Padang:
# 1152
# http://www.yelp.com/biz/sinar-pagi-nasi-padang-singapore?osq=Restaurants
#
# Scraping from Braci:
# 1153
# http://www.yelp.com/biz/braci-singapore?osq=Restaurants
# Sleep: 66s
# Restart scrapping from last url: i is 1153, Braci
#
# Scraping from Braci:
# 1153
# http://www.yelp.com/biz/braci-singapore?osq=Restaurants
#
# Scraping from The Container Japanese Wagyu Tapas & Bar:
# 1154
# http://www.yelp.com/biz/the-container-japanese-wagyu-tapas-and-bar-singapore?osq=Restaurants
#
# Scraping from Tong Xin Ru Yi Traditional Hotpot:
# 1155
# http://www.yelp.com/biz/tong-xin-ru-yi-traditional-hotpot-singapore?osq=Restaurants
#
# Scraping from Indian House Boat Quay:
# 1156
# http://www.yelp.com/biz/indian-house-boat-quay-singapore?osq=Restaurants
#
# Scraping from PurPle TurTle:
# 1157
# http://www.yelp.com/biz/purple-turtle-singapore?osq=Restaurants
#
# Scraping from BK Eating House:
# 1158
# http://www.yelp.com/biz/bk-eating-house-singapore?osq=Restaurants
# Sleep: 74s
# Restart scrapping from last url: i is 1158, BK Eating House
#
# Scraping from BK Eating House:
# 1158
# http://www.yelp.com/biz/bk-eating-house-singapore?osq=Restaurants
#
# Scraping from Meat And Green:
# 1159
# http://www.yelp.com/biz/meat-and-green-singapore?osq=Restaurants
# Saved to reviews_1160.csv
#
# Scraping from Vasco:
# 1160
# http://www.yelp.com/biz/vasco-singapore?osq=Restaurants
#
# Scraping from Un-Yang-Kor-Dai:
# 1161
# http://www.yelp.com/biz/un-yang-kor-dai-no-title?osq=Restaurants
#
# Scraping from Killiney Kopitiam:
# 1162
# http://www.yelp.com/biz/killiney-kopitiam-singapore-5?osq=Restaurants
#
# Scraping from Shah Alam:
# 1163
# http://www.yelp.com/biz/shah-alam-singapore?osq=Restaurants
#
# Scraping from Macpherson BBQ Seafood:
# 1164
# http://www.yelp.com/biz/macpherson-bbq-seafood-singapore?osq=Restaurants
#
# Scraping from Hung Kang Teochew Restaurant:
# 1165
# http://www.yelp.com/biz/hung-kang-teochew-restaurant-singapore?osq=Restaurants
#
# Scraping from Roll Up:
# 1166
# http://www.yelp.com/biz/roll-up-singapore?osq=Restaurants
# Sleep: 14s
#
# Scraping from Harvest Seafood Restaurant:
# 1167
# http://www.yelp.com/biz/harvest-seafood-restaurant-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from ;D Happy Factory:
# 1168
# http://www.yelp.com/biz/d-happy-factory-singapore?osq=Restaurants
#
# Scraping from Tom Yum Kungfu:
# 1169
# http://www.yelp.com/biz/tom-yum-kungfu-singapore-5?osq=Restaurants
#
# Scraping from Tian Tian Fisherman’s Pier Seafood Restaurant:
# 1170
# http://www.yelp.com/biz/tian-tian-fishermans-pier-seafood-restaurant-singapore?osq=Restaurants
# http://www.yelp.com/biz/tian-tian-fishermans-pier-seafood-restaurant-singapore?osq=Restaurants&start=10
#
# Scraping from Mogambo Bar and Restaurant:
# 1171
# http://www.yelp.com/biz/mogambo-bar-and-restaurant-singapore?osq=Restaurants
#
# Scraping from Ah Ter Teochew Fishball Noodle Bar:
# 1172
# http://www.yelp.com/biz/ah-ter-teochew-fishball-noodle-bar-singapore?osq=Restaurants
#
# Scraping from Sushi Sabu-Roku:
# 1173
# http://www.yelp.com/biz/sushi-sabu-roku-singapore?osq=Restaurants
#
# Scraping from Jin De Lai Zhong Hua La Mian:
# 1174
# http://www.yelp.com/biz/jin-de-lai-zhong-hua-la-mian-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Dehesa:
# 1175
# http://www.yelp.com/biz/dehesa-singapore?osq=Restaurants
#
# Scraping from Maharajah:
# 1176
# http://www.yelp.com/biz/maharajah-singapore?osq=Restaurants
#
# Scraping from Charlie’s Tapas Grill & Bar:
# 1177
# http://www.yelp.com/biz/charlies-tapas-grill-and-bar-singapore?osq=Restaurants
#
# Scraping from Dot & Dash:
# 1178
# http://www.yelp.com/biz/dot-and-dash-singapore?osq=Restaurants
#
# Scraping from DePizza:
# 1179
# http://www.yelp.com/biz/depizza-no-title-2?osq=Restaurants
# Saved to reviews_1180.csv
#
# Scraping from Amò:
# 1180
# http://www.yelp.com/biz/am%C3%B2-singapore?osq=Restaurants
#
# Scraping from Tsuiteru Sakaba Kushikatsu Maido:
# 1181
# http://www.yelp.com/biz/tsuiteru-sakaba-kushikatsu-maido-singapore?osq=Restaurants
#
# Scraping from Wang Dae Bak Korean BBQ:
# 1182
# http://www.yelp.com/biz/wang-dae-bak-korean-bbq-singapore?osq=Restaurants
#
# Scraping from Wakanui:
# 1183
# http://www.yelp.com/biz/wakanui-singapore?osq=Restaurants
# Sleep: 7s
# http://www.yelp.com/biz/wakanui-singapore?osq=Restaurants&start=10
#
# Scraping from Waa Cow! Sushi Bar:
# 1184
# http://www.yelp.com/biz/waa-cow-sushi-bar-singapore?osq=Restaurants
# Sleep: 14s
#
# Scraping from Superstar K:
# 1185
# http://www.yelp.com/biz/superstar-k-singapore-2?osq=Restaurants
#
# Scraping from Haldhi:
# 1186
# http://www.yelp.com/biz/haldhi-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Ramen Matsuri:
# 1187
# http://www.yelp.com/biz/ramen-matsuri-singapore?osq=Restaurants
#
# Scraping from Ramen Bar Suzuki:
# 1188
# http://www.yelp.com/biz/ramen-bar-suzuki-singapore?osq=Restaurants
# http://www.yelp.com/biz/ramen-bar-suzuki-singapore?osq=Restaurants&start=10
#
# Scraping from Enoteca L’Operetta:
# 1189
# http://www.yelp.com/biz/enoteca-l-operetta-singapore?osq=Restaurants
#
# Scraping from Haramiya Japanese BBQ Restaurant:
# 1190
# http://www.yelp.com/biz/haramiya-japanese-bbq-restaurant-singapore?osq=Restaurants
#
# Scraping from Warehouse Bistro:
# 1191
# http://www.yelp.com/biz/warehouse-bistro-singapore?osq=Restaurants
#
# Scraping from Fill-a-Pita:
# 1192
# http://www.yelp.com/biz/fill-a-pita-singapore-2?osq=Restaurants
#
# Scraping from Barber Shop by Timbre:
# 1193
# http://www.yelp.com/biz/barber-shop-by-timbre-singapore?osq=Restaurants
# Sleep: 76s
# Restart scrapping from last url: i is 1193, Barber Shop by Timbre
#
# Scraping from Barber Shop by Timbre:
# 1193
# http://www.yelp.com/biz/barber-shop-by-timbre-singapore?osq=Restaurants
#
# Scraping from The Rotisserie:
# 1194
# http://www.yelp.com/biz/the-rotisserie-singapore-6?osq=Restaurants
# Sleep: 75s
# Restart scrapping from last url: i is 1194, The Rotisserie
#
# Scraping from The Rotisserie:
# 1194
# http://www.yelp.com/biz/the-rotisserie-singapore-6?osq=Restaurants
#
# Scraping from Pita Tree Mediterranean Kitchen & Bar:
# 1195
# http://www.yelp.com/biz/pita-tree-mediterranean-kitchen-and-bar-no-title?osq=Restaurants
#
# Scraping from Riverwalk Tandoor:
# 1196
# http://www.yelp.com/biz/riverwalk-tandoor-singapore?osq=Restaurants
#
# Scraping from Fuqing Seafood:
# 1197
# http://www.yelp.com/biz/fuqing-seafood-singapore?osq=Restaurants
#
# Scraping from Aroy Dee Thai Kitchen:
# 1198
# http://www.yelp.com/biz/aroy-dee-thai-kitchen-singapore-2?osq=Restaurants
#
# Scraping from Mouth Restaurant:
# 1199
# http://www.yelp.com/biz/mouth-restaurant-singapore-4?osq=Restaurants
# Sleep: 7s
# Saved to reviews_1200.csv
#
# Scraping from Shinzo Japanese Cuisine:
# 1200
# http://www.yelp.com/biz/shinzo-japanese-cuisine-singapore?osq=Restaurants
#
# Scraping from Lime Restaurant:
# 1201
# http://www.yelp.com/biz/lime-restaurant-singapore?osq=Restaurants
# http://www.yelp.com/biz/lime-restaurant-singapore?osq=Restaurants&start=10
#
# Scraping from Tao’s Restaurant:
# 1202
# http://www.yelp.com/biz/taos-restaurant-singapore?osq=Restaurants
# Sleep: 11s
#
# Scraping from The Burger Bar:
# 1203
# http://www.yelp.com/biz/the-burger-bar-singapore-7?osq=Restaurants
#
# Scraping from Seoulria Korean Restaurant:
# 1204
# http://www.yelp.com/biz/seoulria-korean-restaurant-singapore?osq=Restaurants
#
# Scraping from Si Chuan Dou Hua:
# 1205
# http://www.yelp.com/biz/si-chuan-dou-hua-singapore?osq=Restaurants
# Sleep: 5s
# http://www.yelp.com/biz/si-chuan-dou-hua-singapore?osq=Restaurants&start=10
#
# Scraping from Professor Brawn Cafe:
# 1206
# http://www.yelp.com/biz/professor-brawn-cafe-singapore-2?osq=Restaurants
#
# Scraping from Naruto Izakaya:
# 1207
# http://www.yelp.com/biz/naruto-izakaya-singapore?osq=Restaurants
#
# Scraping from McDonald’s:
# 1208
# http://www.yelp.com/biz/mcdonalds-singapore-79?osq=Restaurants
#
# Scraping from Our Village-Authentic North Indian Village Cuisine:
# 1209
# http://www.yelp.com/biz/our-village-authentic-north-indian-village-cuisine-singapore?osq=Restaurants
#
# Scraping from Aura:
# 1210
# http://www.yelp.com/biz/aura-singapore-4?osq=Restaurants
# http://www.yelp.com/biz/aura-singapore-4?osq=Restaurants&start=10
# Sleep: 7s
# http://www.yelp.com/biz/aura-singapore-4?osq=Restaurants&start=20
#
# Scraping from 8 Korean BBQ:
# 1211
# http://www.yelp.com/biz/8-korean-bbq-singapore?osq=Restaurants
# http://www.yelp.com/biz/8-korean-bbq-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/8-korean-bbq-singapore?osq=Restaurants&start=20
# Sleep: 7s
#
# Scraping from Ricciotti:
# 1212
# http://www.yelp.com/biz/ricciotti-singapore-3?osq=Restaurants
# http://www.yelp.com/biz/ricciotti-singapore-3?osq=Restaurants&start=10
#
# Scraping from WANNA CUPPA:
# 1213
# http://www.yelp.com/biz/wanna-cuppa-singapore?osq=Restaurants
#
# Scraping from Southbank Authentic Thai:
# 1214
# http://www.yelp.com/biz/southbank-authentic-thai-singapore?osq=Restaurants
#
# Scraping from The Salted Plum:
# 1215
# http://www.yelp.com/biz/the-salted-plum-singapore?osq=Restaurants
#
# Scraping from Thai Affair:
# 1216
# http://www.yelp.com/biz/thai-affair-singapore-2?osq=Restaurants
# Sleep: 11s
#
# Scraping from Teh Tarik Time:
# 1217
# http://www.yelp.com/biz/teh-tarik-time-singapore?osq=Restaurants
#
# Scraping from Kintaro Bento:
# 1218
# http://www.yelp.com/biz/kintaro-bento-singapore?osq=Restaurants
#
# Scraping from Tiong Bahru Hainanese Boneless Chicken Rice & Curry Rice:
# 1219
# http://www.yelp.com/biz/tiong-bahru-hainanese-boneless-chicken-rice-and-curry-rice-singapore?osq=Restaurants
# Sleep: 6s
# Saved to reviews_1220.csv
#
# Scraping from Koji Sushi Bar - Pickering Branch:
# 1220
# http://www.yelp.com/biz/koji-sushi-bar-pickering-branch-singapore?osq=Restaurants
#
# Scraping from The Hitsuji Club:
# 1221
# http://www.yelp.com/biz/the-hitsuji-club-singapore?osq=Restaurants
# Sleep: 6s
#
# Scraping from Golden Shoe Nasi Lemak:
# 1222
# http://www.yelp.com/biz/golden-shoe-nasi-lemak-singapore?osq=Restaurants
# Sleep: 69s
# Restart scrapping from last url: i is 1222, Golden Shoe Nasi Lemak
#
# Scraping from Golden Shoe Nasi Lemak:
# 1222
# http://www.yelp.com/biz/golden-shoe-nasi-lemak-singapore?osq=Restaurants
# Sleep: 79s
# Restart scrapping from last url: i is 1222, Golden Shoe Nasi Lemak
#
# Scraping from Golden Shoe Nasi Lemak:
# 1222
# http://www.yelp.com/biz/golden-shoe-nasi-lemak-singapore?osq=Restaurants
#
# Scraping from Colombo Restaurant Authentic Shri Lankan Cuisine:
# 1223
# http://www.yelp.com/biz/colombo-restaurant-authentic-shri-lankan-cuisine-singapore?osq=Restaurants
#
# Scraping from Sque Rotisserie and Alehouse:
# 1224
# http://www.yelp.com/biz/sque-rotisserie-and-alehouse-singapore?osq=Restaurants
#
# Scraping from Forum Restaurant:
# 1225
# http://www.yelp.com/biz/forum-restaurant-singapore?osq=Restaurants
#
# Scraping from Lucky Cafe:
# 1226
# http://www.yelp.com/biz/lucky-cafe-singapore?osq=Restaurants
#
# Scraping from seem reap II:
# 1227
# http://www.yelp.com/biz/seem-reap-ii-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Stellar at 1-Altitude:
# 1228
# http://www.yelp.com/biz/stellar-at-1-altitude-singapore?osq=Restaurants
# http://www.yelp.com/biz/stellar-at-1-altitude-singapore?osq=Restaurants&start=10
#
# Scraping from Bq Bar:
# 1229
# http://www.yelp.com/biz/bq-bar-singapore?osq=Restaurants
#
# Scraping from Dharma’s Kebab Shop:
# 1230
# http://www.yelp.com/biz/dharmas-kebab-shop-singapore?osq=Restaurants
#
# Scraping from Ya Kun Kaya Toast:
# 1231
# http://www.yelp.com/biz/ya-kun-kaya-toast-singapore-32?osq=Restaurants
#
# Scraping from Molly Malone’s Irish Pub:
# 1232
# http://www.yelp.com/biz/molly-malones-irish-pub-singapore?osq=Restaurants
#
# Scraping from Shabu Sai:
# 1233
# http://www.yelp.com/biz/shabu-sai-singapore-6?osq=Restaurants
# Sleep: 6s
#
# Scraping from East Treasure:
# 1234
# http://www.yelp.com/biz/east-treasure-singapore?osq=Restaurants
#
# Scraping from Healthy Soba IKI:
# 1235
# http://www.yelp.com/biz/healthy-soba-iki-singapore?osq=Restaurants
# Sleep: 13s
#
# Scraping from Kotobuki:
# 1236
# http://www.yelp.com/biz/kotobuki-singapore-4?osq=Restaurants
# Sleep: 5s
#
# Scraping from SEAR:
# 1237
# http://www.yelp.com/biz/sear-singapore?osq=Restaurants
#
# Scraping from Gangnam Corndog:
# 1238
# http://www.yelp.com/biz/gangnam-corndog-singapore?osq=Restaurants
#
# Scraping from Peach Garden:
# 1239
# http://www.yelp.com/biz/peach-garden-singapore-10?osq=Restaurants
# Saved to reviews_1240.csv
#
# Scraping from Bōruto:
# 1240
# http://www.yelp.com/biz/b%C5%8Druto-singapore?osq=Restaurants
#
# Scraping from Courtyard Cafe & Lounge:
# 1241
# http://www.yelp.com/biz/courtyard-cafe-and-lounge-singapore?osq=Restaurants
#
# Scraping from Guzman Y Gomez:
# 1242
# http://www.yelp.com/biz/guzman-y-gomez-singapore-2?osq=Restaurants
#
# Scraping from Tae Woo Korean Restaurant:
# 1243
# http://www.yelp.com/biz/tae-woo-korean-restaurant-singapore?osq=Restaurants
#
# Scraping from TCC The Connoiseur Concerto:
# 1244
# http://www.yelp.com/biz/tcc-the-connoiseur-concerto-singapore-2?osq=Restaurants
#
# Scraping from Bottles & Bones:
# 1245
# http://www.yelp.com/biz/bottles-and-bones-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Aglio Olio:
# 1246
# http://www.yelp.com/biz/aglio-olio-singapore?osq=Restaurants
#
# Scraping from Omnivore:
# 1247
# http://www.yelp.com/biz/omnivore-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Upper Crust:
# 1248
# http://www.yelp.com/biz/upper-crust-singapore?osq=Restaurants
#
# Scraping from Rendezvous Restaurant Hock Lock Kee:
# 1249
# http://www.yelp.com/biz/rendezvous-restaurant-hock-lock-kee-singapore-2?osq=Restaurants
# http://www.yelp.com/biz/rendezvous-restaurant-hock-lock-kee-singapore-2?osq=Restaurants&start=10
#
# Scraping from O’Parl Cafe:
# 1250
# http://www.yelp.com/biz/o-parl-cafe-singapore?osq=Restaurants
#
# Scraping from Pasta Fresca Da Salvatore:
# 1251
# http://www.yelp.com/biz/pasta-fresca-da-salvatore-singapore-4?osq=Restaurants
# Sleep: 6s
#
# Scraping from Sun Korean Food:
# 1252
# http://www.yelp.com/biz/sun-korean-food-singapore?osq=Restaurants
#
# Scraping from Art:
# 1253
# http://www.yelp.com/biz/art-singapore-2?osq=Restaurants
#
# Scraping from Platypus Lobster Shack:
# 1254
# http://www.yelp.com/biz/platypus-lobster-shack-singapore?osq=Restaurants
# Sleep: 75s
# Restart scrapping from last url: i is 1254, Platypus Lobster Shack
#
# Scraping from Platypus Lobster Shack:
# 1254
# http://www.yelp.com/biz/platypus-lobster-shack-singapore?osq=Restaurants
# Sleep: 12s
#
# Scraping from An Kee Duck Rice And Kway Chap:
# 1255
# http://www.yelp.com/biz/an-kee-duck-rice-and-kway-chap-singapore?osq=Restaurants
# Sleep: 77s
# Restart scrapping from last url: i is 1255, An Kee Duck Rice And Kway Chap
#
# Scraping from An Kee Duck Rice And Kway Chap:
# 1255
# http://www.yelp.com/biz/an-kee-duck-rice-and-kway-chap-singapore?osq=Restaurants
#
# Scraping from nomVnom Bistro:
# 1256
# http://www.yelp.com/biz/nomvnom-bistro-singapore?osq=Restaurants
# http://www.yelp.com/biz/nomvnom-bistro-singapore?osq=Restaurants&start=10
#
# Scraping from SaladStop:
# 1257
# http://www.yelp.com/biz/saladstop-singapore-2?osq=Restaurants
#
# Scraping from Beng Thin Hoon Kee:
# 1258
# http://www.yelp.com/biz/beng-thin-hoon-kee-singapore?osq=Restaurants
#
# Scraping from Fresh Congee:
# 1259
# http://www.yelp.com/biz/fresh-congee-singapore?osq=Restaurants
# Saved to reviews_1260.csv
#
# Scraping from Mitsuba by Yurine Japanese Restaurant:
# 1260
# http://www.yelp.com/biz/mitsuba-by-yurine-japanese-restaurant-singapore?osq=Restaurants
#
# Scraping from Aayisha Briyani House:
# 1261
# http://www.yelp.com/biz/aayisha-briyani-house-singapore?osq=Restaurants
# Sleep: 6s
#
# Scraping from Wall Street Deli Cafe:
# 1262
# http://www.yelp.com/biz/wall-street-deli-cafe-singapore?osq=Restaurants
#
# Scraping from Yan:
# 1263
# http://www.yelp.com/biz/yan-singapore?osq=Restaurants
#
# Scraping from Nom Vnom:
# 1264
# http://www.yelp.com/biz/nom-vnom-singapore?osq=Restaurants
#
# Scraping from Maison Kayser:
# 1265
# http://www.yelp.com/biz/maison-kayser-singapore-5?osq=Restaurants
#
# Scraping from Lao Song Huat Fishball Noodle:
# 1266
# http://www.yelp.com/biz/lao-song-huat-fishball-noodle-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Yakun Kaya Toast:
# 1267
# http://www.yelp.com/biz/yakun-kaya-toast-singapore?osq=Restaurants
#
# Scraping from The Well:
# 1268
# http://www.yelp.com/biz/the-well-singapore?osq=Restaurants
#
# Scraping from Teepee Bar & Restaurant:
# 1269
# http://www.yelp.com/biz/teepee-bar-and-restaurant-singapore?osq=Restaurants
#
# Scraping from O’Bean Organic Soya Store:
# 1270
# http://www.yelp.com/biz/o-bean-organic-soya-store-singapore-3?osq=Restaurants
# Sleep: 6s
#
# Scraping from D’Bell:
# 1271
# http://www.yelp.com/biz/d-bell-singapore?osq=Restaurants
#
# Scraping from Marutama Ramen:
# 1272
# http://www.yelp.com/biz/marutama-ramen-singapore-5?osq=Restaurants
# http://www.yelp.com/biz/marutama-ramen-singapore-5?osq=Restaurants&start=10
# Sleep: 6s
# Sleep: 13s
# http://www.yelp.com/biz/marutama-ramen-singapore-5?osq=Restaurants&start=20
#
# Scraping from Tiong Bahru Pau:
# 1273
# http://www.yelp.com/biz/tiong-bahru-pau-singapore?osq=Restaurants
#
# Scraping from Muhammed King’s Prata:
# 1274
# http://www.yelp.com/biz/muhammed-kings-prata-no-title?osq=Restaurants
#
# Scraping from Fo You Yuan Vegetarian Restaurant:
# 1275
# http://www.yelp.com/biz/fo-you-yuan-vegetarian-restaurant-singapore?osq=Restaurants
#
# Scraping from Dimbulah:
# 1276
# http://www.yelp.com/biz/dimbulah-singapore-3?osq=Restaurants
#
# Scraping from Kraftwich by Swissbake:
# 1277
# http://www.yelp.com/biz/kraftwich-by-swissbake-singapore-3?osq=Restaurants
# Sleep: 7s
#
# Scraping from Tamashii Robataya:
# 1278
# http://www.yelp.com/biz/tamashii-robataya-singapore?osq=Restaurants
#
# Scraping from Om nom Taste Of Thai:
# 1279
# http://www.yelp.com/biz/om-nom-taste-of-thai-singapore?osq=Restaurants
# Saved to reviews_1280.csv
#
# Scraping from The Salad Shop:
# 1280
# http://www.yelp.com/biz/the-salad-shop-singapore?osq=Restaurants
# Sleep: 6s
#
# Scraping from La Lola Churreria:
# 1281
# http://www.yelp.com/biz/la-lola-churreria-singapore?osq=Restaurants
#
# Scraping from Kiraku:
# 1282
# http://www.yelp.com/biz/kiraku-singapore?osq=Restaurants
#
# Scraping from McDonald’s:
# 1283
# ...
#
# Scraping from Hong Kong Style Chee Cheong Fun:
# 1621
# http://www.yelp.com/biz/hong-kong-style-chee-cheong-fun-singapore?osq=Restaurants
#
# Scraping from Cafe Football:
# 1622
# http://www.yelp.com/biz/cafe-football-singapore?osq=Restaurants
#
# Scraping from Guan Chee Hong Kong Roasted Duck:
# 1623
# http://www.yelp.com/biz/guan-chee-hong-kong-roasted-duck-singapore?osq=Restaurants
#
# Scraping from Jack’s Place:
# 1624
# http://www.yelp.com/biz/jacks-place-singapore-2?osq=Restaurants
#
# Scraping from Kelly Jie Seafood:
# 1625
# http://www.yelp.com/biz/kelly-jie-seafood-singapore?osq=Restaurants
# Sleep: 6s
# http://www.yelp.com/biz/kelly-jie-seafood-singapore?osq=Restaurants&start=10
#
# Scraping from Harry’s:
# 1626
# http://www.yelp.com/biz/harrys-singapore-14?osq=Restaurants
#
# Scraping from 23 Jumpin:
# 1627
# http://www.yelp.com/biz/23-jumpin-singapore?osq=Restaurants
#
# Scraping from Himawari Japanese Restaurant:
# 1628
# http://www.yelp.com/biz/himawari-japanese-restaurant-singapore-2?osq=Restaurants
#
# Scraping from Eng Ho Fried Hokkien Mee:
# 1629
# http://www.yelp.com/biz/eng-ho-fried-hokkien-mee-singapore?osq=Restaurants
#
# Scraping from Makisan:
# 1630
# http://www.yelp.com/biz/makisan-singapore-2?osq=Restaurants
#
# Scraping from Hup Chong Yong Tau Foo:
# 1631
# http://www.yelp.com/biz/hup-chong-yong-tau-foo-singapore?osq=Restaurants
#
# Scraping from Soon huat Bak Kut Teh:
# 1632
# http://www.yelp.com/biz/soon-huat-bak-kut-teh-singapore?osq=Restaurants
#
# Scraping from Cheng Kee Beef Kway Teow:
# 1633
# http://www.yelp.com/biz/cheng-kee-beef-kway-teow-singapore?osq=Restaurants
#
# Scraping from First Street Teochew Fish Soup:
# 1634
# http://www.yelp.com/biz/first-street-teochew-fish-soup-singapore?osq=Restaurants
#
# Scraping from Tom Yum Kungfu:
# 1635
# http://www.yelp.com/biz/tom-yum-kungfu-singapore-4?osq=Restaurants
#
# Scraping from Epic Haus:
# 1636
# http://www.yelp.com/biz/epic-haus-singapore-2?osq=Restaurants
#
# Scraping from Xing Hua Lou:
# 1637
# http://www.yelp.com/biz/xing-hua-lou-singapore?osq=Restaurants
#
# Scraping from Crab At Bay:
# 1638
# http://www.yelp.com/biz/crab-at-bay-singapore?osq=Restaurants
# Sleep: 6s
# Sleep: 10s
#
# Scraping from GLC Restaurant:
# 1639
# http://www.yelp.com/biz/glc-restaurant-singapore?osq=Restaurants
# Saved to reviews_1640.csv
#
# Scraping from IVINS Nyonya Specialist:
# 1640
# http://www.yelp.com/biz/ivins-nyonya-specialist-singapore?osq=Restaurants
#
# Scraping from Truly Test Kitchen:
# 1641
# http://www.yelp.com/biz/truly-test-kitchen-singapore?osq=Restaurants
#
# Scraping from Lavarock Food Holdings:
# 1642
# http://www.yelp.com/biz/lavarock-food-holdings-singapore?osq=Restaurants
#
# Scraping from Hanwoori Korean Restaurant:
# 1643
# http://www.yelp.com/biz/hanwoori-korean-restaurant-singapore?osq=Restaurants
# Sleep: 71s
# Restart scrapping from last url: i is 1643, Hanwoori Korean Restaurant
#
# Scraping from Hanwoori Korean Restaurant:
# 1643
# http://www.yelp.com/biz/hanwoori-korean-restaurant-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Ponggol Nasi Lemak:
# 1644
# http://www.yelp.com/biz/ponggol-nasi-lemak-singapore-2?osq=Restaurants
#
# Scraping from Dingtele:
# 1645
# http://www.yelp.com/biz/dingtele-singapore?osq=Restaurants
#
# Scraping from Niche Savoureuse:
# 1646
# http://www.yelp.com/biz/niche-savoureuse-singapore?osq=Restaurants
#
# Scraping from Sakon Thai:
# 1647
# http://www.yelp.com/biz/sakon-thai-singapore?osq=Restaurants
#
# Scraping from Tuk Tuk Cha:
# 1648
# http://www.yelp.com/biz/tuk-tuk-cha-singapore-8?osq=Restaurants
# Sleep: 77s
# Restart scrapping from last url: i is 1648, Tuk Tuk Cha
#
# Scraping from Tuk Tuk Cha:
# 1648
# http://www.yelp.com/biz/tuk-tuk-cha-singapore-8?osq=Restaurants
#
# Scraping from The Flame Cafe:
# 1649
# http://www.yelp.com/biz/the-flame-cafe-singapore?osq=Restaurants
#
# Scraping from The Larder Cafe:
# 1650
# http://www.yelp.com/biz/the-larder-cafe-singapore?osq=Restaurants
#
# Scraping from KING OMAR Restaurant:
# 1651
# http://www.yelp.com/biz/king-omar-restaurant-singapore?osq=Restaurants
#
# Scraping from Dessert Bowl:
# 1652
# http://www.yelp.com/biz/dessert-bowl-singapore-2?osq=Restaurants
# http://www.yelp.com/biz/dessert-bowl-singapore-2?osq=Restaurants&start=10
#
# Scraping from Top Table:
# 1653
# http://www.yelp.com/biz/top-table-singapore?osq=Restaurants
#
# Scraping from Din Tai Fung:
# 1654
# http://www.yelp.com/biz/din-tai-fung-singapore-30?osq=Restaurants
#
# Scraping from Bugis Street Chuen Chuen:
# 1655
# http://www.yelp.com/biz/bugis-street-chuen-chuen-singapore?osq=Restaurants
#
# Scraping from Arirang Korean Restaurant:
# 1656
# http://www.yelp.com/biz/arirang-korean-restaurant-singapore?osq=Restaurants
#
# Scraping from Peranakan Flavors:
# 1657
# http://www.yelp.com/biz/peranakan-flavors-singapore-2?osq=Restaurants
# Sleep: 12s
#
# Scraping from Chin Chin Restaurant:
# 1658
# http://www.yelp.com/biz/chin-chin-restaurant-singapore?osq=Restaurants
# Sleep: 7s
# http://www.yelp.com/biz/chin-chin-restaurant-singapore?osq=Restaurants&start=10
#
# Scraping from Salted & Hung:
# 1659
# http://www.yelp.com/biz/salted-and-hung-singapore?osq=Restaurants
# http://www.yelp.com/biz/salted-and-hung-singapore?osq=Restaurants&start=10
# Saved to reviews_1660.csv
#
# Scraping from Maggie Thai & Chinese:
# 1660
# http://www.yelp.com/biz/maggie-thai-and-chinese-singapore?osq=Restaurants
#
# Scraping from Crystal Jade La Mian Xiao Long Bao:
# 1661
# http://www.yelp.com/biz/crystal-jade-la-mian-xiao-long-bao-singapore-2?osq=Restaurants
#
# Scraping from Ah Bong’s Italian:
# 1662
# http://www.yelp.com/biz/ah-bongs-italian-singapore-2?osq=Restaurants
#
# Scraping from QQ Noodle House:
# 1663
# http://www.yelp.com/biz/qq-noodle-house-singapore?osq=Restaurants
#
# Scraping from Nando’s:
# 1664
# http://www.yelp.com/biz/nandos-singapore?osq=Restaurants
# http://www.yelp.com/biz/nandos-singapore?osq=Restaurants&start=10
#
# Scraping from Kajiken:
# 1665
# http://www.yelp.com/biz/kajiken-singapore-3?osq=Restaurants
#
# Scraping from Choo Choo Chicken:
# 1666
# http://www.yelp.com/biz/choo-choo-chicken-singapore?osq=Restaurants
#
# Scraping from Founder Bak Kut Teh:
# 1667
# http://www.yelp.com/biz/founder-bak-kut-teh-singapore-6?osq=Restaurants
#
# Scraping from Xian De Lai:
# 1668
# http://www.yelp.com/biz/xian-de-lai-singapore?osq=Restaurants
#
# Scraping from Sankai Japanese Restaurant:
# 1669
# http://www.yelp.com/biz/sankai-japanese-restaurant-singapore?osq=Restaurants
#
# Scraping from Big Fish Small Fish Bugis Junction:
# 1670
# http://www.yelp.com/biz/big-fish-small-fish-bugis-junction-singapore?osq=Restaurants
#
# Scraping from Xin Hao Ramen:
# 1671
# http://www.yelp.com/biz/xin-hao-ramen-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from Toast Box:
# 1672
# http://www.yelp.com/biz/toast-box-singapore-18?osq=Restaurants
#
# Scraping from Tarik Cafe:
# 1673
# http://www.yelp.com/biz/tarik-cafe-singapore?osq=Restaurants
#
# Scraping from Papi’s Tacos:
# 1674
# http://www.yelp.com/biz/papis-tacos-singapore?osq=Restaurants
# Sleep: 13s
#
# Scraping from The Mad Sailors:
# 1675
# http://www.yelp.com/biz/the-mad-sailors-singapore?osq=Restaurants
#
# Scraping from Stateland Cafe:
# 1676
# http://www.yelp.com/biz/stateland-cafe-singapore?osq=Restaurants
# http://www.yelp.com/biz/stateland-cafe-singapore?osq=Restaurants&start=10
#
# Scraping from Stuff’d:
# 1677
# http://www.yelp.com/biz/stuffd-singapore-4?osq=Restaurants
#
# Scraping from Chir Chir Bugis Junction:
# 1678
# http://www.yelp.com/biz/chir-chir-bugis-junction-singapore?osq=Restaurants
# Sleep: 77s
# Restart scrapping from last url: i is 1678, Chir Chir Bugis Junction
#
# Scraping from Chir Chir Bugis Junction:
# 1678
# http://www.yelp.com/biz/chir-chir-bugis-junction-singapore?osq=Restaurants
# Sleep: 5s
#
# Scraping from Man Fu Yuan:
# 1679
# http://www.yelp.com/biz/man-fu-yuan-singapore?osq=Restaurants
# http://www.yelp.com/biz/man-fu-yuan-singapore?osq=Restaurants&start=10
# Saved to reviews_1680.csv
#
# Scraping from Manzoku:
# 1680
# http://www.yelp.com/biz/manzoku-singapore?osq=Restaurants
#
# Scraping from Ramen Champion:
# 1681
# http://www.yelp.com/biz/ramen-champion-singapore?osq=Restaurants
# http://www.yelp.com/biz/ramen-champion-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/ramen-champion-singapore?osq=Restaurants&start=20
# Sleep: 76s
# Restart scrapping from last url: i is 1681, Ramen Champion
#
# Scraping from Ramen Champion:
# 1681
# http://www.yelp.com/biz/ramen-champion-singapore?osq=Restaurants
# http://www.yelp.com/biz/ramen-champion-singapore?osq=Restaurants&start=10
# http://www.yelp.com/biz/ramen-champion-singapore?osq=Restaurants&start=20
#
# Scraping from Lime Truck:
# 1682
# http://www.yelp.com/biz/lime-truck-singapore?osq=Restaurants
#
# Scraping from Green Dot Asian Fusion:
# 1683
# http://www.yelp.com/biz/green-dot-asian-fusion-singapore?osq=Restaurants
#
# Scraping from Ciao Italian Risto Bar:
# 1684
# http://www.yelp.com/biz/ciao-italian-risto-bar-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from FatPapas:
# 1685
# http://www.yelp.com/biz/fatpapas-singapore?osq=Restaurants
#
# Scraping from Platypus Kitchen:
# 1686
# http://www.yelp.com/biz/platypus-kitchen-singapore?osq=Restaurants
# http://www.yelp.com/biz/platypus-kitchen-singapore?osq=Restaurants&start=10
#
# Scraping from Seng Huat Eating House:
# 1687
# http://www.yelp.com/biz/seng-huat-eating-house-singapore?osq=Restaurants
# Sleep: 11s
#
# Scraping from Let’s Eat:
# 1688
# http://www.yelp.com/biz/lets-eat-singapore-5?osq=Restaurants
#
# Scraping from Bali Thai:
# 1689
# http://www.yelp.com/biz/bali-thai-singapore-7?osq=Restaurants
#
# Scraping from YY Kafei Dian:
# 1690
# http://www.yelp.com/biz/yy-kafei-dian-singapore?osq=Restaurants
# Sleep: 5s
# http://www.yelp.com/biz/yy-kafei-dian-singapore?osq=Restaurants&start=10
#
# Scraping from Porn’s:
# 1691
# http://www.yelp.com/biz/porns-singapore?osq=Restaurants
#
# Scraping from My Melody Cafe Singapore:
# 1692
# http://www.yelp.com/biz/my-melody-cafe-singapore-singapore?osq=Restaurants
#
# Scraping from Mook’s Thai Mookata BBQ:
# 1693
# http://www.yelp.com/biz/mooks-thai-mookata-bbq-singapore?osq=Restaurants
#
# Scraping from Din Tai Fung:
# 1694
# http://www.yelp.com/biz/din-tai-fung-singapore-22?osq=Restaurants
# http://www.yelp.com/biz/din-tai-fung-singapore-22?osq=Restaurants&start=10
# Sleep: 6s
#
# Scraping from The Cat Cafe:
# 1695
# http://www.yelp.com/biz/the-cat-cafe-singapore-2?osq=Restaurants
#
# Scraping from Black Cow:
# 1696
# http://www.yelp.com/biz/black-cow-singapore?osq=Restaurants
#
# Scraping from Grandma’s:
# 1697
# http://www.yelp.com/biz/grandmas-singapore-9?osq=Restaurants
#
# Scraping from Seng Kee The Black Seed By Chef Benny:
# 1698
# http://www.yelp.com/biz/seng-kee-the-black-seed-by-chef-benny-singapore?osq=Restaurants
#
# Scraping from Madame Fan:
# 1699
# http://www.yelp.com/biz/madame-fan-singapore?osq=Restaurants
# Saved to reviews_1700.csv
#
# Scraping from Food Junction:
# 1700
# http://www.yelp.com/biz/food-junction-singapore?osq=Restaurants
#
# Scraping from McDonald’s:
# 1701
# http://www.yelp.com/biz/mcdonalds-singapore-90?osq=Restaurants
#
# Scraping from Gantetsu - Ramen Champion:
# 1702
# http://www.yelp.com/biz/gantetsu-ramen-champion-singapore?osq=Restaurants
# Sleep: 79s
# Restart scrapping from last url: i is 1702, Gantetsu - Ramen Champion
#
# Scraping from Gantetsu - Ramen Champion:
# 1702
# http://www.yelp.com/biz/gantetsu-ramen-champion-singapore?osq=Restaurants
#
# Scraping from Food Republic:
# 1703
# http://www.yelp.com/biz/food-republic-singapore-25?osq=Restaurants
#
# Scraping from First Thai Food:
# 1704
# http://www.yelp.com/biz/first-thai-food-singapore?osq=Restaurants
# http://www.yelp.com/biz/first-thai-food-singapore?osq=Restaurants&start=10
# Sleep: 11s
#
# Scraping from Dallas Restaurant & Bar:
# 1705
# http://www.yelp.com/biz/dallas-restaurant-and-bar-singapore-2?osq=Restaurants
#
# Scraping from Shinryoku Yakitori:
# 1706
# http://www.yelp.com/biz/shinryoku-yakitori-singapore?osq=Restaurants
#
# Scraping from Churro 101:
# 1707
# http://www.yelp.com/biz/churro-101-singapore?osq=Restaurants
#
# Scraping from Hood Bar and Cafe:
# 1708
# http://www.yelp.com/biz/hood-bar-and-cafe-singapore?osq=Restaurants
# http://www.yelp.com/biz/hood-bar-and-cafe-singapore?osq=Restaurants&start=10
# Sleep: 72s
# Restart scrapping from last url: i is 1708, Hood Bar and Cafe
#
# Scraping from Hood Bar and Cafe:
# 1708
# http://www.yelp.com/biz/hood-bar-and-cafe-singapore?osq=Restaurants
# http://www.yelp.com/biz/hood-bar-and-cafe-singapore?osq=Restaurants&start=10
#
# Scraping from Fei Zai Fried Kway Teow:
# 1709
# http://www.yelp.com/biz/fei-zai-fried-kway-teow-singapore?osq=Restaurants
#
# Scraping from Kotobuki:
# 1710
# http://www.yelp.com/biz/kotobuki-singapore-3?osq=Restaurants
#
# Scraping from Tonkatsu Ma Maison:
# 1711
# http://www.yelp.com/biz/tonkatsu-ma-maison-singapore-2?osq=Restaurants
# Res Status Code: 400
#
# Scraping from Vietnamese - Authentic Vietnamese Cuisine:
# 1712
# http://www.yelp.com/biz/vietnamese-authentic-vietnamese-cuisine-singapore?osq=Restaurants
# http://www.yelp.com/biz/vietnamese-authentic-vietnamese-cuisine-singapore?osq=Restaurants&start=10
#
# Scraping from 块三点心 $1.30 Dim Sum:
# 1713
# http://www.yelp.com/biz/%E5%9D%97%E4%B8%89%E7%82%B9%E5%BF%83-1-30-dim-sum-singapore?osq=Restaurants
#
# Scraping from SG Kitchen:
# 1714
# http://www.yelp.com/biz/sg-kitchen-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from iO Italian Osteria:
# 1715
# http://www.yelp.com/biz/io-italian-osteria-singapore?osq=Restaurants
# http://www.yelp.com/biz/io-italian-osteria-singapore?osq=Restaurants&start=10
#
# Scraping from Tsukada Nojo:
# 1716
# http://www.yelp.com/biz/tsukada-nojo-singapore-3?osq=Restaurants
#
# Scraping from The Meeting Place:
# 1717
# http://www.yelp.com/biz/the-meeting-place-singapore?osq=Restaurants
#
# Scraping from Riverside Indonesian BBQ:
# 1718
# http://www.yelp.com/biz/riverside-indonesian-bbq-singapore-4?osq=Restaurants
# Sleep: 6s
#
# Scraping from Ippudo Westgate:
# 1719
# http://www.yelp.com/biz/ippudo-westgate-singapore?osq=Restaurants
# Saved to reviews_1720.csv
#
# Scraping from Waa Cow!:
# 1720
# http://www.yelp.com/biz/waa-cow-singapore?osq=Restaurants
# Sleep: 12s
#
# Scraping from The Kitchen Table:
# 1721
# http://www.yelp.com/biz/the-kitchen-table-singapore?osq=Restaurants
# Sleep: 6s
#
# Scraping from Unique Pot:
# 1722
# http://www.yelp.com/biz/unique-pot-singapore?osq=Restaurants
#
# Scraping from Blue Lotus Chinese Eating House:
# 1723
# http://www.yelp.com/biz/blue-lotus-chinese-eating-house-quayside-isle?osq=Restaurants
#
# Scraping from Tenderfresh Classic:
# 1724
# http://www.yelp.com/biz/tenderfresh-classic-singapore?osq=Restaurants
#
# Scraping from Gaia Korean Grill + Bar:
# 1725
# http://www.yelp.com/biz/gaia-korean-grill-bar-singapore?osq=Restaurants
#
# Scraping from Kim’s Family Food Korean Restaurant:
# 1726
# http://www.yelp.com/biz/kims-family-food-korean-restaurant-singapore-2?osq=Restaurants
# http://www.yelp.com/biz/kims-family-food-korean-restaurant-singapore-2?osq=Restaurants&start=10
#
# Scraping from Sabio By The Sea:
# 1727
# http://www.yelp.com/biz/sabio-by-the-sea-southern-islands?osq=Restaurants
# Sleep: 7s
#
# Scraping from Colonial Club:
# 1728
# http://www.yelp.com/biz/colonial-club-singapore-2?osq=Restaurants
#
# Scraping from Paik’s Bibim:
# 1729
# http://www.yelp.com/biz/paiks-bibim-singapore-2?osq=Restaurants
#
# Scraping from Lim Joo Hin Eating House:
# 1730
# http://www.yelp.com/biz/lim-joo-hin-eating-house-singapore?osq=Restaurants
#
# Scraping from Wang Jiao Handmade Noodle:
# 1731
# http://www.yelp.com/biz/wang-jiao-handmade-noodle-singapore?osq=Restaurants
# Sleep: 7s
#
# Scraping from PocoLoco:
# 1732
# http://www.yelp.com/biz/pocoloco-singapore-2?osq=Restaurants
#
# Scraping from Dancing Crab:
# 1733
# http://www.yelp.com/biz/dancing-crab-singapore-3?osq=Restaurants
# Sleep: 66s
# Restart scrapping from last url: i is 1733, Dancing Crab
#
# Scraping from Dancing Crab:
# 1733
# http://www.yelp.com/biz/dancing-crab-singapore-3?osq=Restaurants
#
# Scraping from Swensen’s:
# 1734
# http://www.yelp.com/biz/swensens-singapore-12?osq=Restaurants
#
# Scraping from Astons’s Specialities:
# 1735
# http://www.yelp.com/biz/astonss-specialities-singapore?osq=Restaurants
#
# Scraping from Ya Hua Bak Kut Teh:
# 1736
# http://www.yelp.com/biz/ya-hua-bak-kut-teh-singapore-2?osq=Restaurants
# Sleep: 6s
# http://www.yelp.com/biz/ya-hua-bak-kut-teh-singapore-2?osq=Restaurants&start=10
#
# Scraping from Two Chefs Bar:
# 1737
# http://www.yelp.com/biz/two-chefs-bar-southern-islands?osq=Restaurants
# Sleep: 6s
#
# Scraping from Shutters Restaurant:
# 1738
# http://www.yelp.com/biz/shutters-restaurant-sentosa-island?osq=Restaurants

# %%
rest_url['href'][0]

# %%
soup=get_soup(rest_url['href'][0])

# %%
soup.find_all('meta')
# Out:
# [<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>,
#  <meta content="en-US" http-equiv="Content-Language"/>,
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>,
#  <meta id="emotion-container"/>,
#  <meta name="critical_css_middleware"/>,
#  <meta content="19 reviews of The Naked Finn &quot;They serve the BEST cocktails you can ever find in Singapore!
#
#  I love the fact that they live up to their name of being &quot;naked&quot;, for the fact that the ingredients used in the choice of seafood are simply salt, pepper and olive oil to bring out the freshness in their seafood!
#  The cocktails, served at -12°C, taste FRESH!
#
#  Made my first visit there from friend's recommendation and tried all of their 3 signature cocktails, Strawberry, Coconut and Kyoho grapes.
#  The ingredients are freshly pacotized (according to their website), and it seriously brought me to heaven!
#  Ordered a portion of baby squids for sharing (as it was rather late that night, that we headed there for some really chill night out) - SO FRESH!
#  I have never imagined that COCONUT can make such an awesome ingredient for a cocktail. lovely surprise!
#
#  p.s. waiter was SO NICE, and asked us &quot;is everything ok?&quot; after serving. top notch!
#
#  I love that place, the environment (can get really quiet as they have limited tables), the drinks, the food!
#  Gonna frequent this place whenever I have some cocktail cravings!&quot;" data-rh="true" name="description"/>,
#  <meta content="BfGgttAzEPx9v7b8Sgkedw" data-rh="true" name="yelp-biz-id"/>,
#  <meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" data-rh="true" name="keywords"/>,
#  <meta content="Yelp" data-rh="true" property="og:site_name"/>,
#  <meta content="yelpyelp:business" data-rh="true" property="og:type"/>,
#  <meta content="https://s3-media0.fl.yelpcdn.com/bphoto/ScSHvCNpbz7DI-_DsDDtaA/o.jpg" data-rh="true" property="og:image"/>,
#  <meta content="1125" data-rh="true" property="og:image:height"/>,
#  <meta content="2000" data-rh="true" property="og:image:width"/>,
#  <meta content="The Naked Finn - Singapore, SG" data-rh="true" property="og:title"/>,
#  <meta content="https://www.yelp.com/biz/the-naked-finn-singapore?osq=Restaurants" data-rh="true" property="og:url"/>,
#  <meta content="" data-rh="true" property="og:description"/>,
#  <meta content="97534753161" data-rh="true" property="fb:app_id"/>,
#  <meta content="app-id=284910350, app-argument=yelp:///biz/BfGgttAzEPx9v7b8Sgkedw?utm_campaign=default&amp;amp;utm_source=www" data-rh="true" name="apple-itunes-app"/>,
#  <meta content="Yelp" data-rh="true" property="al:ios:app_name"/>,
#  <meta content="284910350" data-rh="true" property="al:ios:app_store_id"/>,
#  <meta content="https://www.yelp.com/biz/the-naked-finn-singapore?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple" data-rh="true" property="al:ios:url"/>,
#  <meta content="Yelp" data-rh="true" name="application-name"/>,
#  <meta content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/f5e05563b53a/ico/win8-tile.png" data-rh="true" name="msapplication-TileImage"/>,
#  <meta content="\#FFFFFF" data-rh="true" name="msapplication-TileColor"/>,
#  <meta content="https://www.yelp.com" data-rh="true" name="msapplication-starturl"/>,
#  <meta content="\#FF1A1A" data-rh="true" name="msapplication-navbutton-color"/>,
#  <meta content="width=1024;height=768" data-rh="true" name="msapplication-window"/>,
#  <meta content="Go to https://www.yelp.com" data-rh="true" name="msapplication-tooltip"/>,
#  <meta content="[object Object]" data-rh="true" name="msapplication-task"/>,
#  <meta content="[object Object]" data-rh="true" name="msapplication-task"/>,
#  <meta content="[object Object]" data-rh="true" name="msapplication-task"/>,
#  <meta content="3.0" itemprop="ratingValue"/>,
#  <meta content="4.5" itemprop="ratingValue"/>,
#  <meta content="3.5" itemprop="ratingValue"/>,
#  <meta content="4.5" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>]

# %%
# Address info
add = ''

for row in soup.find('address').find_all('span', {'class':'raw__09f24__T4Ezm'}):
    add += (row.text + ' ')
    
print(add)
postal_code = re.search('\d{6}', add).group()
print(postal_code)

# %%
onemap = get_soup(f'https://developers.onemap.sg/commonapi/search?searchVal={postal_code}&returnGeom=Y&getAddrDetails=Y&pageNum=1')
latitude = json.loads(onemap.p.text)['results'][0]['LATITUDE']
longitude = json.loads(onemap.p.text)['results'][0]['LONGTITUDE']

# %%
# Convert postal code to lat long
# https://developers.onemap.sg/commonapi/search?searchVal=revenue&returnGeom=Y&getAddrDetails=Y&pageNum=1

# %%
# opening hours info
day=[]
hrs=[]
for row in soup.find('table', {'class':'hours-table__09f24__KR8wh table__09f24__J2OBP table--simple__09f24__vy16f'}).find_all('th', {'class':"table-header-cell__09f24__y32Xb"}):
    day.append(row.text)
    
for row in soup.find('table', {'class':'hours-table__09f24__KR8wh table__09f24__J2OBP table--simple__09f24__vy16f'}).find_all('ul', {'class':"undefined list__09f24__ynIEd"}):
    subset=[]
    for i in range(len(row.find_all('li'))):
        subset.append(row.find_all('li')[i].text)
    hrs.append(subset)
    
list(zip(day, hrs))

# %%
review_li[1].find('div', {'class':'user-passport-info border-color--default__09f24__NPAKY'}).find('span', {'class':'css-qgunke'}).text

# %%
# Review info
review_li = soup.find('div', {'class':'css-79elbk border-color--default__09f24__NPAKY'}).find_all('li', {'class':'margin-b5__09f24__pTvws border-color--default__09f24__NPAKY'})
for row in review_li:
    # username
    print(row.find('div', {'class':'user-passport-info border-color--default__09f24__NPAKY'}).a.text)
    # usesrid
    print(row.find('div', {'class':'user-passport-info border-color--default__09f24__NPAKY'}).a['href'].replace('/user_details?userid=',''))
    # location
    print(row.find('div', {'class':'user-passport-info border-color--default__09f24__NPAKY'}).find('span', {'class':'css-qgunke'}).text)
    # rating
    print(row.find('div', {'class':'margin-t1__09f24__w96jn margin-b1-5__09f24__NHcQi border-color--default__09f24__NPAKY'}).span.div['aria-label'].replace(' star rating',''))
    # date of post
    print(row.find('span', {'class':'css-chan6m'}).text)
    # comments
    print(row.find('span', {'class':'raw__09f24__T4Ezm'}).text)

# %%
# find_list = soup.find('main', {"id": "main-content"}).find_all('a')

# restaurants = []

# for row in find_list:
#     try:
#         restaurant ={}
    
#         restaurant['name']=row['name']
#         href=row['href']
#         restaurant['href']=f'www.yelp.com{href}'
        
#         restaurants.append(restaurant)

#     except:
#         pass
        
# pd.DataFrame(restaurants)
